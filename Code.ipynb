# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Task 1: Image Inpainting using GANs**

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
tf.compat.v1.reset_default_graph()

# %% [markdown]
# ### Function Definitions for GANs

# %%
import tensorflow as tf
import cv2 as cv
import random
import os
import math
import numpy as np

def random_interpolates(x, y, alpha=None):
    """
    x: first dimension as batch_size
    y: first dimension as batch_size
    alpha: [BATCH_SIZE, 1]
    """
    shape = x.get_shape().as_list()
    x = tf.reshape(x, [shape[0], -1])
    y = tf.reshape(y, [shape[0], -1])
    if alpha is None:
        alpha = tf.compat.v1.random_uniform(shape=[shape[0], 1])
    interpolates = x + alpha*(y - x)
    return tf.reshape(interpolates, shape)


def gradients_penalty(x, y, mask=None, norm=1.):
    """Improved Training of Wasserstein GANs
    - https://arxiv.org/abs/1704.00028
    """
    gradients = tf.gradients(y, x)[0]
    if mask is None:
        mask = tf.ones_like(gradients)
    slopes = tf.sqrt(tf.reduce_mean(tf.square(gradients) * mask, axis=[1, 2, 3]))
    return tf.reduce_mean(tf.square(slopes - norm))


def standard_conv(x,mask,cnum,ksize=3,stride=1,rate=1,name='conv',padding='SAME'):
        '''
        define convolution for generator
        Args:
                x:iput image
                cnum: channel number
                ksize: kernal size
                stride: convolution stride
                rate : rate for dilated conv
                name: name of layers
        '''
        p       = int(rate*(ksize-1)/2)
        x       = tf.pad(x, [[0,0], [p, p], [p, p], [0,0]],'REFLECT')
        padding = 'VALID'
        x       = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                  ,padding=padding,name=name+'_1')
        return x
def standard_dconv(x,mask,cnum,name='deconv',padding='VALID'):
        '''
        define upsample convolution for generator
        Args:
        x: input image
        mask: input mask
        name: name of layers
        '''
        rate   = 1
        ksize  = 3
        stride = 1
        shape  = x.get_shape().as_list()
        x      = tf.compat.v1.image.resize_nearest_neighbor(x,[shape[1]*2,shape[2]*2])
        p3     = int(1 * (3 - 1) / 2)
        x      = tf.pad(x, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')
        x      = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                          ,padding=padding,name=name+'_1')
        return x


def l2_norm(v, eps=1e-12):
    return v / (tf.reduce_sum(v ** 2) ** 0.5 + eps)


def spectral_norm(w, iteration=1,name='dasd'):
   w_shape = w.shape.as_list()
   w = tf.reshape(w, [-1, w_shape[-1]])

   u = tf.compat.v1.get_variable(name+"u", [1, w_shape[-1]], initializer=tf.compat.v1.truncated_normal_initializer(), trainable=False)

   u_hat = u
   v_hat = None
   for i in range(0, iteration):
       v_ = tf.matmul(u_hat, tf.transpose(w))
       v_hat = l2_norm(v_)

       u_ = tf.matmul(v_hat, w)
       u_hat = l2_norm(u_)

   sigma = tf.matmul(tf.matmul(v_hat, w), tf.transpose(u_hat))
   w_norm = w / sigma

   with tf.control_dependencies([u.assign(u_hat)]):
       w_norm = tf.reshape(w_norm, w_shape)

   return w_norm


def LeakyRelu(x, leak=0.2, name="LeakyRelu"):
        f1 = 0.5 * (1 + leak)
        f2 = 0.5 * (1 - leak)
        return f1 * x + f2 * tf.abs(x)


def dis_conv(x, cnum, ksize=5, stride=2, activation = 'leak_relu', name='conv'):
    """
    covolution for discriminator.
    Args:
        x: input image
        cnum: channel number.
        ksize: kernel size.
        Stride: convolution stride.
        name: name of layers.
    """

    x_shape = x.get_shape().as_list()
    w = tf.compat.v1.get_variable(name = name+'_w',shape = [ksize, ksize, x_shape[-1]] + [cnum])
    w = spectral_norm(w, name = name)
    x = tf.nn.conv2d(x, w, strides = [1, stride, stride, 1], padding = 'SAME')
    bias = tf.compat.v1.get_variable(name=name+'_bias',shape=[cnum])
    if activation != None:
        return  LeakyRelu(x + bias, name = name)
    else:
        return x + bias

# %%
from random import randint
import itertools
import numpy as np
import cv2
from math import *
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

def continuous_mask(height, width,num,maxAngle,maxLength,maxBrushWidth,channels=3):
    """Generates a continuous mask with lines, circles and elipses"""

    img = np.zeros((height, width, channels), np.uint8)

    for j in range(0, 1):
        startX = randint(0, width)
        startY = randint(0, height)
        for i in range(0,randint(1,num)):
            angle = randint(0,maxAngle)
            if i%2==0:
                angle = 360 - angle
            length = randint(1,maxLength)
            brushWidth = randint(1, maxBrushWidth)
            endX   = startX + int(length * sin(angle))
            endY   = startY + int(length * cos(angle))
            if endX>255:
                endX = 255
            if endX<0:
                endX = 0
            if endY>255:
                endY = 255
            if endY<0:
                endY = 0
            cv2.line(img, (startX,startY),(endX,endY),(255,255,255),brushWidth)
            cv2.circle(img, (endX,endY),brushWidth//2,(255,255,255),-1)
            startY = endY
            startX = endX


    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return 1-img2



def discontinuous_mask(height, width,num,low,high,channels=3):
    """Generates a discontinuous mask with lines, circles and elipses
       When we were training, we generated more elipses
    """
    img = np.zeros((height, width, channels), np.uint8)

    # Set size scale
    size = int((width + height) * 0.1)
    if width < 64 or height < 64:
        raise Exception("Width and Height of mask must be at least 64!")

    # Draw random lines
    for _ in range(0, randint(1, num)):
        x1, x2 = randint(1, width), randint(1, width)
        y1, y2 = randint(1, height), randint(1, height)
        thickness = randint(3, size)
        cv2.line(img,(x1,y1),(x2,y2),(1,1,1),thickness)

    # Draw random circles
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        radius = randint(3, size)
        cv2.circle(img,(x1,y1),radius,(1,1,1), -1)

    # Draw randow rectangle
    for _ in range(0, randint(1, num)):
        x1,y1 = randint(1, width), randint(1, height)
        x2,y2 = randint(1, width), randint(1, height)
        cv2.rectangle(img, (x1, y1), (x2, y2), (1, 1, 1), -1)

    # Draw random ellipses
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        s1, s2 = randint(low, high), randint(low, high)
        a1, a2, a3 = randint(3, 180), randint(3, 180), randint(3, 180)
        thickness = randint(3, size)
        cv2.ellipse(img, (x1,y1), (s1,s2), a1, a2, a3,(1,1,1), thickness)

    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return img2


mask = continuous_mask(256, 256, 60, 270, 32, 15)
plt.imshow(mask)
#print(mask)
cv2.waitKey(0)
# Out:
# -1

# %%
import tensorflow as tf
import cv2 as cv
import numpy as np

def region_deconv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)

    x_fusion   = standard_dconv(x_fusion,mask,shape[-1],name = name+"_fusion")
    return x_fusion

def region_conv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    p3 = int(1 * (3 - 1) / 2)

    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)
    x_fusion   = tf.pad(x_fusion, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')

    x_fusion   = tf.compat.v1.layers.conv2d(x_fusion, shape[-1], kernel_size = 3, strides = 1, padding = 'VALID', dilation_rate = 1, name = name + "_fusion")
    x_fusion   = tf.nn.elu(x_fusion)
    return x_fusion

# %%
import inspect
import os

import numpy as np
import tensorflow as tf
import time

VGG_MEAN = [103.939, 116.779, 123.68]


class Vgg16:
    def __init__(self, vgg16_npy_path=None):
        if vgg16_npy_path is None:
            path = inspect.getfile(Vgg16)
            path = os.path.abspath(os.path.join(path, os.pardir))
            path = os.path.join(path, "vgg16.npy")
            vgg16_npy_path = path
            print(path)

        self.data_dict = np.load(vgg16_npy_path, encoding='latin1', allow_pickle=True).item()
        print("npy file loaded")

    def build(self, rgb):
        """
        load variable from npy to build the VGG
        :param rgb: rgb image [batch, height, width, 3] values scaled [0, 1]
        """

        start_time = time.time()
        rgb = tf.compat.v1.image.resize_images(rgb, (224, 224))
        print("build model started")
        rgb_scaled = (rgb+1.) * 127.5
        #print(type(rgb[0][0][0][0]))

        # Convert RGB to BGR
        # red, green, blue = tf.split(3, 3, rgb_scaled)
        red, green, blue = tf.split(rgb_scaled, 3, 3)
        assert red.get_shape().as_list()[1:] == [224, 224, 1]
        assert green.get_shape().as_list()[1:] == [224, 224, 1]
        assert blue.get_shape().as_list()[1:] == [224, 224, 1]
        bgr = tf.concat([
            blue - VGG_MEAN[0],
            green - VGG_MEAN[1],
            red - VGG_MEAN[2],
        ], 3)
        assert bgr.get_shape().as_list()[1:] == [224, 224, 3]

        self.conv1_1 = self.conv_layer(bgr, "conv1_1")
        self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
        self.pool1 = self.max_pool(self.conv1_2, 'pool1')

        self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
        self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
        self.pool2 = self.max_pool(self.conv2_2, 'pool2')

        self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
        self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
        self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
        self.pool3 = self.max_pool(self.conv3_3, 'pool3')

        self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
        self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
        self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
        self.pool4 = self.max_pool(self.conv4_3, 'pool4')

        self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
        self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
        self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
        self.pool5 = self.max_pool(self.conv5_3, 'pool5')


        print("build model finished: %ds" % (time.time() - start_time))

    def avg_pool(self, bottom, name):
        return tf.nn.avg_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def max_pool(self, bottom, name):
        return tf.nn.max_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def conv_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            filt = self.get_conv_filter(name)

            conv = tf.nn.conv2d(bottom, filt, [1, 1, 1, 1], padding='SAME')

            conv_biases = self.get_bias(name)
            bias = tf.nn.bias_add(conv, conv_biases)

            relu = tf.nn.relu(bias)
            return relu

    def fc_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            shape = bottom.get_shape().as_list()
            dim = 1
            for d in shape[1:]:
                dim *= d
            x = tf.reshape(bottom, [-1, dim])

            weights = self.get_fc_weight(name)
            biases = self.get_bias(name)

            # Fully connected layer. Note that the '+' operation automatically
            # broadcasts the biases.
            fc = tf.nn.bias_add(tf.matmul(x, weights), biases)

            return fc

    def get_conv_filter(self, name):
        return tf.constant(self.data_dict[name][0], name="filter")

    def get_bias(self, name):
        return tf.constant(self.data_dict[name][1], name="biases")

    def get_fc_weight(self, name):
        return tf.constant(self.data_dict[name][0], name="weights")

def loss_perceptual(pic1, pic2, pic3):
    loss = 0

    for o, c, g in zip(pic2, pic3, pic1):
        loss += l1(o, g) + l1(c, g)
    return loss

def l1(pic1, pic2):
    return tf.reduce_sum(tf.abs(pic1 - pic2))

def gram_matrix(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_a=True)
    gram = gram / tf.cast(C * H * W, x.dtype)
    return gram
def new_gram(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_b=True)
    gram = gram / tf.cast(C * C, x.dtype)
    return gram
def loss_style(output, vgg_gt):
    loss = 0
    for o, g in zip(output, vgg_gt):
        loss += l1(gram_matrix(o), gram_matrix(g))
    return loss

def loss_cor(output, vgg_gt):
    loss = 0
    loss_new = l1(new_gram(output[1]), new_gram(vgg_gt[1]))
    return loss_new

# %%
import tensorflow as tf
import cv2 as cv
import numpy as np

def RW_generator(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Region-wise generator
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            predicted image
    '''
    x1 = SINet(x, mask, reuse=reuse)
    x_combine = x * mask + x1 * (1 - mask)
    x2 = GPNet(x_combine,mask, reuse=reuse)
    return x1, x2

def SINet(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Semantic inferring network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by semantic inferring network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    ones_x = tf.ones_like(x)[:, :, :, 0:1]
    x = tf.concat([x, mask], axis=3)
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x_complete, x_missing = tf.concat([x12,x4],axis=-1),x12
            x13 = region_deconv(x_complete, x_missing, mask,name = 'com_13')

            x_complete, x_missing = tf.concat([x13,x3],axis=-1),x13
            x14 = region_conv(x_complete,x_missing,mask,name='com_14')

            x_complete, x_missing = tf.concat([x14,x2],axis=-1),x14
            x15 = region_deconv(x_complete, x_missing, mask, name = 'com_15')

            x16 = standard_conv(x15,mask,cnum,3,1,name='conv16')

            x17=standard_conv(x16,mask,cnum//2,3,1,name='conv17')
            x18=standard_conv(x17,mask,3,3,1,name='conv18')
            x18=tf.clip_by_value(x18,-1.,1.)

            return x18
def GPNet(x,mask,padding='SAME',name='inpaint_net_1',reuse=False):
    '''
    Global perceiving network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by global perceiving network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    x = tf.concat([x, mask], axis=3) #concat
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x13=standard_dconv(tf.concat([x12,x4],axis=-1),mask,2*cnum,name='conv13_upsample')
            x14=standard_conv(tf.concat([x13,x3],axis=-1),mask,2*cnum,3,1,name='conv14')
            x15=standard_dconv(tf.concat([x14,x2],axis=-1),mask,cnum,name='conv15_upsample')
            x16=standard_conv(tf.concat([x15,x1],axis=-1),mask,cnum//2,3,1,name='conv16')
            x17=standard_conv(x16,mask,3,3,1,name='conv17')
            x18=tf.clip_by_value(x17,-1.,1.)

            return x18

def RW_discriminator(x, mask, batch_size, activation = 'leaky_relu',reuse=False):
    '''
    Region-wise discriminator
    Args:
            x: input images
            mask: mask region {0,1}
    returns:
            matrix {real, fake}
    '''
    with tf.compat.v1.variable_scope('discriminator',reuse=reuse):
            cnum=64
            x=tf.concat([x,mask],axis=3)
            x=dis_conv(x,cnum,name='d_conv1')
            x=dis_conv(x,2*cnum,name='d_conv2')
            x=dis_conv(x,4*cnum,name='d_conv3')
            x=dis_conv(x,4*cnum,name='d_conv4')
            x=dis_conv(x,4*cnum,name='d_conv5')
            x=dis_conv(x,4*cnum,name='d_conv6', activation = activation)
            return x
def build_graph_with_loss(batch_data, batch_size, mask, vgg_path, adv_type, stage = 0,
                         lambda_style = 0.001, lambda_cor = 0.00001, alpha = 0.01 ,lambda_adv = 1.0,
                         reuse=False, training = True):

    image_gt=tf.subtract(tf.divide(batch_data,127.5),1.)
    date_shape=batch_data.get_shape().as_list()
    batch_incomplete=image_gt*mask

    image_p1, image_p2 = RW_generator(batch_incomplete, mask)
    image_c1 = image_p1 * (1 - mask) + image_gt * mask
    image_c2 = image_p2 * (1 - mask) + image_gt * mask
    rec_loss = tf.reduce_sum(tf.abs(image_gt - image_p1)) + tf.reduce_sum(tf.abs(image_gt - image_p2))

    vgg = Vgg16(vgg_path)
    vgg.build(image_gt)
    vgg_pos = [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c1)
    vgg_x1 =  [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c2)
    vgg_x2 =  [vgg.pool1,vgg.pool2, vgg.pool3]

    cor_loss = loss_cor(vgg_x1, vgg_pos)
    style_loss= loss_style(vgg_x2, vgg_pos)
    cor_loss = cor_loss * lambda_cor
    style_loss = style_loss * lambda_style
    cor_style = cor_loss + style_loss


    if stage == 1:
        activation = None
        if adv_type == ' ':
            activation = 'leaky_relu'
        d_pred = RW_discriminator(image_c1 * (1 - mask), mask, batch_size, activation)
        d_pred2 = RW_discriminator(image_c2 * (1 - mask), mask, batch_size, activation, reuse = True)
        d_real = RW_discriminator(image_gt * (1 - mask), mask, batch_size, activation, reuse = True)
        mask_label = 1 - mask
        shape = d_pred.get_shape().as_list()
        mask_label =  tf.compat.v1.image.resize_nearest_neighbor(mask_label, [shape[1],shape[2]])
        if adv_type == 'wgan':
            penalty_img = random_interpolates(image_gt, image_c2)
            dout_penalty = RW_discriminator(penalty_img, mask, batch_size, activation,reuse = True)
            penalty_loss = gradients_penalty(penalty_img, dout_penalty, mask = mask)
            adv_d_loss =  tf.reduce_mean(d_pred * mask_label) + tf.reduce_mean(d_pred2 * mask_label) - 0.01 * tf.reduce_mean(d_real * mask_label) +penalty_loss
            adv_g_loss = -1 * tf.reduce_mean(d_pred * mask_label) - tf.reduce_mean(d_pred2 * mask_label)

        elif adv_type == 'gan':
            adv_d_loss = 0.01 * tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_real, labels=tf.ones_like(d_real)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.zeros_like(d_pred)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.zeros_like(d_pred2))* mask_label)
            adv_g_loss = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.ones_like(d_real)) * mask_label)  + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.ones_like(d_real)) * mask_label)

        elif adv_type == 'hinge':

            adv_d_loss =  0.01 * tf.reduce_mean(tf.nn.relu(1 - d_real) * mask_label) + tf.reduce_mean(tf.nn.relu(1 + d_pred) * mask_label)
            + tf.reduce_mean(tf.nn.relu(1 + d_pred2) * mask_label)
            adv_g_loss = -1 * tf.reduce_mean(tf.nn.relu(d_pred) * mask_label) - tf.reduce_mean(tf.nn.relu(d_pred2) * mask_label)
        else:

            adv_d_loss =  alpha*tf.reduce_sum(tf.abs(mask_label - d_real)) + tf.reduce_sum(tf.abs(0 - d_pred)) + tf.reduce_sum(tf.abs(0 - d_pred2))
            adv_g_loss = tf.reduce_sum(tf.abs(mask_label - d_pred)) + tf.reduce_sum(tf.abs(mask_label - d_pred2))
    else:
        adv_d_loss = None
        adv_g_loss = None

    if stage == 1:
        g_loss= rec_loss+cor_style + lambda_adv * adv_g_loss
    else:
        g_loss = rec_loss + cor_style
    g_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'inpaint_net')
    d_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'discriminator') if stage == 1 else None

    tf.compat.v1.summary.image('incomplete',batch_incomplete, max_outputs=7)
    tf.compat.v1.summary.image('image_p1',image_p1, max_outputs=7)
    tf.compat.v1.summary.image('image_p2',image_p2, max_outputs=7)
    tf.compat.v1.summary.image('image_c2',image_c2, max_outputs=7)
    tf.compat.v1.summary.scalar('rec_loss',rec_loss)
    tf.compat.v1.summary.scalar('correlation loss', cor_loss)
    tf.compat.v1.summary.scalar('style loss', style_loss)
    if stage == 1:
        tf.compat.v1.summary.scalar('adv_g_loss', adv_g_loss)
        tf.compat.v1.summary.scalar('adv_d_loss', adv_d_loss)
    return g_vars,d_vars,g_loss,adv_d_loss,rec_loss,cor_loss,style_loss

# %% [markdown]
# ## Training Block for GANs

# %%
from tensorflow.python import pywrap_tensorflow
import math
import random
import gc
import os
import cv2
import glob
import socket
import tensorflow as tf
import argparse

train_data_path = "/content/drive/MyDrive/DL_Milestone_2/images"
epoch = 20
batch_size=8
width = 256
height = 256
mask_area = 60
learning_rate = 0.0003
beta1 = 0.5
beta2 = 0.9
lambda_style = 0.001
lambda_cor = 0.00001
lambda_adv = 1.0
alpha = 0.001
stage = 1
discriminator_train = 0
mask_type = 1
pretrained_model = "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint"
adv_type = 'gan'
vgg_path = "/content/drive/MyDrive/DL_Milestone_2/vgg16.npy"
output = "/content/drive/MyDrive/DL_Milestone_2/output"

fnames = glob.glob(train_data_path + '/*.png')
filename_queue = tf.compat.v1.train.string_input_producer(fnames, shuffle = True)
reader = tf.compat.v1.WholeFileReader()
_,img_bytes = reader.read(filename_queue)
images = tf.image.decode_png(img_bytes, channels = 3)
images = tf.compat.v1.image.resize_images(images,[height, width])
images = tf.compat.v1.train.batch([images],batch_size, dynamic_pad = True)
mask   = tf.compat.v1.placeholder(tf.float32,[batch_size, height, width, 1], name = 'mask')

# %%
sess = tf.compat.v1.Session()
if discriminator_train == 0:
  g_vars, _, adv_g_loss, _,rec_loss, correlation_loss, style_loss = build_graph_with_loss(images, batch_size, mask, vgg_path, adv_type, discriminator_train, lambda_style, lambda_cor, alpha, lambda_adv)
else:
  g_vars, d_vars, adv_g_loss, adv_d_loss, rec_loss, correlation_loss, style_loss = build_graph_with_loss(images, batch_size, mask, vgg_path, adv_type, discriminator_train, lambda_style, lambda_cor, alpha , lambda_adv)
  d_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = 0.0001, beta1 = 0.5, beta2 = 0.9).minimize(adv_d_loss, var_list = d_vars)
g_optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = 0.0003, beta1 = 0.5, beta2 = 0.9).minimize(adv_g_loss, var_list = g_vars)

init_op = tf.group(tf.compat.v1.initialize_all_variables(), tf.compat.v1.initialize_local_variables()) # tf.initialize_all_variables()
sess.run(init_op)
if stage == 1:
  saver_pre = tf.compat.v1.train.Saver(g_vars)
  saver_pre.restore(sess, pretrained_model)

tf.compat.v1.train.start_queue_runners(sess)
summarywriter = tf.compat.v1.summary.FileWriter(output + '/summary', tf.compat.v1.get_default_graph())
merge = tf.compat.v1.summary.merge_all()
Iters = int(len(fnames)/batch_size)
saver = tf.compat.v1.train.Saver(max_to_keep=5)
low   = 0
it    = 0
high=height
num=mask_area
for j in range(0,10):
  mask_type=1
  for i in range(0, Iters):
    if mask_type == 0:
      mask_ = np.stack([discontinuous_mask(height,width,num,low,high) for _ in range(0, batch_size)], axis=0)
    else:
      mask_ = np.stack([continuous_mask(height,width, num,360,32,15) for _ in range(0, batch_size)], axis=0)
    if discriminator_train == 0:
       _,g,rec,closs,sloss=sess.run([g_optimizer,adv_g_loss,rec_loss,correlation_loss,style_loss],feed_dict={mask:mask_,})
    else:
       _,_,g,d,rec,closs,sloss=sess.run([g_optimizer,d_optimizer,adv_g_loss,adv_d_loss,rec_loss,correlation_loss,style_loss],feed_dict={mask:mask_,})
    if i % 20==0:
      if discriminator_train == 0:
        print('[{}/{}]rec_loss: {} correlation_loss:{}  style_loss: {}'.format(i,Iters,rec,closs,sloss))
      else:
        print('[{}/{}]g_loss: {}  rec_loss: {} correlation_loss:{}  style_loss: {} d_loss: {}'.format(i,Iters,g,rec,closs,sloss,d))
    it += 1
  saver.save(sess, "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint")

# %% [markdown]
# ## Test Block for GANs

# %%
def infer(batch_data,mask,reuse=False):
        shape=batch_data.get_shape().as_list()
        batch_gt=batch_data/127.5-1.
        batch_incomplete=batch_gt*mask

        image_p1, image_p2=RW_generator(batch_incomplete,mask,reuse=reuse)

        image_c2=batch_incomplete*mask+ image_p2*(1.-mask)
        image_c2=(image_c2+1.)*127.5
        return image_c2

# %%
def calculate_psnr(img1, img2):
    # Read images
    image1 = cv2.imread(img1)
    image2 = cv2.imread(img2)

    # Ensure images have the same shape
    if image1.shape != image2.shape:
        raise ValueError("Input images must have the same dimensions")

    # Calculate MSE (Mean Squared Error)
    mse = np.mean((image1 - image2) ** 2)

    # Calculate PSNR (Peak Signal-to-Noise Ratio)
    if mse == 0:
        return float('inf')
    max_pixel = 255.0
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr

# %%
from skimage.metrics import structural_similarity as ssim
def calculate_ssim(img1, img2):
    # Read images
    image1 = cv2.imread(img1)
    image2 = cv2.imread(img2)

    # Ensure images have the same shape
    if image1.shape != image2.shape:
        raise ValueError("Input images must have the same dimensions")

    # Convert images to grayscale
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

    # Calculate SSIM
    ssim_index, _ = ssim(gray1, gray2, full=True)
    return ssim_index

# %%
images=tf.compat.v1.placeholder(tf.float32,[1,256,256,3],name = 'image')
mask=tf.compat.v1.placeholder(tf.float32,[1,256,256,1],name='mask')
sess = tf.compat.v1.Session()
inpainting_result=infer(images,mask)
saver_pre=tf.compat.v1.train.Saver()
init_op = tf.group(tf.compat.v1.initialize_all_variables(),tf.compat.v1.initialize_local_variables())

# %% [markdown]
# ### Inpainting Validation Data

# %%
psnr_values_validation = []
ssim_values_validation = []

# %%
import random
import gc
import os
import cv2
import glob
import socket
import tensorflow as tf
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

corrupted_image_folder = "DL_Milestone_2/train_val/validation_paired/Earthquake"
actual_images_folder = "DL_Milestone_2/train_val/validation/Earthquake"

corrupted_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', corrupted_image_folder)) if f.endswith('.png')]
actual_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', actual_images_folder)) if f.endswith('.png')]
common_files = set(corrupted_image_files) & set(actual_image_files)

for file_name in common_files:
  test_data_path = os.path.join('/content/drive/MyDrive', corrupted_image_folder, file_name)
  corrupted_image = cv2.imread(test_data_path)

  difference_image_gray = cv2.cvtColor(corrupted_image, cv2.COLOR_BGR2GRAY)

  mask_test = 255-cv2.threshold(difference_image_gray, 1, 255, cv2.THRESH_BINARY)[1]
  mask_test = mask_test.reshape((256,256,1))

  cv2.imwrite('/content/mask.png', mask_test)

  mask_path = "/content/mask.png"
  model_path = "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint"
  file_out = "DL_Milestone_2/validation_inpainted/Earthquake"
  file_out_2 = "DL_Milestone_2/validation_inpainted_2/Earthquake"
  width = 256
  height = 256
  file_test=test_data_path
  file_mask=mask_path
  sess.run(init_op)
  saver_pre.restore(sess, model_path)

  test_mask = cv2.resize(cv2.imread(file_mask),(height,width))
  test_mask = test_mask[:,:,0:1]
  test_mask = 0. + test_mask//255
  test_mask[test_mask >= 0.5] = 1
  test_mask[test_mask <  0.5] = 0
  test_mask  = 1-test_mask
  test_image = cv2.imread(file_test)[...,::-1]
  test_image = cv2.resize(test_image, (height, width))
  test_mask = np.expand_dims(test_mask,0)
  test_image = np.expand_dims(test_image,0)
  img_out=sess.run(inpainting_result,feed_dict={mask:test_mask,images:test_image})

  out_address = os.path.join('/content/drive/MyDrive', file_out, file_name)
  out_address_2 = os.path.join('/content/drive/MyDrive', file_out_2, file_name)
  cv2.imwrite(out_address, img_out[0][...,::-1])
  cv2.imwrite(out_address_2, test_image[0][...,::-1] * test_mask[0] + 255 * (1 - test_mask[0]))

  actual_image_path = os.path.join('/content/drive/MyDrive', actual_images_folder, file_name)
  new_image_path = out_address
  actual_image = cv2.imread(actual_image_path)
  actual_image = cv2.resize(actual_image, (256, 256), interpolation = cv2.INTER_LINEAR)
  actual_image = actual_image.reshape((256,256,3))
  new_image = cv2.imread(new_image_path)
  cv2.imwrite('/content/image.png', actual_image)
  psnr = calculate_psnr('/content/image.png', new_image_path)
  print(f'PSNR: {psnr} dB')
  psnr_values_validation.append(psnr)
  ssim_value = calculate_ssim('/content/image.png', new_image_path)
  print(f'SSIM: {ssim_value:.5f}')
  ssim_values_validation.append(ssim_value)
# Out:
# PSNR: 48.57806277260116 dB
# SSIM: 0.99092
# PSNR: 41.253359843102274 dB
# SSIM: 0.95738
# PSNR: 43.295992508919134 dB
# SSIM: 0.96340
# PSNR: 41.677837291795555 dB
# SSIM: 0.94900
# PSNR: 35.27581815821285 dB
# SSIM: 0.94415
# PSNR: 45.079741869049045 dB
# SSIM: 0.98808
# PSNR: 42.34671617465881 dB
# SSIM: 0.96727
# PSNR: 45.315237333233725 dB
# SSIM: 0.97931
# PSNR: 44.131075943551906 dB
# SSIM: 0.97587
# PSNR: 34.7204791788134 dB
# SSIM: 0.93350
# PSNR: 33.954348764985525 dB
# SSIM: 0.97526
# PSNR: 32.79490034208541 dB
# SSIM: 0.92267
# PSNR: 41.806247781661305 dB
# SSIM: 0.95992
# PSNR: 44.61969270059725 dB
# SSIM: 0.98390
# PSNR: 39.700262866388954 dB
# SSIM: 0.92934
# PSNR: 40.58006342970976 dB
# SSIM: 0.93871
# PSNR: 40.69635720773302 dB
# SSIM: 0.94619
# PSNR: 42.376523488236415 dB
# SSIM: 0.96065
# PSNR: 35.82984362917086 dB
# SSIM: 0.93845
# PSNR: 34.9577875693251 dB
# SSIM: 0.91089
# PSNR: 33.024866886194225 dB
# SSIM: 0.92464
# PSNR: 33.91313404964923 dB
# SSIM: 0.92084
# PSNR: 37.22828136264906 dB
# SSIM: 0.91896
# PSNR: 44.2249800062951 dB
# SSIM: 0.97801
# PSNR: 33.49995926653324 dB
# SSIM: 0.93564
# PSNR: 43.93327108980422 dB
# SSIM: 0.97682
# PSNR: 32.85714537611785 dB
# SSIM: 0.96272
# PSNR: 41.78333325560368 dB
# SSIM: 0.94086
# PSNR: 41.289373695657574 dB
# SSIM: 0.94488
# PSNR: 35.06399172306365 dB
# SSIM: 0.94970
# PSNR: 38.535728662536506 dB
# SSIM: 0.98617
# PSNR: 41.798346025727355 dB
# SSIM: 0.95333
# PSNR: 41.50547226487195 dB
# SSIM: 0.95157
# PSNR: 41.13164637025014 dB
# SSIM: 0.95107
# PSNR: 47.775868634243594 dB
# SSIM: 0.98785
# PSNR: 41.379245649253704 dB
# SSIM: 0.93920
# PSNR: 34.68062020451407 dB
# SSIM: 0.96481
# PSNR: 34.45167292271557 dB
# SSIM: 0.95177
# PSNR: 43.04932184809581 dB
# SSIM: 0.97153
# PSNR: 37.00482122547959 dB
# SSIM: 0.93021
# PSNR: 44.24327047740162 dB
# SSIM: 0.97984
# PSNR: 47.724027544639085 dB
# SSIM: 0.99282
# PSNR: 49.656866875180256 dB
# SSIM: 0.99658
# PSNR: 56.10416295741226 dB
# SSIM: 0.99972
# PSNR: 40.46149524707321 dB
# SSIM: 0.92998
# PSNR: 42.712922322894286 dB
# SSIM: 0.96876
# PSNR: 41.29114315084948 dB
# SSIM: 0.95189
# PSNR: 49.27687342526562 dB
# SSIM: 0.99068
# PSNR: 45.406532024113524 dB
# SSIM: 0.97605
# PSNR: 42.57002370559084 dB
# SSIM: 0.95370
# PSNR: 41.69510827310992 dB
# SSIM: 0.95898
# PSNR: 47.35212839609096 dB
# SSIM: 0.98884
# PSNR: 45.07891039448157 dB
# SSIM: 0.98521
# PSNR: 32.5367522857512 dB
# SSIM: 0.96260
# PSNR: 34.7765747807168 dB
# SSIM: 0.95788
# PSNR: 39.54443362679132 dB
# SSIM: 0.94119
# PSNR: 40.59701631809282 dB
# SSIM: 0.93729
# PSNR: 40.050286254195655 dB
# SSIM: 0.93392
# PSNR: 44.40813621682586 dB
# SSIM: 0.97623
# PSNR: 45.215683913366924 dB
# SSIM: 0.97448
# PSNR: 37.241845221688614 dB
# SSIM: 0.95448
# PSNR: 41.91321817809096 dB
# SSIM: 0.96758
# PSNR: 34.76212379575572 dB
# SSIM: 0.93335
# PSNR: 45.69617142413826 dB
# SSIM: 0.98283
# PSNR: 34.53844714841391 dB
# SSIM: 0.90499
# PSNR: 38.834250134315596 dB
# SSIM: 0.92196
# PSNR: 42.22874235321881 dB
# SSIM: 0.96726
# PSNR: 40.373750186011506 dB
# SSIM: 0.94310
# PSNR: 41.210817482185234 dB
# SSIM: 0.94912
# PSNR: 42.90518492579089 dB
# SSIM: 0.97117
# PSNR: 34.37962580696353 dB
# SSIM: 0.89966
# PSNR: 34.64595293961156 dB
# SSIM: 0.96492
# PSNR: 33.62676075107715 dB
# SSIM: 0.95697
# PSNR: 32.8836563492507 dB
# SSIM: 0.91568
# PSNR: 37.18462369039341 dB
# SSIM: 0.96939
# PSNR: 35.00105114893904 dB
# SSIM: 0.94533
# PSNR: 34.72418352349211 dB
# SSIM: 0.93384
# PSNR: 43.69439590815667 dB
# SSIM: 0.97836
# PSNR: 42.01298036694047 dB
# SSIM: 0.96498
# PSNR: 33.04695805233685 dB
# SSIM: 0.91813
# PSNR: 42.075694008259596 dB
# SSIM: 0.96162
# PSNR: 42.44614003333532 dB
# SSIM: 0.96228
# PSNR: 32.52092242435178 dB
# SSIM: 0.93044
# PSNR: 43.446177302891805 dB
# SSIM: 0.96927
# PSNR: 34.14624562807026 dB
# SSIM: 0.92340
# PSNR: 42.52804544102739 dB
# SSIM: 0.95745
# PSNR: 36.82526409100975 dB
# SSIM: 0.95757
# PSNR: 35.33080385023907 dB
# SSIM: 0.84372
# PSNR: 33.43966005270567 dB
# SSIM: 0.94384
# PSNR: 38.45524348766699 dB
# SSIM: 0.90536
# PSNR: 42.83791986480107 dB
# SSIM: 0.97010
# PSNR: 44.165705607846704 dB
# SSIM: 0.98301
# PSNR: 41.48523002495728 dB
# SSIM: 0.93870
# PSNR: 33.59652303453817 dB
# SSIM: 0.93897
# PSNR: 41.89983408578868 dB
# SSIM: 0.96238
# PSNR: 38.12262058823569 dB
# SSIM: 0.94869
# PSNR: 46.44806514002013 dB
# SSIM: 0.98998
# PSNR: 46.58436039220333 dB
# SSIM: 0.98992
# PSNR: 34.688505193265954 dB
# SSIM: 0.96066
# PSNR: 42.1842227977968 dB
# SSIM: 0.95229
# PSNR: 42.83333841670061 dB
# SSIM: 0.95618
# PSNR: 43.8810595883444 dB
# SSIM: 0.97280
# PSNR: 44.40256237512271 dB
# SSIM: 0.97368
# PSNR: 43.76144740502963 dB
# SSIM: 0.97236
# PSNR: 32.56689695689642 dB
# SSIM: 0.94603
# PSNR: 36.622980389814764 dB
# SSIM: 0.95900
# PSNR: 43.180939367254815 dB
# SSIM: 0.97253
# PSNR: 36.06628216456811 dB
# SSIM: 0.86448
# PSNR: 46.232226311170585 dB
# SSIM: 0.98301
# PSNR: 47.52453980669497 dB
# SSIM: 0.98767
# PSNR: 34.88320869987335 dB
# SSIM: 0.91061
# PSNR: 41.60444516632053 dB
# SSIM: 0.95274
# PSNR: 48.98907193244942 dB
# SSIM: 0.99129
# PSNR: 34.82787393892437 dB
# SSIM: 0.90984
# PSNR: 41.48384341462143 dB
# SSIM: 0.94425
# PSNR: 32.42965797607183 dB
# SSIM: 0.92940
# PSNR: 40.70934508736124 dB
# SSIM: 0.94690
# PSNR: 43.84313381332561 dB
# SSIM: 0.96787
# PSNR: 42.60635917490295 dB
# SSIM: 0.96530
# PSNR: 41.77001100694174 dB
# SSIM: 0.95640
# PSNR: 45.65386933280077 dB
# SSIM: 0.98008
# PSNR: 34.872488468553314 dB
# SSIM: 0.95494
# PSNR: 44.973924241678844 dB
# SSIM: 0.97651
# PSNR: 39.47911189840313 dB
# SSIM: 0.92240
# PSNR: 46.242052951802116 dB
# SSIM: 0.97761
# PSNR: 43.19927285548961 dB
# SSIM: 0.97616
# PSNR: 50.918293230799904 dB
# SSIM: 0.99780
# PSNR: 43.04696421887451 dB
# SSIM: 0.96686
# PSNR: 44.52475153632073 dB
# SSIM: 0.96312
# PSNR: 44.18161171758847 dB
# SSIM: 0.98113
# PSNR: 38.69596723730298 dB
# SSIM: 0.93309
# PSNR: 34.065992626615056 dB
# SSIM: 0.93261
# PSNR: 41.74461532334153 dB
# SSIM: 0.95029
# PSNR: 45.17061419116297 dB
# SSIM: 0.98137
# PSNR: 48.93296621294884 dB
# SSIM: 0.99194
# PSNR: 43.01762855971567 dB
# SSIM: 0.96173
# PSNR: 38.56299607333933 dB
# SSIM: 0.92216
# PSNR: 42.68567601472697 dB
# SSIM: 0.95025
# PSNR: 36.64830940558251 dB
# SSIM: 0.92273
# PSNR: 41.602140516813634 dB
# SSIM: 0.95398
# PSNR: 42.72358140478937 dB
# SSIM: 0.96609
# PSNR: 41.90776998531149 dB
# SSIM: 0.95396
# PSNR: 47.44999030243313 dB
# SSIM: 0.99293
# PSNR: 45.861914630752054 dB
# SSIM: 0.98644
# PSNR: 41.32714098677596 dB
# SSIM: 0.95346
# PSNR: 44.76002524293091 dB
# SSIM: 0.97447
# PSNR: 32.53044042584539 dB
# SSIM: 0.92526
# PSNR: 41.87261908297028 dB
# SSIM: 0.95281
# PSNR: 42.37898437808951 dB
# SSIM: 0.96995
# PSNR: 46.93118602299407 dB
# SSIM: 0.98720
# PSNR: 76.08370992421672 dB
# SSIM: 0.99979
# PSNR: 42.630595106865556 dB
# SSIM: 0.96605
# PSNR: 45.89180825093023 dB
# SSIM: 0.98582
# PSNR: 41.73258546802681 dB
# SSIM: 0.95017
# PSNR: 41.02803723220902 dB
# SSIM: 0.95266
# PSNR: 41.06622920413368 dB
# SSIM: 0.94832
# PSNR: 43.29552088937796 dB
# SSIM: 0.96860
# PSNR: 45.3044388611055 dB
# SSIM: 0.97523
# PSNR: 41.193639291108504 dB
# SSIM: 0.95716
# PSNR: 38.66868726627138 dB
# SSIM: 0.92543
# PSNR: 45.12114429071748 dB
# SSIM: 0.97661
# PSNR: 42.455308220633086 dB
# SSIM: 0.96723
# PSNR: 42.699941931896 dB
# SSIM: 0.96729
# PSNR: 44.79749176089024 dB
# SSIM: 0.98569
# PSNR: 50.70543904884893 dB
# SSIM: 0.99637
# PSNR: 44.49555867476189 dB
# SSIM: 0.97357
# PSNR: 44.523990917655624 dB
# SSIM: 0.97206
# PSNR: 37.8269908410331 dB
# SSIM: 0.91142
# PSNR: 33.8156085374622 dB
# SSIM: 0.88234
# PSNR: 43.07911468945669 dB
# SSIM: 0.96678
# PSNR: 37.891664363173234 dB
# SSIM: 0.95771
# PSNR: 32.16673722869749 dB
# SSIM: 0.90552
# PSNR: 42.928751299304906 dB
# SSIM: 0.97150
# PSNR: 42.464855322185514 dB
# SSIM: 0.97059
# PSNR: 44.3455596823585 dB
# SSIM: 0.97135
# PSNR: 33.92878457182431 dB
# SSIM: 0.90717
# PSNR: 38.264971330120446 dB
# SSIM: 0.90756
# PSNR: 34.57056897506262 dB
# SSIM: 0.92863
# PSNR: 40.856643445728594 dB
# SSIM: 0.94950
# PSNR: 43.21525463746092 dB
# SSIM: 0.96519
# PSNR: 38.85522221429613 dB
# SSIM: 0.93763
# PSNR: 37.5171938585421 dB
# SSIM: 0.91386
# PSNR: 34.767115999191006 dB
# SSIM: 0.93176
# PSNR: 50.16180130777688 dB
# SSIM: 0.99395
# PSNR: 43.26314541525696 dB
# SSIM: 0.97439
# PSNR: 33.34190629657459 dB
# SSIM: 0.96524
# PSNR: 35.12377300306551 dB
# SSIM: 0.92731
# PSNR: 37.910318997942426 dB
# SSIM: 0.94643
# PSNR: 40.944932963596166 dB
# SSIM: 0.95189
# PSNR: 43.72831323579472 dB
# SSIM: 0.96766
# PSNR: 48.431425242895884 dB
# SSIM: 0.99178
# PSNR: 43.38696487207002 dB
# SSIM: 0.97391
# PSNR: 40.93019524055177 dB
# SSIM: 0.94631
# PSNR: 46.53516153685415 dB
# SSIM: 0.98656
# PSNR: 48.1808359385181 dB
# SSIM: 0.98944
# PSNR: 42.92828458340231 dB
# SSIM: 0.97537
# PSNR: 42.28992947202333 dB
# SSIM: 0.96146
# PSNR: 47.49667693656129 dB
# SSIM: 0.99143
# PSNR: 40.76087490752695 dB
# SSIM: 0.94580
# PSNR: 31.05576501224327 dB
# SSIM: 0.90534
# PSNR: 41.935063642469885 dB
# SSIM: 0.96019
# PSNR: 35.555847390718334 dB
# SSIM: 0.91440
# PSNR: 32.660237086578164 dB
# SSIM: 0.94649
# PSNR: 45.28463083722058 dB
# SSIM: 0.98364
# PSNR: 44.89327828992296 dB
# SSIM: 0.97800
# PSNR: 43.60538735948323 dB
# SSIM: 0.97436
# PSNR: 33.89192536350214 dB
# SSIM: 0.92366
# PSNR: 36.44050888703867 dB
# SSIM: 0.97938
# PSNR: 34.15823981326179 dB
# SSIM: 0.93753
# PSNR: 42.83897127744932 dB
# SSIM: 0.95891
# PSNR: 33.97656368968644 dB
# SSIM: 0.95327
# PSNR: 41.750538558514016 dB
# SSIM: 0.96127
# PSNR: 45.41407658554493 dB
# SSIM: 0.97650
# PSNR: 39.541498204543736 dB
# SSIM: 0.95174
# PSNR: 42.33828629545304 dB
# SSIM: 0.96560
# PSNR: 43.7391879287872 dB
# SSIM: 0.96971
# PSNR: 42.08795055195239 dB
# SSIM: 0.95939
# PSNR: 41.529880423289924 dB
# SSIM: 0.95796
# PSNR: 35.702864997977436 dB
# SSIM: 0.92005
# PSNR: 43.67732216282285 dB
# SSIM: 0.97122
# PSNR: 35.18284892609499 dB
# SSIM: 0.93684
# PSNR: 42.28852531612392 dB
# SSIM: 0.96186
# PSNR: 44.58092249242668 dB
# SSIM: 0.97574
# PSNR: 42.472274040476556 dB
# SSIM: 0.95567
# PSNR: 43.465102118901946 dB
# SSIM: 0.96160
# PSNR: 40.411473918491374 dB
# SSIM: 0.94135
# PSNR: 42.22597376487802 dB
# SSIM: 0.96451
# PSNR: 44.18595582891424 dB
# SSIM: 0.98452
# PSNR: 43.668838068406984 dB
# SSIM: 0.97185
# PSNR: 39.94065486393177 dB
# SSIM: 0.93532
# PSNR: 47.66116480345761 dB
# SSIM: 0.99146
# PSNR: 39.34921169196174 dB
# SSIM: 0.92637
# PSNR: 38.71622239145387 dB
# SSIM: 0.95509
# PSNR: 41.622704398435324 dB
# SSIM: 0.95018
# PSNR: 38.75549786784451 dB
# SSIM: 0.91917
# PSNR: 45.821101836676014 dB
# SSIM: 0.98402
# PSNR: 46.37210051603777 dB
# SSIM: 0.98151
# PSNR: 48.49329414714845 dB
# SSIM: 0.99012
# PSNR: 41.05759216232481 dB
# SSIM: 0.95328
# PSNR: 43.178036057654836 dB
# SSIM: 0.96882
# PSNR: 44.05129966226926 dB
# SSIM: 0.96978
# PSNR: 33.24420028997028 dB
# SSIM: 0.95838
# PSNR: 43.846105971701746 dB
# SSIM: 0.97583
# PSNR: 44.058065674056415 dB
# SSIM: 0.97665
# PSNR: 46.71037817124989 dB
# SSIM: 0.97858
# PSNR: 42.086357550522315 dB
# SSIM: 0.95397
# PSNR: 43.336590782537066 dB
# SSIM: 0.97219
# PSNR: 45.2078786613562 dB
# SSIM: 0.97801
# PSNR: 47.251134464953644 dB
# SSIM: 0.98546
# PSNR: 34.12626187384325 dB
# SSIM: 0.93585
# PSNR: 35.193543213597174 dB
# SSIM: 0.92177
# PSNR: 44.00384610505215 dB
# SSIM: 0.96539
# PSNR: 41.07140403503475 dB
# SSIM: 0.94438
# PSNR: 44.820199953642366 dB
# SSIM: 0.98286
# PSNR: 44.137086733728495 dB
# SSIM: 0.97696
# PSNR: 39.917417967729854 dB
# SSIM: 0.94748
# PSNR: 44.11834262686924 dB
# SSIM: 0.97090
# PSNR: 43.18622823511157 dB
# SSIM: 0.96528
# PSNR: 39.44018284727019 dB
# SSIM: 0.96162
# PSNR: 42.670426322701886 dB
# SSIM: 0.96181
# PSNR: 43.418615508140334 dB
# SSIM: 0.97806
# PSNR: 46.507515448911136 dB
# SSIM: 0.98426
# PSNR: 40.80893717717916 dB
# SSIM: 0.94834
# PSNR: 34.598298356868 dB
# SSIM: 0.97955
# PSNR: 37.013811283851446 dB
# SSIM: 0.87942
# PSNR: 33.58147772334345 dB
# SSIM: 0.93366
# PSNR: 35.17799118576726 dB
# SSIM: 0.96536
# PSNR: 35.40712071314932 dB
# SSIM: 0.92547
# PSNR: 41.09446798127492 dB
# SSIM: 0.93249
# PSNR: 45.47583245333052 dB
# SSIM: 0.98201
# PSNR: 36.82455110663257 dB
# SSIM: 0.91810
# PSNR: 35.059185558192894 dB
# SSIM: 0.91255
# PSNR: 46.5301010318025 dB
# SSIM: 0.98437
# PSNR: 33.43204210612872 dB
# SSIM: 0.93899
# PSNR: 42.21784273741647 dB
# SSIM: 0.95577
# PSNR: 39.30810964809269 dB
# SSIM: 0.92104
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 44.65781917109122 dB
# SSIM: 0.98374
# PSNR: 46.30300670494396 dB
# SSIM: 0.98295
# PSNR: 40.179906241909876 dB
# SSIM: 0.93845
# PSNR: 31.988215029939127 dB
# SSIM: 0.95180
# PSNR: 34.20672865717164 dB
# SSIM: 0.94200
# PSNR: 46.564663203433774 dB
# SSIM: 0.98601
# PSNR: 31.982436588837682 dB
# SSIM: 0.93868
# PSNR: 51.28418836203827 dB
# SSIM: 0.99984
# PSNR: 41.23664961885968 dB
# SSIM: 0.94324
# PSNR: 35.021947786421215 dB
# SSIM: 0.92045
# PSNR: 37.65513021885567 dB
# SSIM: 0.95120
# PSNR: 44.16344564914233 dB
# SSIM: 0.97205
# PSNR: 44.096441028421296 dB
# SSIM: 0.97634
# PSNR: 44.73628393865357 dB
# SSIM: 0.97227
# PSNR: 45.20649277874173 dB
# SSIM: 0.98041
# PSNR: 41.02802862353916 dB
# SSIM: 0.98209
# PSNR: 32.73162222996848 dB
# SSIM: 0.94534
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 45.43353558804746 dB
# SSIM: 0.98670
# PSNR: 44.719393465515765 dB
# SSIM: 0.97407
# PSNR: 45.99243985503024 dB
# SSIM: 0.98032
# PSNR: 61.53792281300342 dB
# SSIM: 0.99966
# PSNR: 45.95959637248222 dB
# SSIM: 0.97537
# PSNR: 43.41291684861303 dB
# SSIM: 0.96903
# PSNR: 39.45337206182322 dB
# SSIM: 0.93638
# PSNR: 42.82946557812541 dB
# SSIM: 0.96401
# PSNR: 36.63630201715387 dB
# SSIM: 0.94902
# PSNR: 46.14615745636993 dB
# SSIM: 0.98576
# PSNR: 34.32629239747299 dB
# SSIM: 0.96496
# PSNR: 48.13902863416288 dB
# SSIM: 0.99515
# PSNR: 57.28410863114914 dB
# SSIM: 0.99943
# PSNR: 34.689664223248144 dB
# SSIM: 0.96908
# PSNR: 40.75176134013289 dB
# SSIM: 0.94512
# PSNR: 40.752997464394085 dB
# SSIM: 0.95229
# PSNR: 47.35780041343503 dB
# SSIM: 0.99040
# PSNR: 32.645442966479415 dB
# SSIM: 0.91856
# PSNR: 42.53919840520777 dB
# SSIM: 0.95695
# PSNR: 33.51983545446868 dB
# SSIM: 0.94677
# PSNR: 34.7115306534745 dB
# SSIM: 0.90884
# PSNR: 43.21219307166595 dB
# SSIM: 0.97599
# PSNR: 33.18343592846692 dB
# SSIM: 0.91439
# PSNR: 40.92254680678111 dB
# SSIM: 0.94306
# PSNR: 34.765418046791964 dB
# SSIM: 0.89736
# PSNR: 42.31623757189325 dB
# SSIM: 0.96417
# PSNR: 44.12699721889985 dB
# SSIM: 0.97787
# PSNR: 46.00842672067842 dB
# SSIM: 0.98356
# PSNR: 41.66506854013649 dB
# SSIM: 0.95652
# PSNR: 40.390089748304945 dB
# SSIM: 0.94800
# PSNR: 35.459783687987915 dB
# SSIM: 0.90706
# PSNR: 40.16707235636006 dB
# SSIM: 0.93646
# PSNR: 41.18738797003626 dB
# SSIM: 0.95129
# PSNR: 32.99189137916414 dB
# SSIM: 0.92465
# PSNR: 32.12535633990739 dB
# SSIM: 0.97043
# PSNR: 43.52792980163607 dB
# SSIM: 0.94994
# PSNR: 45.88781316202003 dB
# SSIM: 0.98293
# PSNR: 42.916327106662244 dB
# SSIM: 0.96978
# PSNR: 44.70013149250947 dB
# SSIM: 0.98128
# PSNR: 43.91486575140676 dB
# SSIM: 0.97127
# PSNR: 45.024252448133154 dB
# SSIM: 0.98201
# PSNR: 42.60093333524271 dB
# SSIM: 0.96223
# PSNR: 37.865387926534325 dB
# SSIM: 0.92688
# PSNR: 45.59563084142837 dB
# SSIM: 0.97538
# PSNR: 42.476009184028534 dB
# SSIM: 0.96952
# PSNR: 34.18472425934857 dB
# SSIM: 0.93470
# PSNR: 47.06029601847334 dB
# SSIM: 0.98586
# PSNR: 40.981265093584454 dB
# SSIM: 0.95047
# PSNR: 36.33646185170771 dB
# SSIM: 0.92513
# PSNR: 44.23208531700595 dB
# SSIM: 0.96335
# PSNR: 44.45514632132176 dB
# SSIM: 0.97449
# PSNR: 45.677196844007604 dB
# SSIM: 0.98405
# PSNR: 31.842512181551143 dB
# SSIM: 0.96480
# PSNR: 70.93001848920079 dB
# SSIM: 0.99999
# PSNR: 46.38354896981142 dB
# SSIM: 0.98307
# PSNR: 40.36692840825114 dB
# SSIM: 0.94689
# PSNR: 50.2635816118515 dB
# SSIM: 0.99486
# PSNR: 44.41295703247646 dB
# SSIM: 0.97956
# PSNR: 39.19772652526186 dB
# SSIM: 0.92133
# PSNR: 43.3340646587632 dB
# SSIM: 0.97610
# PSNR: 41.0343993990398 dB
# SSIM: 0.95881
# PSNR: 33.102705550896744 dB
# SSIM: 0.89973
# PSNR: 42.69583860164091 dB
# SSIM: 0.95614
# PSNR: 44.06924445365975 dB
# SSIM: 0.97713
# PSNR: 32.31569386488759 dB
# SSIM: 0.93300
# PSNR: 42.382569552469874 dB
# SSIM: 0.95589
# PSNR: 46.6328711653209 dB
# SSIM: 0.98149
# PSNR: 41.50556835633189 dB
# SSIM: 0.94476
# PSNR: 32.132888416339945 dB
# SSIM: 0.95780
# PSNR: 45.088120194689544 dB
# SSIM: 0.97356
# PSNR: 35.64489231833525 dB
# SSIM: 0.96075
# PSNR: 39.475615094141844 dB
# SSIM: 0.93158
# PSNR: 46.1573192709391 dB
# SSIM: 0.98375
# PSNR: 45.96768330834085 dB
# SSIM: 0.98547
# PSNR: 32.23787360730928 dB
# SSIM: 0.95434
# PSNR: 39.382789460667695 dB
# SSIM: 0.92985
# PSNR: 41.726186177410646 dB
# SSIM: 0.95135
# PSNR: 49.02966188724469 dB
# SSIM: 0.99432
# PSNR: 42.382510755251516 dB
# SSIM: 0.96178
# PSNR: 43.22318201103228 dB
# SSIM: 0.97323
# PSNR: 51.960037914685664 dB
# SSIM: 0.99991
# PSNR: 41.87297462534032 dB
# SSIM: 0.94492
# PSNR: 46.52005865422227 dB
# SSIM: 0.98927
# PSNR: 40.81669543687254 dB
# SSIM: 0.93417
# PSNR: 34.019170998921176 dB
# SSIM: 0.93037
# PSNR: 34.23741833417004 dB
# SSIM: 0.93975
# PSNR: 34.871131527257134 dB
# SSIM: 0.94495
# PSNR: 47.26481161997433 dB
# SSIM: 0.99239
# PSNR: 45.45134165998619 dB
# SSIM: 0.98030
# PSNR: 45.22853897655508 dB
# SSIM: 0.97579
# PSNR: 46.12823542946535 dB
# SSIM: 0.98618

# %%
for i in range(len(psnr_values_validation)):
  if(psnr_values_validation[i]==inf):
    print(i)
    psnr_values_validation[i] = 72.0
# Out:
# 1174
# 1192

# %%
average_psnr = np.mean(psnr_values_validation)
print(f"Average PSNR: {average_psnr}")

average_ssim = np.mean(ssim_values_validation)
print(f"Average SSIM: {average_ssim}")
# Out:
# Average PSNR: 41.393762732390925
# Average SSIM: 0.9482967585106814

# %% [markdown]
# ### Inpainting Train Data

# %%
psnr_values_train = []
ssim_values_train = []

# %%
import random
import gc
import os
import cv2
import glob
import socket
import tensorflow as tf
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

corrupted_image_folder = "DL_Milestone_2/train_val/train_paired/Earthquake"
actual_images_folder = "DL_Milestone_2/train_val/train/Earthquake"

corrupted_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', corrupted_image_folder)) if f.endswith('.png')]
actual_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', actual_images_folder)) if f.endswith('.png')]
common_files = set(corrupted_image_files) & set(actual_image_files)

for file_name in common_files:
  test_data_path = os.path.join('/content/drive/MyDrive', corrupted_image_folder, file_name)
  corrupted_image = cv2.imread(test_data_path)

  difference_image_gray = cv2.cvtColor(corrupted_image, cv2.COLOR_BGR2GRAY)

  mask_test = 255-cv2.threshold(difference_image_gray, 1, 255, cv2.THRESH_BINARY)[1]
  mask_test = mask_test.reshape((256,256,1))

  cv2.imwrite('/content/mask.png', mask_test)

  mask_path = "/content/mask.png"
  model_path = "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint"
  file_out = "DL_Milestone_2/train_inpainted/Earthquake"
  file_out_2 = "DL_Milestone_2/train_inpainted_2/Earthquake"
  width = 256
  height = 256
  file_test=test_data_path
  file_mask=mask_path
  sess.run(init_op)
  saver_pre.restore(sess, model_path)

  test_mask = cv2.resize(cv2.imread(file_mask),(height,width))
  test_mask = test_mask[:,:,0:1]
  test_mask = 0. + test_mask//255
  test_mask[test_mask >= 0.5] = 1
  test_mask[test_mask <  0.5] = 0
  test_mask  = 1-test_mask
  test_image = cv2.imread(file_test)[...,::-1]
  test_image = cv2.resize(test_image, (height, width))
  test_mask = np.expand_dims(test_mask,0)
  test_image = np.expand_dims(test_image,0)
  img_out=sess.run(inpainting_result,feed_dict={mask:test_mask,images:test_image})

  out_address = os.path.join('/content/drive/MyDrive', file_out, file_name)
  out_address_2 = os.path.join('/content/drive/MyDrive', file_out_2, file_name)
  cv2.imwrite(out_address, img_out[0][...,::-1])
  cv2.imwrite(out_address_2, test_image[0][...,::-1] * test_mask[0] + 255 * (1 - test_mask[0]))

  actual_image_path = os.path.join('/content/drive/MyDrive', actual_images_folder, file_name)
  new_image_path = out_address
  actual_image = cv2.imread(actual_image_path)
  actual_image = cv2.resize(actual_image, (256, 256), interpolation = cv2.INTER_LINEAR)
  actual_image = actual_image.reshape((256,256,3))
  new_image = cv2.imread(new_image_path)
  cv2.imwrite('/content/image.png', actual_image)
  psnr = calculate_psnr('/content/image.png', new_image_path)
  print(f'PSNR: {psnr} dB')
  psnr_values_train.append(psnr)
  ssim_value = calculate_ssim('/content/image.png', new_image_path)
  print(f'SSIM: {ssim_value:.5f}')
  ssim_values_train.append(ssim_value)
# Out:
# PSNR: 41.96014460914989 dB
# SSIM: 0.96329
# PSNR: 45.095910645640885 dB
# SSIM: 0.97971
# PSNR: 34.30740786785699 dB
# SSIM: 0.91574
# PSNR: 34.587179488120306 dB
# SSIM: 0.91183
# PSNR: 53.07237605617598 dB
# SSIM: 1.00000
# PSNR: 37.97298187777473 dB
# SSIM: 0.91621
# PSNR: 41.6206811188771 dB
# SSIM: 0.95440
# PSNR: 44.19535325125082 dB
# SSIM: 0.97675
# PSNR: 33.81692462708794 dB
# SSIM: 0.98067
# PSNR: 43.758839332782415 dB
# SSIM: 0.97717
# PSNR: 41.142102119162104 dB
# SSIM: 0.93461
# PSNR: 44.69410019424899 dB
# SSIM: 0.97834
# PSNR: 34.4337986532374 dB
# SSIM: 0.94752
# PSNR: 38.4933373693462 dB
# SSIM: 0.94459
# PSNR: 55.94731375835772 dB
# SSIM: 0.99795
# PSNR: 33.450227080288656 dB
# SSIM: 0.94656
# PSNR: 45.61473425524746 dB
# SSIM: 0.98579
# PSNR: 36.47860652317912 dB
# SSIM: 0.94731
# PSNR: 42.40761296747004 dB
# SSIM: 0.96207
# PSNR: 44.69812680967337 dB
# SSIM: 0.97306
# PSNR: 37.38374016537528 dB
# SSIM: 0.95319
# PSNR: 44.54293042979694 dB
# SSIM: 0.97860
# PSNR: 42.00680166398623 dB
# SSIM: 0.95992
# PSNR: 37.92237476929444 dB
# SSIM: 0.96134
# PSNR: 46.207472824395204 dB
# SSIM: 0.98647
# PSNR: 32.85695386650486 dB
# SSIM: 0.94527
# PSNR: 39.93887252307048 dB
# SSIM: 0.93805
# PSNR: 32.4470249495736 dB
# SSIM: 0.93741
# PSNR: 46.26519320408852 dB
# SSIM: 0.98697
# PSNR: 45.49766639659832 dB
# SSIM: 0.98486
# PSNR: 47.84083959660628 dB
# SSIM: 0.98962
# PSNR: 33.97133539181087 dB
# SSIM: 0.95580
# PSNR: 43.377520401501286 dB
# SSIM: 0.96604
# PSNR: 34.85735355995275 dB
# SSIM: 0.91011
# PSNR: 44.83332999846329 dB
# SSIM: 0.97824
# PSNR: 41.68511699078151 dB
# SSIM: 0.95205
# PSNR: 44.041312506187104 dB
# SSIM: 0.98201
# PSNR: 35.2212554215148 dB
# SSIM: 0.83512
# PSNR: 46.0212097956765 dB
# SSIM: 0.98383
# PSNR: 42.928537937240286 dB
# SSIM: 0.97157
# PSNR: 38.32910113684847 dB
# SSIM: 0.92348
# PSNR: 37.38600418692354 dB
# SSIM: 0.94847
# PSNR: 43.69975968144928 dB
# SSIM: 0.98170
# PSNR: 40.799326179476836 dB
# SSIM: 0.93183
# PSNR: 47.31530244640993 dB
# SSIM: 0.99030
# PSNR: 45.21317838774324 dB
# SSIM: 0.97874
# PSNR: 46.21576517099025 dB
# SSIM: 0.98656
# PSNR: 42.94350534432422 dB
# SSIM: 0.97069
# PSNR: 46.46401772919997 dB
# SSIM: 0.98453
# PSNR: 34.426441494213414 dB
# SSIM: 0.91183
# PSNR: 47.273415764027945 dB
# SSIM: 0.99023
# PSNR: 45.59624696334719 dB
# SSIM: 0.98021
# PSNR: 43.1224439097225 dB
# SSIM: 0.97182
# PSNR: 43.22615137036522 dB
# SSIM: 0.97074
# PSNR: 34.624386795553974 dB
# SSIM: 0.96053
# PSNR: 32.280921416071195 dB
# SSIM: 0.95615
# PSNR: 40.44813444177859 dB
# SSIM: 0.93630
# PSNR: 42.5320601305421 dB
# SSIM: 0.96241
# PSNR: 41.185263051600046 dB
# SSIM: 0.94836
# PSNR: 42.12492910039082 dB
# SSIM: 0.96040
# PSNR: 35.19447332277088 dB
# SSIM: 0.93580
# PSNR: 41.10405472658926 dB
# SSIM: 0.94933
# PSNR: 47.72330348920542 dB
# SSIM: 0.98778
# PSNR: 45.533556957307084 dB
# SSIM: 0.97758
# PSNR: 44.036310318133445 dB
# SSIM: 0.97637
# PSNR: 42.19824927009161 dB
# SSIM: 0.96124
# PSNR: 39.989341305355225 dB
# SSIM: 0.93920
# PSNR: 44.26851341318908 dB
# SSIM: 0.97732
# PSNR: 37.47145811517361 dB
# SSIM: 0.94726
# PSNR: 41.885594298323085 dB
# SSIM: 0.95759
# PSNR: 49.24766534126563 dB
# SSIM: 0.99644
# PSNR: 41.14714699916969 dB
# SSIM: 0.95357
# PSNR: 32.83949642603326 dB
# SSIM: 0.95455
# PSNR: 36.44070646452863 dB
# SSIM: 0.96486
# PSNR: 39.52148024185966 dB
# SSIM: 0.92897
# PSNR: 32.834258234288484 dB
# SSIM: 0.97182
# PSNR: 41.42402111505901 dB
# SSIM: 0.94156
# PSNR: 48.29122754246275 dB
# SSIM: 0.99344
# PSNR: 33.375163228487004 dB
# SSIM: 0.92564
# PSNR: 44.5714808700899 dB
# SSIM: 0.97458
# PSNR: 34.50953946843963 dB
# SSIM: 0.93756
# PSNR: 42.31596542036804 dB
# SSIM: 0.96754
# PSNR: 35.567650184104885 dB
# SSIM: 0.93755
# PSNR: 40.44554399234825 dB
# SSIM: 0.95335
# PSNR: 37.625377364489204 dB
# SSIM: 0.94725
# PSNR: 32.73978457873062 dB
# SSIM: 0.94230
# PSNR: 46.89794842066557 dB
# SSIM: 0.98473
# PSNR: 43.89522180683865 dB
# SSIM: 0.97860
# PSNR: 42.00516807093358 dB
# SSIM: 0.94873
# PSNR: 48.021694765870365 dB
# SSIM: 0.99060
# PSNR: 44.508115765355704 dB
# SSIM: 0.98233
# PSNR: 45.38221669733286 dB
# SSIM: 0.98397
# PSNR: 33.62423542809584 dB
# SSIM: 0.94474
# PSNR: 46.7896504302021 dB
# SSIM: 0.98648
# PSNR: 39.35261985417151 dB
# SSIM: 0.97320
# PSNR: 47.62004421619181 dB
# SSIM: 0.98769
# PSNR: 42.81758176619945 dB
# SSIM: 0.97076
# PSNR: 41.09521106138723 dB
# SSIM: 0.95456
# PSNR: 35.98699720407251 dB
# SSIM: 0.92156
# PSNR: 45.96686454197873 dB
# SSIM: 0.98719
# PSNR: 46.70118196867537 dB
# SSIM: 0.98641
# PSNR: 41.99300823628106 dB
# SSIM: 0.95221
# PSNR: 44.37766597222878 dB
# SSIM: 0.96988
# PSNR: 40.92100949603372 dB
# SSIM: 0.94854
# PSNR: 43.574277045148584 dB
# SSIM: 0.97228
# PSNR: 43.5255194201972 dB
# SSIM: 0.97612
# PSNR: 45.25707558438589 dB
# SSIM: 0.98193
# PSNR: 44.78239482204245 dB
# SSIM: 0.97917
# PSNR: 45.88082071904458 dB
# SSIM: 0.98841
# PSNR: 42.30079825022593 dB
# SSIM: 0.95498
# PSNR: 46.5597220648182 dB
# SSIM: 0.99259
# PSNR: 43.70075517515855 dB
# SSIM: 0.96634
# PSNR: 32.405817919439606 dB
# SSIM: 0.92540
# PSNR: 34.79897665247329 dB
# SSIM: 0.92967
# PSNR: 38.827351902291966 dB
# SSIM: 0.92727
# PSNR: 41.517427937955546 dB
# SSIM: 0.95437
# PSNR: 43.03120649314134 dB
# SSIM: 0.96565
# PSNR: 47.588189928405185 dB
# SSIM: 0.98957
# PSNR: 35.19683993328363 dB
# SSIM: 0.96975
# PSNR: 41.93008067776646 dB
# SSIM: 0.94874
# PSNR: 37.58384278514189 dB
# SSIM: 0.93609
# PSNR: 41.14635959429977 dB
# SSIM: 0.94927
# PSNR: 46.0904708760399 dB
# SSIM: 0.98463
# PSNR: 42.03950543360755 dB
# SSIM: 0.96051
# PSNR: 40.413472417145215 dB
# SSIM: 0.93925
# PSNR: 46.818913496230536 dB
# SSIM: 0.98997
# PSNR: 44.0231479426065 dB
# SSIM: 0.97499
# PSNR: 33.89149923169125 dB
# SSIM: 0.93674
# PSNR: 47.53448342338964 dB
# SSIM: 0.99107
# PSNR: 40.961670400291965 dB
# SSIM: 0.94846
# PSNR: 42.440982109151655 dB
# SSIM: 0.96377
# PSNR: 44.9190240686398 dB
# SSIM: 0.98203
# PSNR: 40.82744634725877 dB
# SSIM: 0.94524
# PSNR: 44.553802670604796 dB
# SSIM: 0.97610
# PSNR: 38.887882421295494 dB
# SSIM: 0.95332
# PSNR: 43.47095281016383 dB
# SSIM: 0.97175
# PSNR: 42.84189175203637 dB
# SSIM: 0.96633
# PSNR: 48.689217199062256 dB
# SSIM: 0.99575
# PSNR: 45.630691295671724 dB
# SSIM: 0.97733
# PSNR: 44.91608329004904 dB
# SSIM: 0.98100
# PSNR: 37.55070549488045 dB
# SSIM: 0.96978
# PSNR: 34.58271472257686 dB
# SSIM: 0.92829
# PSNR: 33.93890048703154 dB
# SSIM: 0.95545
# PSNR: 42.89714156195511 dB
# SSIM: 0.97358
# PSNR: 41.41521253350469 dB
# SSIM: 0.98463
# PSNR: 44.398744442542196 dB
# SSIM: 0.97574
# PSNR: 34.186291610199525 dB
# SSIM: 0.92792
# PSNR: 40.345478682588976 dB
# SSIM: 0.94804
# PSNR: 41.20555016807364 dB
# SSIM: 0.94715
# PSNR: 43.37486691689292 dB
# SSIM: 0.97560
# PSNR: 50.47262033494501 dB
# SSIM: 0.98946
# PSNR: 45.25715536775148 dB
# SSIM: 0.97699
# PSNR: 43.534195396228846 dB
# SSIM: 0.97283
# PSNR: 42.37703434589573 dB
# SSIM: 0.96148
# PSNR: 40.10075298113555 dB
# SSIM: 0.93776
# PSNR: 35.57959317004931 dB
# SSIM: 0.94172
# PSNR: 46.557245914337 dB
# SSIM: 0.98328
# PSNR: 35.00758689729247 dB
# SSIM: 0.95833
# PSNR: 43.75577301635183 dB
# SSIM: 0.96089
# PSNR: 46.799816435751644 dB
# SSIM: 0.98758
# PSNR: 40.72554240866712 dB
# SSIM: 0.94265
# PSNR: 43.86074116733104 dB
# SSIM: 0.97999
# PSNR: 35.27604595576195 dB
# SSIM: 0.96223
# PSNR: 41.4988183003468 dB
# SSIM: 0.96042
# PSNR: 42.86853438182102 dB
# SSIM: 0.96310
# PSNR: 42.33826301506462 dB
# SSIM: 0.96211
# PSNR: 50.79213695943211 dB
# SSIM: 0.99740
# PSNR: 33.820856457732496 dB
# SSIM: 0.96237
# PSNR: 32.067435157535165 dB
# SSIM: 0.95473
# PSNR: 32.645852765948035 dB
# SSIM: 0.91298
# PSNR: 44.05482393164395 dB
# SSIM: 0.97588
# PSNR: 47.68304746979201 dB
# SSIM: 0.98574
# PSNR: 32.64223961753405 dB
# SSIM: 0.96188
# PSNR: 42.5552903143639 dB
# SSIM: 0.96530
# PSNR: 33.22714970235879 dB
# SSIM: 0.93968
# PSNR: 46.880720483502444 dB
# SSIM: 0.98563
# PSNR: 41.77840360803093 dB
# SSIM: 0.95425
# PSNR: 45.60377069727895 dB
# SSIM: 0.98301
# PSNR: 33.05431066947517 dB
# SSIM: 0.92591
# PSNR: 41.372190382366355 dB
# SSIM: 0.94411
# PSNR: 46.69151356566854 dB
# SSIM: 0.98554
# PSNR: 45.7829068616772 dB
# SSIM: 0.98747
# PSNR: 43.497701931521135 dB
# SSIM: 0.97420
# PSNR: 41.3214037955699 dB
# SSIM: 0.94204
# PSNR: 50.882848271084924 dB
# SSIM: 0.99751
# PSNR: 44.21452308738493 dB
# SSIM: 0.97590
# PSNR: 34.59798889708953 dB
# SSIM: 0.93511
# PSNR: 31.558275097707394 dB
# SSIM: 0.91200
# PSNR: 44.17902334077628 dB
# SSIM: 0.97505
# PSNR: 44.3225399815921 dB
# SSIM: 0.97631
# PSNR: 45.85203485476973 dB
# SSIM: 0.99020
# PSNR: 40.23142378383288 dB
# SSIM: 0.93769
# PSNR: 41.89078370768705 dB
# SSIM: 0.94606
# PSNR: 37.229569967536605 dB
# SSIM: 0.93651
# PSNR: 35.03211196038173 dB
# SSIM: 0.91092
# PSNR: 36.92727982197679 dB
# SSIM: 0.92793
# PSNR: 50.71087727747239 dB
# SSIM: 0.99990
# PSNR: 40.91572966119547 dB
# SSIM: 0.94302
# PSNR: 45.46436470888979 dB
# SSIM: 0.98225
# PSNR: 41.78855567047258 dB
# SSIM: 0.96735
# PSNR: 33.56421379541337 dB
# SSIM: 0.93545
# PSNR: 45.25491059550337 dB
# SSIM: 0.97861
# PSNR: 43.03358290370072 dB
# SSIM: 0.96630
# PSNR: 39.20246507437352 dB
# SSIM: 0.92602
# PSNR: 42.61824916928727 dB
# SSIM: 0.95803
# PSNR: 48.08562370685955 dB
# SSIM: 0.99035
# PSNR: 46.00100755644967 dB
# SSIM: 0.98298
# PSNR: 42.97611614766698 dB
# SSIM: 0.96645
# PSNR: 44.018175189566776 dB
# SSIM: 0.97912
# PSNR: 44.4168532335398 dB
# SSIM: 0.97985
# PSNR: 41.91283821791407 dB
# SSIM: 0.96177
# PSNR: 40.37467587282219 dB
# SSIM: 0.94805
# PSNR: 42.77444048557869 dB
# SSIM: 0.96627
# PSNR: 39.38730072926984 dB
# SSIM: 0.96273
# PSNR: 32.45440009495915 dB
# SSIM: 0.91518
# PSNR: 37.292370497360196 dB
# SSIM: 0.95348
# PSNR: 33.82254355446125 dB
# SSIM: 0.95458
# PSNR: 50.22309059173758 dB
# SSIM: 0.99476
# PSNR: 45.13275843109198 dB
# SSIM: 0.97879
# PSNR: 41.665751451487466 dB
# SSIM: 0.95709
# PSNR: 33.720770730999476 dB
# SSIM: 0.91941
# PSNR: 36.812078116263656 dB
# SSIM: 0.94407
# PSNR: 46.04016858386168 dB
# SSIM: 0.98127
# PSNR: 36.92448298374424 dB
# SSIM: 0.96442
# PSNR: 42.63918209320334 dB
# SSIM: 0.95583
# PSNR: 45.753278262107116 dB
# SSIM: 0.98237
# PSNR: 39.87403216764787 dB
# SSIM: 0.93326
# PSNR: 32.14521414541001 dB
# SSIM: 0.94474
# PSNR: 53.473915131869674 dB
# SSIM: 1.00000
# PSNR: 41.97593223622407 dB
# SSIM: 0.95325
# PSNR: 34.46711656597594 dB
# SSIM: 0.95064
# PSNR: 42.30076939987157 dB
# SSIM: 0.96716
# PSNR: 45.35956521013475 dB
# SSIM: 0.98013
# PSNR: 46.1141619023515 dB
# SSIM: 0.98046
# PSNR: 35.88084571902611 dB
# SSIM: 0.90278
# PSNR: 40.79859528973081 dB
# SSIM: 0.95093
# PSNR: 39.59419931583897 dB
# SSIM: 0.92269
# PSNR: 46.62857077834035 dB
# SSIM: 0.98865
# PSNR: 44.920384456976635 dB
# SSIM: 0.97745
# PSNR: 41.19168562454298 dB
# SSIM: 0.95112
# PSNR: 42.0261820255217 dB
# SSIM: 0.96414
# PSNR: 40.512932751115244 dB
# SSIM: 0.94834
# PSNR: 34.453419220431776 dB
# SSIM: 0.93641
# PSNR: 33.4577791096976 dB
# SSIM: 0.93178
# PSNR: 45.86978216778817 dB
# SSIM: 0.98424
# PSNR: 46.32500260280349 dB
# SSIM: 0.98570
# PSNR: 34.91771575600306 dB
# SSIM: 0.95374
# PSNR: 45.280698386115304 dB
# SSIM: 0.98309
# PSNR: 40.485992210991874 dB
# SSIM: 0.94189
# PSNR: 43.26015785951598 dB
# SSIM: 0.96585
# PSNR: 45.731496995269 dB
# SSIM: 0.98312
# PSNR: 45.844408136463635 dB
# SSIM: 0.98195
# PSNR: 41.835909570267454 dB
# SSIM: 0.96024
# PSNR: 39.402816297621534 dB
# SSIM: 0.90213
# PSNR: 41.75453088342506 dB
# SSIM: 0.96325
# PSNR: 47.544430559737016 dB
# SSIM: 0.99143
# PSNR: 34.2585109228849 dB
# SSIM: 0.90067
# PSNR: 37.529920381146795 dB
# SSIM: 0.96465
# PSNR: 46.026281876388076 dB
# SSIM: 0.98621
# PSNR: 37.194298617249345 dB
# SSIM: 0.95443
# PSNR: 31.646753296380794 dB
# SSIM: 0.93990
# PSNR: 43.25313979400007 dB
# SSIM: 0.96861
# PSNR: 34.48202222730143 dB
# SSIM: 0.97411
# PSNR: 47.38709103883211 dB
# SSIM: 0.99096
# PSNR: 41.42026468451731 dB
# SSIM: 0.95333
# PSNR: 31.9139333321951 dB
# SSIM: 0.95857
# PSNR: 42.80775956859031 dB
# SSIM: 0.96686
# PSNR: 33.637416767912335 dB
# SSIM: 0.93408
# PSNR: 34.82291560683419 dB
# SSIM: 0.95693
# PSNR: 44.296780980222515 dB
# SSIM: 0.97522
# PSNR: 45.14605876788639 dB
# SSIM: 0.97227
# PSNR: 43.46639236810127 dB
# SSIM: 0.97419
# PSNR: 51.377365300721884 dB
# SSIM: 0.99994
# PSNR: 43.34062830826575 dB
# SSIM: 0.97617
# PSNR: 44.01575945841237 dB
# SSIM: 0.98208
# PSNR: 43.427087800155 dB
# SSIM: 0.96574
# PSNR: 41.372255613225796 dB
# SSIM: 0.95479
# PSNR: 56.307344724513236 dB
# SSIM: 0.99928
# PSNR: 45.83943969578701 dB
# SSIM: 0.98328
# PSNR: 42.053540232747075 dB
# SSIM: 0.96313
# PSNR: 41.854587389723825 dB
# SSIM: 0.95619
# PSNR: 31.81443683116411 dB
# SSIM: 0.92058
# PSNR: 35.79754817708027 dB
# SSIM: 0.90185
# PSNR: 31.22172325097354 dB
# SSIM: 0.92653
# PSNR: 40.925139626042586 dB
# SSIM: 0.95201
# PSNR: 35.23333346221488 dB
# SSIM: 0.93780
# PSNR: 43.995927669800295 dB
# SSIM: 0.96818
# PSNR: 38.54949907754412 dB
# SSIM: 0.87114
# PSNR: 41.37495889600053 dB
# SSIM: 0.92484
# PSNR: 40.686836696401365 dB
# SSIM: 0.93325
# PSNR: 31.429636836774012 dB
# SSIM: 0.89493
# PSNR: 40.58140309154281 dB
# SSIM: 0.96049
# PSNR: 42.57955591241034 dB
# SSIM: 0.96203
# PSNR: 37.04432375773124 dB
# SSIM: 0.95720
# PSNR: 43.767760090272674 dB
# SSIM: 0.96810
# PSNR: 38.27396374257023 dB
# SSIM: 0.97326
# PSNR: 40.66501444269109 dB
# SSIM: 0.94374
# PSNR: 47.86986412545617 dB
# SSIM: 0.99389
# PSNR: 34.03217774503882 dB
# SSIM: 0.95018
# PSNR: 32.42170405823037 dB
# SSIM: 0.94765
# PSNR: 42.58817193443989 dB
# SSIM: 0.95979
# PSNR: 32.96737533206758 dB
# SSIM: 0.92345
# PSNR: 40.21130897405165 dB
# SSIM: 0.93575
# PSNR: 34.91559440739288 dB
# SSIM: 0.93331
# PSNR: 44.13626779117322 dB
# SSIM: 0.97263
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 43.46834733546054 dB
# SSIM: 0.96943
# PSNR: 47.906629484925524 dB
# SSIM: 0.98404
# PSNR: 33.21453746791313 dB
# SSIM: 0.93609
# PSNR: 46.66545755776663 dB
# SSIM: 0.98599
# PSNR: 43.53313006701291 dB
# SSIM: 0.97253
# PSNR: 36.17550419359498 dB
# SSIM: 0.96143
# PSNR: 44.828122778609696 dB
# SSIM: 0.97369
# PSNR: 48.198434961522594 dB
# SSIM: 0.99132
# PSNR: 48.531860407574925 dB
# SSIM: 0.99369
# PSNR: 39.91058721381387 dB
# SSIM: 0.94017
# PSNR: 37.15416782915916 dB
# SSIM: 0.92396
# PSNR: 41.452732675809116 dB
# SSIM: 0.95302
# PSNR: 41.43738109024683 dB
# SSIM: 0.94797
# PSNR: 51.394519196689274 dB
# SSIM: 0.99625
# PSNR: 44.5834398249153 dB
# SSIM: 0.98539
# PSNR: 39.96153786209878 dB
# SSIM: 0.93742
# PSNR: 42.59206984543116 dB
# SSIM: 0.97126
# PSNR: 39.99629715686231 dB
# SSIM: 0.94995
# PSNR: 42.632730919651564 dB
# SSIM: 0.95594
# PSNR: 42.44772740188364 dB
# SSIM: 0.95971
# PSNR: 49.78337214049738 dB
# SSIM: 0.99536
# PSNR: 40.39933460735039 dB
# SSIM: 0.94756
# PSNR: 39.828948910097075 dB
# SSIM: 0.93677
# PSNR: 41.304292600583935 dB
# SSIM: 0.95661
# PSNR: 39.889940577753926 dB
# SSIM: 0.92906
# PSNR: 42.15258949250449 dB
# SSIM: 0.96211
# PSNR: 47.27611826418525 dB
# SSIM: 0.98955
# PSNR: 42.39892842192831 dB
# SSIM: 0.95490
# PSNR: 45.078855697787986 dB
# SSIM: 0.97805
# PSNR: 45.26603186551831 dB
# SSIM: 0.97888
# PSNR: 42.96080101877762 dB
# SSIM: 0.96703
# PSNR: 34.2517718800709 dB
# SSIM: 0.94580
# PSNR: 42.82346103480827 dB
# SSIM: 0.96524
# PSNR: 42.88646440859007 dB
# SSIM: 0.96612
# PSNR: 35.39365158782168 dB
# SSIM: 0.96245
# PSNR: 45.47054969874842 dB
# SSIM: 0.98629
# PSNR: 44.047243383825545 dB
# SSIM: 0.97419
# PSNR: 43.065730438374594 dB
# SSIM: 0.98616
# PSNR: 38.25136876616942 dB
# SSIM: 0.92932
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 43.64322538862152 dB
# SSIM: 0.96323
# PSNR: 45.0478770430074 dB
# SSIM: 0.98705
# PSNR: 40.52870800495073 dB
# SSIM: 0.94944
# PSNR: 44.22627428549021 dB
# SSIM: 0.98195
# PSNR: 42.81843974739853 dB
# SSIM: 0.96712
# PSNR: 34.746046560249795 dB
# SSIM: 0.93448
# PSNR: 42.253922049960444 dB
# SSIM: 0.95192
# PSNR: 40.3330086737208 dB
# SSIM: 0.93632
# PSNR: 41.421244719479844 dB
# SSIM: 0.95174
# PSNR: 37.270144180911245 dB
# SSIM: 0.95489
# PSNR: 41.001145368841335 dB
# SSIM: 0.95250
# PSNR: 35.906451373120994 dB
# SSIM: 0.96514
# PSNR: 42.56184797758828 dB
# SSIM: 0.96229
# PSNR: 42.0641603796323 dB
# SSIM: 0.96310
# PSNR: 38.79800535986993 dB
# SSIM: 0.95611
# PSNR: 33.093313102858204 dB
# SSIM: 0.92728
# PSNR: 41.9258496483623 dB
# SSIM: 0.96747
# PSNR: 33.725149042520016 dB
# SSIM: 0.96147
# PSNR: 33.672194110466634 dB
# SSIM: 0.91526
# PSNR: 35.87230016635479 dB
# SSIM: 0.91270
# PSNR: 43.42662416105679 dB
# SSIM: 0.97230
# PSNR: 32.95393282742716 dB
# SSIM: 0.95918
# PSNR: 39.51403216042627 dB
# SSIM: 0.93861
# PSNR: 44.12454655275501 dB
# SSIM: 0.97668
# PSNR: 35.37973987701409 dB
# SSIM: 0.95004
# PSNR: 47.24464521937819 dB
# SSIM: 0.98537
# PSNR: 45.08907404830238 dB
# SSIM: 0.97881
# PSNR: 42.484578515535524 dB
# SSIM: 0.96300
# PSNR: 44.22009398515753 dB
# SSIM: 0.97590
# PSNR: 32.50909519439873 dB
# SSIM: 0.90771
# PSNR: 41.85295279753227 dB
# SSIM: 0.95192
# PSNR: 46.086330268576596 dB
# SSIM: 0.98884
# PSNR: 43.10998917129784 dB
# SSIM: 0.96270
# PSNR: 44.301918742922965 dB
# SSIM: 0.96534
# PSNR: 53.77768006960598 dB
# SSIM: 0.99167
# PSNR: 42.05539388551812 dB
# SSIM: 0.95102
# PSNR: 37.64725983077878 dB
# SSIM: 0.95530
# PSNR: 46.32080708353221 dB
# SSIM: 0.98404
# PSNR: 46.737202682241055 dB
# SSIM: 0.98834
# PSNR: 43.75405521168964 dB
# SSIM: 0.97150
# PSNR: 56.95971781294957 dB
# SSIM: 0.99901
# PSNR: 42.09536294225625 dB
# SSIM: 0.96005
# PSNR: 33.73239427320056 dB
# SSIM: 0.92362
# PSNR: 47.72157428970094 dB
# SSIM: 0.99116
# PSNR: 47.0234053736347 dB
# SSIM: 0.98733
# PSNR: 57.54711401764411 dB
# SSIM: 0.99955
# PSNR: 44.56253564359737 dB
# SSIM: 0.96559
# PSNR: 43.94343368997259 dB
# SSIM: 0.97570
# PSNR: 46.95825050783391 dB
# SSIM: 0.98780
# PSNR: 45.127312509472844 dB
# SSIM: 0.97809
# PSNR: 37.31717938783193 dB
# SSIM: 0.90359
# PSNR: 43.696138010130966 dB
# SSIM: 0.97411
# PSNR: 42.925458689985525 dB
# SSIM: 0.96926
# PSNR: 38.12660645019907 dB
# SSIM: 0.93128
# PSNR: 34.3628881879519 dB
# SSIM: 0.92665
# PSNR: 41.89158707236756 dB
# SSIM: 0.95391
# PSNR: 40.201885997620536 dB
# SSIM: 0.93205
# PSNR: 53.15735237682216 dB
# SSIM: 1.00000
# PSNR: 49.01017138839585 dB
# SSIM: 0.99508
# PSNR: 42.31542695803039 dB
# SSIM: 0.96456
# PSNR: 33.180961979714766 dB
# SSIM: 0.95597
# PSNR: 42.50629087103484 dB
# SSIM: 0.96362
# PSNR: 44.648397301066645 dB
# SSIM: 0.97985
# PSNR: 36.97115954306696 dB
# SSIM: 0.97236
# PSNR: 41.213651193148436 dB
# SSIM: 0.94320
# PSNR: 38.49145760125913 dB
# SSIM: 0.93169
# PSNR: 41.15386786516915 dB
# SSIM: 0.95095
# PSNR: 44.55856481554879 dB
# SSIM: 0.97902
# PSNR: 42.917430927920236 dB
# SSIM: 0.95789
# PSNR: 40.49599584560119 dB
# SSIM: 0.93241
# PSNR: 42.61311846917167 dB
# SSIM: 0.97055
# PSNR: 40.961322811088785 dB
# SSIM: 0.94502
# PSNR: 41.7672085685058 dB
# SSIM: 0.95806
# PSNR: 37.3429229927302 dB
# SSIM: 0.95840
# PSNR: 30.99257519298957 dB
# SSIM: 0.93319
# PSNR: 44.340776143632965 dB
# SSIM: 0.96828
# PSNR: 32.52212993276312 dB
# SSIM: 0.93290
# PSNR: 32.54076040088793 dB
# SSIM: 0.95028
# PSNR: 42.776010903195505 dB
# SSIM: 0.96830
# PSNR: 43.896838052922135 dB
# SSIM: 0.97889
# PSNR: 43.67732216282285 dB
# SSIM: 0.96920
# PSNR: 38.598728658079345 dB
# SSIM: 0.96085
# PSNR: 34.65355795415918 dB
# SSIM: 0.93684
# PSNR: 44.915451124629094 dB
# SSIM: 0.98108
# PSNR: 31.83912038359435 dB
# SSIM: 0.94221
# PSNR: 52.42603789143792 dB
# SSIM: 0.99552
# PSNR: 35.21882802229143 dB
# SSIM: 0.93071
# PSNR: 35.57965209595492 dB
# SSIM: 0.97606
# PSNR: 39.856653205466166 dB
# SSIM: 0.92670
# PSNR: 38.845097148452965 dB
# SSIM: 0.95456
# PSNR: 43.4643628505938 dB
# SSIM: 0.97569
# PSNR: 36.09166962850736 dB
# SSIM: 0.97085
# PSNR: 42.25355674406704 dB
# SSIM: 0.95979
# PSNR: 34.91771153967766 dB
# SSIM: 0.94314
# PSNR: 33.92621837249543 dB
# SSIM: 0.91121
# PSNR: 37.04956956544655 dB
# SSIM: 0.90801
# PSNR: 42.082876953562156 dB
# SSIM: 0.96299
# PSNR: 46.291840659481565 dB
# SSIM: 0.98258
# PSNR: 46.985162316789854 dB
# SSIM: 0.98762
# PSNR: 32.49199605811157 dB
# SSIM: 0.96030
# PSNR: 39.36774160077425 dB
# SSIM: 0.92743
# PSNR: 37.22031952125898 dB
# SSIM: 0.95131
# PSNR: 41.50731278591991 dB
# SSIM: 0.95241
# PSNR: 44.4894799598317 dB
# SSIM: 0.97581
# PSNR: 42.00392845991996 dB
# SSIM: 0.95914
# PSNR: 41.30142206573473 dB
# SSIM: 0.95169
# PSNR: 47.9248135386777 dB
# SSIM: 0.98688
# PSNR: 46.69176730441569 dB
# SSIM: 0.99002
# PSNR: 38.55041865952129 dB
# SSIM: 0.96477
# PSNR: 54.31279022662519 dB
# SSIM: 0.99853
# PSNR: 44.949019640809254 dB
# SSIM: 0.98243
# PSNR: 42.32845561961406 dB
# SSIM: 0.96305
# PSNR: 44.61412584323406 dB
# SSIM: 0.98055
# PSNR: 39.659118111907034 dB
# SSIM: 0.95365
# PSNR: 42.693153620130815 dB
# SSIM: 0.96299
# PSNR: 35.35443008312244 dB
# SSIM: 0.95050
# PSNR: 42.166530789324135 dB
# SSIM: 0.95912
# PSNR: 35.62080763287924 dB
# SSIM: 0.93687
# PSNR: 43.68264901407646 dB
# SSIM: 0.97688
# PSNR: 42.08327208602676 dB
# SSIM: 0.95077
# PSNR: 36.728969961113066 dB
# SSIM: 0.96060
# PSNR: 43.14711046344576 dB
# SSIM: 0.96857
# PSNR: 43.05969278179219 dB
# SSIM: 0.96041
# PSNR: 48.43542774993129 dB
# SSIM: 0.99298
# PSNR: 40.56949654027963 dB
# SSIM: 0.94796
# PSNR: 32.91274295254395 dB
# SSIM: 0.94389
# PSNR: 41.728426121104214 dB
# SSIM: 0.95527
# PSNR: 32.87897896297908 dB
# SSIM: 0.94125
# PSNR: 44.29518238327448 dB
# SSIM: 0.97115
# PSNR: 42.204176158068954 dB
# SSIM: 0.95964
# PSNR: 42.25703981578172 dB
# SSIM: 0.94998
# PSNR: 49.60953866355059 dB
# SSIM: 0.99455
# PSNR: 43.76455814538167 dB
# SSIM: 0.97684
# PSNR: 39.60477515648059 dB
# SSIM: 0.92660
# PSNR: 40.044053265587046 dB
# SSIM: 0.93895
# PSNR: 31.77717948627388 dB
# SSIM: 0.92916
# PSNR: 43.990517651572425 dB
# SSIM: 0.97628
# PSNR: 45.53716602768624 dB
# SSIM: 0.98666
# PSNR: 33.27944538241772 dB
# SSIM: 0.92006
# PSNR: 31.496788135276145 dB
# SSIM: 0.93606
# PSNR: 43.823679847628085 dB
# SSIM: 0.97538
# PSNR: 42.8592984727905 dB
# SSIM: 0.97129
# PSNR: 40.37080411277052 dB
# SSIM: 0.93989
# PSNR: 40.09445413663578 dB
# SSIM: 0.93533
# PSNR: 48.30870522179651 dB
# SSIM: 0.99308
# PSNR: 48.76408933081807 dB
# SSIM: 0.99420
# PSNR: 42.1756312662683 dB
# SSIM: 0.96431
# PSNR: 44.30318125880483 dB
# SSIM: 0.97881
# PSNR: 42.46327965220881 dB
# SSIM: 0.96089
# PSNR: 36.315584375232206 dB
# SSIM: 0.92957
# PSNR: 48.65633395539628 dB
# SSIM: 0.99371
# PSNR: 50.87183078589429 dB
# SSIM: 0.99659
# PSNR: 33.46004592533361 dB
# SSIM: 0.94614
# PSNR: 37.84180258441696 dB
# SSIM: 0.93850
# PSNR: 40.67958087704135 dB
# SSIM: 0.92921
# PSNR: 43.03773107936002 dB
# SSIM: 0.96998
# PSNR: 40.13641787795698 dB
# SSIM: 0.94068
# PSNR: 43.07845208807588 dB
# SSIM: 0.97447
# PSNR: 44.62832263643185 dB
# SSIM: 0.98028
# PSNR: 42.123400027103614 dB
# SSIM: 0.95979
# PSNR: 47.36266540152741 dB
# SSIM: 0.98270
# PSNR: 41.209996006849366 dB
# SSIM: 0.95477
# PSNR: 31.705574863702765 dB
# SSIM: 0.93180
# PSNR: 43.15160017304942 dB
# SSIM: 0.97063
# PSNR: 45.53321686290204 dB
# SSIM: 0.98641
# PSNR: 42.74580295187206 dB
# SSIM: 0.96976
# PSNR: 38.7380583588962 dB
# SSIM: 0.90567
# PSNR: 45.36467954414982 dB
# SSIM: 0.97663
# PSNR: 45.83643009961329 dB
# SSIM: 0.98924
# PSNR: 41.10500098401559 dB
# SSIM: 0.95354
# PSNR: 32.68004633862061 dB
# SSIM: 0.93260
# PSNR: 37.20181867241111 dB
# SSIM: 0.92502
# PSNR: 48.91946285358016 dB
# SSIM: 0.99216
# PSNR: 38.47948748358359 dB
# SSIM: 0.90691
# PSNR: 41.62950162045442 dB
# SSIM: 0.95742
# PSNR: 34.007204705477236 dB
# SSIM: 0.91189
# PSNR: 34.286822634306425 dB
# SSIM: 0.92737
# PSNR: 42.14846484171511 dB
# SSIM: 0.96222
# PSNR: 45.741551998374426 dB
# SSIM: 0.97976
# PSNR: 42.27385489900084 dB
# SSIM: 0.96708
# PSNR: 42.39073833927683 dB
# SSIM: 0.96341
# PSNR: 47.28236402407973 dB
# SSIM: 0.98866
# PSNR: 42.355437067532606 dB
# SSIM: 0.96431
# PSNR: 47.28623581900531 dB
# SSIM: 0.98572
# PSNR: 32.73941369412189 dB
# SSIM: 0.93710
# PSNR: 42.31135302010643 dB
# SSIM: 0.96080
# PSNR: 42.787329541344555 dB
# SSIM: 0.96234
# PSNR: 35.34031792765881 dB
# SSIM: 0.92468
# PSNR: 48.908510646010015 dB
# SSIM: 0.99516
# PSNR: 40.31620974941583 dB
# SSIM: 0.92716
# PSNR: 45.10016288192662 dB
# SSIM: 0.97983
# PSNR: 43.27009312521159 dB
# SSIM: 0.97478
# PSNR: 46.94313411694076 dB
# SSIM: 0.99127
# PSNR: 32.54485278568181 dB
# SSIM: 0.92484
# PSNR: 40.230836213834095 dB
# SSIM: 0.93562
# PSNR: 37.18641654858643 dB
# SSIM: 0.92665
# PSNR: 41.569047505943516 dB
# SSIM: 0.95524
# PSNR: 41.7598053592478 dB
# SSIM: 0.96325
# PSNR: 40.598435299574255 dB
# SSIM: 0.94994
# PSNR: 44.4367831308163 dB
# SSIM: 0.98433
# PSNR: 45.45707844817433 dB
# SSIM: 0.98069
# PSNR: 39.653471819122885 dB
# SSIM: 0.95764
# PSNR: 32.72425435079575 dB
# SSIM: 0.90091
# PSNR: 39.663479473474446 dB
# SSIM: 0.92830
# PSNR: 38.74302267052726 dB
# SSIM: 0.91125
# PSNR: 46.841360243844115 dB
# SSIM: 0.98480
# PSNR: 39.25207265553959 dB
# SSIM: 0.92954
# PSNR: 33.410699078719354 dB
# SSIM: 0.91920
# PSNR: 33.046083862940144 dB
# SSIM: 0.92172
# PSNR: 45.15126129791356 dB
# SSIM: 0.98304
# PSNR: 33.42703096431335 dB
# SSIM: 0.91019
# PSNR: 33.13574840402374 dB
# SSIM: 0.97178
# PSNR: 47.556315994511706 dB
# SSIM: 0.98941
# PSNR: 34.76547300607741 dB
# SSIM: 0.95621
# PSNR: 41.62792980536388 dB
# SSIM: 0.94736
# PSNR: 39.88489594525012 dB
# SSIM: 0.94888
# PSNR: 33.23033118453753 dB
# SSIM: 0.93266
# PSNR: 43.336371061261325 dB
# SSIM: 0.97627
# PSNR: 40.59780761596719 dB
# SSIM: 0.94215
# PSNR: 32.38617946207184 dB
# SSIM: 0.94709
# PSNR: 44.61488275267026 dB
# SSIM: 0.97631
# PSNR: 41.269379194586335 dB
# SSIM: 0.95828
# PSNR: 33.65085240031333 dB
# SSIM: 0.93931
# PSNR: 39.678356091767995 dB
# SSIM: 0.92186
# PSNR: 47.76281978988693 dB
# SSIM: 0.99001
# PSNR: 38.63930971511174 dB
# SSIM: 0.91123
# PSNR: 34.729053555972584 dB
# SSIM: 0.95019
# PSNR: 42.529851592056616 dB
# SSIM: 0.96201
# PSNR: 41.916892841312816 dB
# SSIM: 0.95066
# PSNR: 47.495627199185925 dB
# SSIM: 0.98910
# PSNR: 33.53973088220585 dB
# SSIM: 0.93929
# PSNR: 41.596622192981805 dB
# SSIM: 0.95451
# PSNR: 33.838895626723826 dB
# SSIM: 0.94866
# PSNR: 45.28448172894568 dB
# SSIM: 0.98487
# PSNR: 44.92497495677355 dB
# SSIM: 0.98078
# PSNR: 43.61134442914907 dB
# SSIM: 0.97284
# PSNR: 32.88213558011777 dB
# SSIM: 0.94770
# PSNR: 32.21047225003286 dB
# SSIM: 0.87903
# PSNR: 42.464699527063566 dB
# SSIM: 0.96106
# PSNR: 34.84432594520635 dB
# SSIM: 0.92502
# PSNR: 41.69876361266358 dB
# SSIM: 0.95671
# PSNR: 40.310827645353264 dB
# SSIM: 0.94011
# PSNR: 40.421864937782274 dB
# SSIM: 0.94816
# PSNR: 39.16371983614163 dB
# SSIM: 0.93211
# PSNR: 33.98504803492396 dB
# SSIM: 0.96520
# PSNR: 43.10544502606179 dB
# SSIM: 0.97313
# PSNR: 45.76640734047396 dB
# SSIM: 0.98344
# PSNR: 41.56402877654649 dB
# SSIM: 0.95544
# PSNR: 45.92797030450663 dB
# SSIM: 0.97821
# PSNR: 32.468205670139916 dB
# SSIM: 0.93664
# PSNR: 40.569403588220865 dB
# SSIM: 0.93299
# PSNR: 45.29534561383747 dB
# SSIM: 0.97551
# PSNR: 40.922849292633074 dB
# SSIM: 0.93841
# PSNR: 44.59473698589393 dB
# SSIM: 0.97814
# PSNR: 33.70907048219878 dB
# SSIM: 0.93229
# PSNR: 42.500336028161385 dB
# SSIM: 0.96463
# PSNR: 40.539337535706316 dB
# SSIM: 0.96376
# PSNR: 44.33134456588958 dB
# SSIM: 0.97666
# PSNR: 33.59770669980207 dB
# SSIM: 0.88967
# PSNR: 42.50027561475176 dB
# SSIM: 0.96651
# PSNR: 40.94158982735529 dB
# SSIM: 0.94473
# PSNR: 35.078898361149875 dB
# SSIM: 0.95772
# PSNR: 38.84663367941458 dB
# SSIM: 0.90395
# PSNR: 40.07637623392499 dB
# SSIM: 0.94355
# PSNR: 34.089034032870686 dB
# SSIM: 0.96974
# PSNR: 38.02584345022188 dB
# SSIM: 0.94789
# PSNR: 45.902188913301856 dB
# SSIM: 0.98119
# PSNR: 45.149259587213855 dB
# SSIM: 0.97559
# PSNR: 41.59886009834722 dB
# SSIM: 0.94942
# PSNR: 33.61197492189331 dB
# SSIM: 0.90263
# PSNR: 43.11803994311425 dB
# SSIM: 0.96838
# PSNR: 44.28147689446561 dB
# SSIM: 0.97805
# PSNR: 43.749501882517556 dB
# SSIM: 0.96999
# PSNR: 42.350152240438305 dB
# SSIM: 0.96404
# PSNR: 42.04486040629472 dB
# SSIM: 0.96014
# PSNR: 41.33417881319595 dB
# SSIM: 0.94546
# PSNR: 38.86666344333239 dB
# SSIM: 0.95479
# PSNR: 46.481615391530426 dB
# SSIM: 0.98634
# PSNR: 40.56121612523163 dB
# SSIM: 0.94631
# PSNR: 44.94097934812797 dB
# SSIM: 0.97641
# PSNR: 45.70705499070869 dB
# SSIM: 0.98523
# PSNR: 43.72216164139807 dB
# SSIM: 0.97123
# PSNR: 32.25607855151489 dB
# SSIM: 0.93374
# PSNR: 44.50619776610223 dB
# SSIM: 0.97669
# PSNR: 33.30378599612773 dB
# SSIM: 0.91263
# PSNR: 34.017824739562656 dB
# SSIM: 0.94137
# PSNR: 41.0740089900759 dB
# SSIM: 0.94814
# PSNR: 43.92689795720685 dB
# SSIM: 0.97539
# PSNR: 39.96936669717179 dB
# SSIM: 0.94412
# PSNR: 38.82833743451283 dB
# SSIM: 0.95132
# PSNR: 42.8281623688676 dB
# SSIM: 0.96814
# PSNR: 34.995551025721944 dB
# SSIM: 0.95406
# PSNR: 33.8830169278863 dB
# SSIM: 0.92685
# PSNR: 43.62187503903483 dB
# SSIM: 0.97350
# PSNR: 34.1870950967978 dB
# SSIM: 0.94570
# PSNR: 35.53615226867055 dB
# SSIM: 0.95839
# PSNR: 41.119927402122805 dB
# SSIM: 0.95574
# PSNR: 42.95763840881996 dB
# SSIM: 0.96910
# PSNR: 41.75581327457499 dB
# SSIM: 0.95173
# PSNR: 34.55664963098708 dB
# SSIM: 0.94192
# PSNR: 43.45325880559379 dB
# SSIM: 0.96445
# PSNR: 41.906895114137285 dB
# SSIM: 0.96090
# PSNR: 33.910134903836706 dB
# SSIM: 0.90594
# PSNR: 41.41416328968874 dB
# SSIM: 0.94930
# PSNR: 34.77786472755649 dB
# SSIM: 0.97556
# PSNR: 41.766198296549824 dB
# SSIM: 0.95570
# PSNR: 46.585242370215276 dB
# SSIM: 0.98783
# PSNR: 41.71663767199107 dB
# SSIM: 0.95752
# PSNR: 37.36639089273586 dB
# SSIM: 0.93389
# PSNR: 44.55042093724686 dB
# SSIM: 0.97269
# PSNR: 36.744237346038815 dB
# SSIM: 0.93469
# PSNR: 42.50604889088326 dB
# SSIM: 0.96904
# PSNR: 42.167918429626795 dB
# SSIM: 0.95966
# PSNR: 36.137307238058995 dB
# SSIM: 0.92288
# PSNR: 35.86305454051963 dB
# SSIM: 0.93134
# PSNR: 44.03501981064497 dB
# SSIM: 0.96829
# PSNR: 38.81292651128062 dB
# SSIM: 0.90953
# PSNR: 44.190776823464134 dB
# SSIM: 0.97503
# PSNR: 43.350323425818175 dB
# SSIM: 0.97370
# PSNR: 42.957014216609636 dB
# SSIM: 0.97300
# PSNR: 35.34753992188315 dB
# SSIM: 0.94388
# PSNR: 40.66873765850404 dB
# SSIM: 0.92353
# PSNR: 50.30602079529534 dB
# SSIM: 0.99652
# PSNR: 36.48542931730854 dB
# SSIM: 0.94157
# PSNR: 46.98199054446747 dB
# SSIM: 0.98277
# PSNR: 34.697049674885314 dB
# SSIM: 0.92326
# PSNR: 35.75509553876523 dB
# SSIM: 0.92908
# PSNR: 31.96103027438264 dB
# SSIM: 0.89294
# PSNR: 46.11292638973416 dB
# SSIM: 0.98845
# PSNR: 34.1835144020368 dB
# SSIM: 0.92782
# PSNR: 44.64650547472746 dB
# SSIM: 0.98066
# PSNR: 47.992133211505234 dB
# SSIM: 0.99057
# PSNR: 41.830831883708626 dB
# SSIM: 0.95983
# PSNR: 37.003875357384736 dB
# SSIM: 0.95995
# PSNR: 41.32808177975999 dB
# SSIM: 0.96124
# PSNR: 34.78864933383721 dB
# SSIM: 0.93839
# PSNR: 43.50556091126662 dB
# SSIM: 0.97090
# PSNR: 43.13982457017402 dB
# SSIM: 0.97316
# PSNR: 39.640133825154294 dB
# SSIM: 0.93791
# PSNR: 40.82312472264387 dB
# SSIM: 0.94808
# PSNR: 48.26176019600814 dB
# SSIM: 0.99345
# PSNR: 34.65141999002952 dB
# SSIM: 0.95067
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 33.164740271757665 dB
# SSIM: 0.94597
# PSNR: 36.04310423779457 dB
# SSIM: 0.94738
# PSNR: 42.45957937570136 dB
# SSIM: 0.95996
# PSNR: 43.025687041479934 dB
# SSIM: 0.96989
# PSNR: 32.73519894286105 dB
# SSIM: 0.93868
# PSNR: 44.2488332157434 dB
# SSIM: 0.96983
# PSNR: 33.83059412847486 dB
# SSIM: 0.95212
# PSNR: 43.451295576470905 dB
# SSIM: 0.97268
# PSNR: 53.22649411942873 dB
# SSIM: 0.99825
# PSNR: 45.23275312949765 dB
# SSIM: 0.97400
# PSNR: 32.964529274720746 dB
# SSIM: 0.95074
# PSNR: 34.71819023218482 dB
# SSIM: 0.96712
# PSNR: 46.256232161404334 dB
# SSIM: 0.98402
# PSNR: 40.50118931830347 dB
# SSIM: 0.95030
# PSNR: 52.653909175134864 dB
# SSIM: 0.99909
# PSNR: 51.524921204526926 dB
# SSIM: 0.99730
# PSNR: 33.05102918670381 dB
# SSIM: 0.95702
# PSNR: 49.013499450391826 dB
# SSIM: 0.99466
# PSNR: 38.55475402086141 dB
# SSIM: 0.92292
# PSNR: 39.9865160241881 dB
# SSIM: 0.94683
# PSNR: 43.6310515296421 dB
# SSIM: 0.97156
# PSNR: 41.73203875712824 dB
# SSIM: 0.96363
# PSNR: 46.42533428204712 dB
# SSIM: 0.98135
# PSNR: 44.69056746103682 dB
# SSIM: 0.98239
# PSNR: 40.69596242882505 dB
# SSIM: 0.93816
# PSNR: 42.837293056637904 dB
# SSIM: 0.96990
# PSNR: 32.00990124879101 dB
# SSIM: 0.94166
# PSNR: 43.92949142409247 dB
# SSIM: 0.97060
# PSNR: 36.534799002524316 dB
# SSIM: 0.96512
# PSNR: 31.89405743075499 dB
# SSIM: 0.93818
# PSNR: 35.17927172218293 dB
# SSIM: 0.94640
# PSNR: 44.1851098108199 dB
# SSIM: 0.97243
# PSNR: 44.99235101737764 dB
# SSIM: 0.98047
# PSNR: 37.16044368426219 dB
# SSIM: 0.94663
# PSNR: 33.57806094547702 dB
# SSIM: 0.95231
# PSNR: 43.50247800922603 dB
# SSIM: 0.97265
# PSNR: 42.6930083625857 dB
# SSIM: 0.96029
# PSNR: 46.12525560225567 dB
# SSIM: 0.98468
# PSNR: 43.39603637417091 dB
# SSIM: 0.97337
# PSNR: 41.04494310414114 dB
# SSIM: 0.94465
# PSNR: 43.3230182462428 dB
# SSIM: 0.96322
# PSNR: 42.773462479620996 dB
# SSIM: 0.96252
# PSNR: 38.786915483309706 dB
# SSIM: 0.95374
# PSNR: 45.82356838637948 dB
# SSIM: 0.98571
# PSNR: 41.0612383605411 dB
# SSIM: 0.95002
# PSNR: 44.744642452475034 dB
# SSIM: 0.97221
# PSNR: 39.39843972920397 dB
# SSIM: 0.93555
# PSNR: 44.565849062678154 dB
# SSIM: 0.97792
# PSNR: 43.84903895777815 dB
# SSIM: 0.97990
# PSNR: 40.08738447176229 dB
# SSIM: 0.92813
# PSNR: 43.57476445621948 dB
# SSIM: 0.97249
# PSNR: 40.84803299698035 dB
# SSIM: 0.94846
# PSNR: 44.7593035913705 dB
# SSIM: 0.97762
# PSNR: 54.20295559866482 dB
# SSIM: 0.99732
# PSNR: 41.6362649346517 dB
# SSIM: 0.94706
# PSNR: 40.026484278999455 dB
# SSIM: 0.93180
# PSNR: 34.318622760507104 dB
# SSIM: 0.95369
# PSNR: 43.010705991808116 dB
# SSIM: 0.96228
# PSNR: 31.968446000589203 dB
# SSIM: 0.94708
# PSNR: 36.42795720904766 dB
# SSIM: 0.95749
# PSNR: 42.36372470295488 dB
# SSIM: 0.96027
# PSNR: 49.17486102602605 dB
# SSIM: 0.99453
# PSNR: 41.427827991149215 dB
# SSIM: 0.95168
# PSNR: 45.325113264804784 dB
# SSIM: 0.98190
# PSNR: 42.763822897581 dB
# SSIM: 0.96606
# PSNR: 44.67862949383492 dB
# SSIM: 0.97890
# PSNR: 39.328600404113914 dB
# SSIM: 0.95935
# PSNR: 45.557246791428426 dB
# SSIM: 0.98765
# PSNR: 43.22611566889334 dB
# SSIM: 0.97042
# PSNR: 45.450424000047775 dB
# SSIM: 0.98223
# PSNR: 47.080680350062025 dB
# SSIM: 0.98760
# PSNR: 40.47255215857171 dB
# SSIM: 0.94229
# PSNR: 42.69859480283981 dB
# SSIM: 0.97056
# PSNR: 33.75071751689567 dB
# SSIM: 0.97073
# PSNR: 41.5535665808731 dB
# SSIM: 0.95162
# PSNR: 34.45705232952186 dB
# SSIM: 0.95239
# PSNR: 49.67139326000142 dB
# SSIM: 0.99372
# PSNR: 47.29832783984883 dB
# SSIM: 0.98777
# PSNR: 45.65613023258979 dB
# SSIM: 0.98713
# PSNR: 39.20024067491766 dB
# SSIM: 0.92939
# PSNR: 39.51405038503205 dB
# SSIM: 0.92043
# PSNR: 42.027205869930675 dB
# SSIM: 0.95833
# PSNR: 36.890695396014834 dB
# SSIM: 0.95264
# PSNR: 39.4298300449735 dB
# SSIM: 0.92989
# PSNR: 41.44143640386386 dB
# SSIM: 0.95662
# PSNR: 44.114670079463494 dB
# SSIM: 0.97142
# PSNR: 35.34972830835437 dB
# SSIM: 0.96490
# PSNR: 45.41555397264939 dB
# SSIM: 0.97417
# PSNR: 43.452295885014635 dB
# SSIM: 0.97216
# PSNR: 51.53066804520631 dB
# SSIM: 0.99470
# PSNR: 42.948191164408165 dB
# SSIM: 0.95895
# PSNR: 38.8235104621281 dB
# SSIM: 0.96541
# PSNR: 42.598133359336146 dB
# SSIM: 0.96588
# PSNR: 43.748921978050426 dB
# SSIM: 0.98017
# PSNR: 40.44119491104898 dB
# SSIM: 0.93064
# PSNR: 47.060572245495045 dB
# SSIM: 0.98961
# PSNR: 37.13338204019851 dB
# SSIM: 0.95135
# PSNR: 39.79362570329534 dB
# SSIM: 0.91668
# PSNR: 47.17047739336809 dB
# SSIM: 0.98933
# PSNR: 44.886533333161765 dB
# SSIM: 0.97224
# PSNR: 46.07558312807049 dB
# SSIM: 0.98611
# PSNR: 46.76796899217247 dB
# SSIM: 0.98357
# PSNR: 36.35498128831277 dB
# SSIM: 0.90327
# PSNR: 32.49836336056316 dB
# SSIM: 0.92338
# PSNR: 43.78917506094012 dB
# SSIM: 0.97428
# PSNR: 35.824574881398576 dB
# SSIM: 0.93379
# PSNR: 33.57668213734272 dB
# SSIM: 0.89022
# PSNR: 38.92403708922197 dB
# SSIM: 0.94423
# PSNR: 35.91090615669537 dB
# SSIM: 0.90586
# PSNR: 36.442543467340926 dB
# SSIM: 0.96238
# PSNR: 41.48570348641951 dB
# SSIM: 0.95482
# PSNR: 63.293997545402576 dB
# SSIM: 0.99989
# PSNR: 44.81585267148016 dB
# SSIM: 0.97974
# PSNR: 34.40958002433422 dB
# SSIM: 0.95612
# PSNR: 40.55926440229521 dB
# SSIM: 0.94305
# PSNR: 41.22525229266824 dB
# SSIM: 0.95296
# PSNR: 38.98036259001607 dB
# SSIM: 0.96034
# PSNR: 35.57077680279646 dB
# SSIM: 0.94569
# PSNR: 38.505810522599894 dB
# SSIM: 0.95146
# PSNR: 41.50616417084298 dB
# SSIM: 0.94567
# PSNR: 47.63330074258935 dB
# SSIM: 0.97862
# PSNR: 43.564686955689915 dB
# SSIM: 0.97682
# PSNR: 44.0550140470646 dB
# SSIM: 0.97818
# PSNR: 34.7437825846344 dB
# SSIM: 0.90797
# PSNR: 41.23467199837162 dB
# SSIM: 0.95578
# PSNR: 44.93487951216885 dB
# SSIM: 0.97400
# PSNR: 44.958574891724396 dB
# SSIM: 0.97984
# PSNR: 34.517497386737894 dB
# SSIM: 0.95348
# PSNR: 44.67230917600597 dB
# SSIM: 0.97902
# PSNR: 32.73507204059107 dB
# SSIM: 0.94302
# PSNR: 35.85246360220137 dB
# SSIM: 0.95226
# PSNR: 46.237836770769675 dB
# SSIM: 0.98956
# PSNR: 40.77124491188192 dB
# SSIM: 0.94440
# PSNR: 39.01538648487549 dB
# SSIM: 0.91999
# PSNR: 31.195223434375457 dB
# SSIM: 0.92731
# PSNR: 46.44752539978667 dB
# SSIM: 0.98614
# PSNR: 43.7010498850701 dB
# SSIM: 0.96844
# PSNR: 45.88596848694387 dB
# SSIM: 0.98466
# PSNR: 43.17004256565177 dB
# SSIM: 0.97010
# PSNR: 35.55991251719573 dB
# SSIM: 0.97643
# PSNR: 50.88726310307047 dB
# SSIM: 0.99215
# PSNR: 42.972645998929565 dB
# SSIM: 0.97229
# PSNR: 36.49247642610292 dB
# SSIM: 0.94209
# PSNR: 45.61202478226523 dB
# SSIM: 0.98336
# PSNR: 43.24041256544716 dB
# SSIM: 0.97229
# PSNR: 39.491870018423505 dB
# SSIM: 0.91833
# PSNR: 41.8257704714447 dB
# SSIM: 0.96117
# PSNR: 34.24849527481589 dB
# SSIM: 0.94351
# PSNR: 44.80662655172138 dB
# SSIM: 0.97840
# PSNR: 45.77615823693662 dB
# SSIM: 0.98108
# PSNR: 43.8062462916405 dB
# SSIM: 0.97071
# PSNR: 42.364930856956605 dB
# SSIM: 0.96611
# PSNR: 40.325320474125604 dB
# SSIM: 0.93147
# PSNR: 40.40360094291829 dB
# SSIM: 0.95134
# PSNR: 44.744318336242024 dB
# SSIM: 0.98116
# PSNR: 41.926236041949124 dB
# SSIM: 0.95600
# PSNR: 32.21827525326223 dB
# SSIM: 0.90214
# PSNR: 41.38703700233465 dB
# SSIM: 0.95160
# PSNR: 47.65660738202441 dB
# SSIM: 0.98942
# PSNR: 45.08598300764831 dB
# SSIM: 0.97333
# PSNR: 33.1783361882762 dB
# SSIM: 0.95616
# PSNR: 42.059965975370375 dB
# SSIM: 0.96307
# PSNR: 43.29523794223462 dB
# SSIM: 0.97006
# PSNR: 47.17667934835171 dB
# SSIM: 0.97928
# PSNR: 45.52196020486107 dB
# SSIM: 0.97975
# PSNR: 44.76559921151329 dB
# SSIM: 0.98022
# PSNR: 40.92557261378466 dB
# SSIM: 0.95672
# PSNR: 44.97975841743325 dB
# SSIM: 0.98229
# PSNR: 43.490388292651204 dB
# SSIM: 0.97785
# PSNR: 42.26849653860499 dB
# SSIM: 0.95829
# PSNR: 41.24475009772573 dB
# SSIM: 0.96842
# PSNR: 35.99789474231372 dB
# SSIM: 0.87050
# PSNR: 45.01451942388502 dB
# SSIM: 0.97718
# PSNR: 46.80249994144639 dB
# SSIM: 0.98656
# PSNR: 43.158329392770305 dB
# SSIM: 0.96571
# PSNR: 41.69296570648929 dB
# SSIM: 0.95966
# PSNR: 44.341246876033615 dB
# SSIM: 0.98021
# PSNR: 52.454160391025006 dB
# SSIM: 0.99588
# PSNR: 40.44213132618129 dB
# SSIM: 0.94483
# PSNR: 32.99938440389943 dB
# SSIM: 0.94243
# PSNR: 34.63490215956909 dB
# SSIM: 0.94229
# PSNR: 45.482273883867904 dB
# SSIM: 0.98045
# PSNR: 46.33330360015933 dB
# SSIM: 0.99008
# PSNR: 42.1593367196803 dB
# SSIM: 0.96215
# PSNR: 41.05832462467906 dB
# SSIM: 0.95108
# PSNR: 45.33793687302368 dB
# SSIM: 0.98439
# PSNR: 35.1014514610541 dB
# SSIM: 0.94970
# PSNR: 40.62674004949166 dB
# SSIM: 0.94814
# PSNR: 38.90755165948566 dB
# SSIM: 0.96791
# PSNR: 41.01202022778109 dB
# SSIM: 0.94875
# PSNR: 37.19887503363396 dB
# SSIM: 0.95189
# PSNR: 46.233967204930764 dB
# SSIM: 0.98114
# PSNR: 41.58140462896988 dB
# SSIM: 0.95407
# PSNR: 34.798793064477 dB
# SSIM: 0.94215
# PSNR: 44.05257774318254 dB
# SSIM: 0.97226
# PSNR: 42.57575527196623 dB
# SSIM: 0.96815
# PSNR: 44.35307807745518 dB
# SSIM: 0.97185
# PSNR: 45.57048155767811 dB
# SSIM: 0.98620
# PSNR: 49.562229226794955 dB
# SSIM: 0.99486
# PSNR: 48.275441071778616 dB
# SSIM: 0.98662
# PSNR: 43.6505965072158 dB
# SSIM: 0.97568
# PSNR: 48.5970314313705 dB
# SSIM: 0.99023
# PSNR: 43.310630894953505 dB
# SSIM: 0.96152
# PSNR: 34.36330194664398 dB
# SSIM: 0.93916
# PSNR: 46.90417257538728 dB
# SSIM: 0.98491
# PSNR: 37.694725505722545 dB
# SSIM: 0.93792
# PSNR: 46.07719350468787 dB
# SSIM: 0.98039
# PSNR: 32.03589279179284 dB
# SSIM: 0.91735
# PSNR: 44.076003767164195 dB
# SSIM: 0.97432
# PSNR: 33.83112512662515 dB
# SSIM: 0.95293
# PSNR: 45.67457360677907 dB
# SSIM: 0.98235
# PSNR: 46.4974947707186 dB
# SSIM: 0.98902
# PSNR: 41.81218354772976 dB
# SSIM: 0.96340
# PSNR: 51.948583519281414 dB
# SSIM: 0.99916
# PSNR: 47.92424479125003 dB
# SSIM: 0.99222
# PSNR: 42.450808313526295 dB
# SSIM: 0.96207
# PSNR: 42.05214506318343 dB
# SSIM: 0.95073
# PSNR: 44.024211822098884 dB
# SSIM: 0.97017
# PSNR: 39.83295470214878 dB
# SSIM: 0.93092
# PSNR: 37.56394753315063 dB
# SSIM: 0.98262
# PSNR: 31.955830908094253 dB
# SSIM: 0.90130
# PSNR: 45.460911169686405 dB
# SSIM: 0.98498
# PSNR: 43.57102130475162 dB
# SSIM: 0.97346
# PSNR: 62.964490282161876 dB
# SSIM: 0.99977
# PSNR: 37.741736047369386 dB
# SSIM: 0.94572
# PSNR: 45.573974331053336 dB
# SSIM: 0.97385
# PSNR: 44.67685409085858 dB
# SSIM: 0.97725
# PSNR: 41.59497394767844 dB
# SSIM: 0.94855
# PSNR: 40.04266022275086 dB
# SSIM: 0.93921
# PSNR: 42.776648242814794 dB
# SSIM: 0.96454
# PSNR: 36.08874652346222 dB
# SSIM: 0.94799
# PSNR: 42.122585849047496 dB
# SSIM: 0.96240
# PSNR: 42.53502486613783 dB
# SSIM: 0.96683
# PSNR: 46.42026598954432 dB
# SSIM: 0.98646
# PSNR: 33.22218245044741 dB
# SSIM: 0.91970
# PSNR: 67.6782679995895 dB
# SSIM: 0.99997
# PSNR: 43.280622339293515 dB
# SSIM: 0.96819
# PSNR: 45.732463300590574 dB
# SSIM: 0.98382
# PSNR: 38.94907117702432 dB
# SSIM: 0.93369
# PSNR: 43.28238692619735 dB
# SSIM: 0.96487
# PSNR: 42.23606946833791 dB
# SSIM: 0.95940
# PSNR: 42.33179590193642 dB
# SSIM: 0.95223
# PSNR: 34.08590313214694 dB
# SSIM: 0.96709
# PSNR: 43.31362424381794 dB
# SSIM: 0.97029
# PSNR: 42.35534942128072 dB
# SSIM: 0.96298
# PSNR: 35.716352853097035 dB
# SSIM: 0.94831
# PSNR: 40.030515778009025 dB
# SSIM: 0.93653
# PSNR: 46.70134090710175 dB
# SSIM: 0.98337
# PSNR: 45.77365427342489 dB
# SSIM: 0.98790
# PSNR: 34.29992508131328 dB
# SSIM: 0.91158
# PSNR: 42.86279083154848 dB
# SSIM: 0.96616
# PSNR: 34.499129583909586 dB
# SSIM: 0.92372
# PSNR: 42.125993121156384 dB
# SSIM: 0.96282
# PSNR: 34.185419701478196 dB
# SSIM: 0.95442
# PSNR: 43.01236422689311 dB
# SSIM: 0.96999
# PSNR: 44.362909524319576 dB
# SSIM: 0.97339
# PSNR: 32.50551355770805 dB
# SSIM: 0.92583
# PSNR: 31.80984485611079 dB
# SSIM: 0.92003
# PSNR: 41.55740125219764 dB
# SSIM: 0.94861
# PSNR: 44.46095889496122 dB
# SSIM: 0.98309
# PSNR: 42.19128944820744 dB
# SSIM: 0.95199
# PSNR: 39.78917380310007 dB
# SSIM: 0.94124
# PSNR: 48.11847317741939 dB
# SSIM: 0.99065
# PSNR: 46.474127293487896 dB
# SSIM: 0.98517
# PSNR: 42.28899715393533 dB
# SSIM: 0.96357
# PSNR: 43.94108442032006 dB
# SSIM: 0.97721
# PSNR: 37.09428613464231 dB
# SSIM: 0.94600
# PSNR: 40.786893320254705 dB
# SSIM: 0.94817
# PSNR: 42.5035935549754 dB
# SSIM: 0.96674
# PSNR: 35.87280183993249 dB
# SSIM: 0.86494
# PSNR: 33.189081098805474 dB
# SSIM: 0.95076
# PSNR: 42.25311727613402 dB
# SSIM: 0.96532
# PSNR: 34.5342850017576 dB
# SSIM: 0.91003
# PSNR: 42.95874606744081 dB
# SSIM: 0.97073
# PSNR: 44.1843975023356 dB
# SSIM: 0.97361
# PSNR: 42.46932782611481 dB
# SSIM: 0.96041
# PSNR: 43.87754905136138 dB
# SSIM: 0.97585
# PSNR: 45.242318103933 dB
# SSIM: 0.98006
# PSNR: 41.515236408186 dB
# SSIM: 0.94763
# PSNR: 45.028554009691135 dB
# SSIM: 0.98349
# PSNR: 42.83220359113132 dB
# SSIM: 0.96856
# PSNR: 41.99321250289914 dB
# SSIM: 0.96038
# PSNR: 41.2306743573824 dB
# SSIM: 0.95259
# PSNR: 43.400203893502784 dB
# SSIM: 0.97331
# PSNR: 40.611223128978835 dB
# SSIM: 0.94067
# PSNR: 42.98671219102482 dB
# SSIM: 0.97248
# PSNR: 42.28146538248239 dB
# SSIM: 0.96178
# PSNR: 36.18294425974074 dB
# SSIM: 0.90132
# PSNR: 34.534974072690005 dB
# SSIM: 0.93643
# PSNR: 48.31796631623323 dB
# SSIM: 0.99074
# PSNR: 31.79996584573631 dB
# SSIM: 0.95519
# PSNR: 38.57368941582137 dB
# SSIM: 0.95493
# PSNR: 44.05669087978036 dB
# SSIM: 0.97529
# PSNR: 42.12459664735527 dB
# SSIM: 0.96314
# PSNR: 43.67551632172255 dB
# SSIM: 0.96987
# PSNR: 47.00490644893782 dB
# SSIM: 0.98465
# PSNR: 42.8870917503211 dB
# SSIM: 0.96492
# PSNR: 36.53075810564266 dB
# SSIM: 0.96160
# PSNR: 34.69363967520964 dB
# SSIM: 0.94174
# PSNR: 36.424776480255176 dB
# SSIM: 0.97598
# PSNR: 46.09153426891567 dB
# SSIM: 0.98633
# PSNR: 46.99863846619874 dB
# SSIM: 0.98838
# PSNR: 32.79508202253804 dB
# SSIM: 0.94186
# PSNR: 30.814750474186773 dB
# SSIM: 0.92036
# PSNR: 43.12766197648217 dB
# SSIM: 0.96802
# PSNR: 43.68388653952814 dB
# SSIM: 0.97351
# PSNR: 31.948394109830765 dB
# SSIM: 0.90129
# PSNR: 45.34466526667511 dB
# SSIM: 0.98430
# PSNR: 42.55046564513799 dB
# SSIM: 0.96420
# PSNR: 33.98212884808818 dB
# SSIM: 0.95789
# PSNR: 43.507792622797545 dB
# SSIM: 0.97404
# PSNR: 39.20269973439055 dB
# SSIM: 0.96672
# PSNR: 44.5763014252475 dB
# SSIM: 0.98321
# PSNR: 40.788611982269025 dB
# SSIM: 0.93665
# PSNR: 46.39591647690455 dB
# SSIM: 0.98803
# PSNR: 46.10647689277695 dB
# SSIM: 0.98344
# PSNR: 36.3974041328637 dB
# SSIM: 0.92986
# PSNR: 52.96718024497258 dB
# SSIM: 0.99826
# PSNR: 78.23380317507723 dB
# SSIM: 1.00000
# PSNR: 47.14165733279587 dB
# SSIM: 0.98291
# PSNR: 52.70281467268126 dB
# SSIM: 0.99689
# PSNR: 42.49209735980787 dB
# SSIM: 0.96680
# PSNR: 36.515434459691825 dB
# SSIM: 0.86948
# PSNR: 37.36415928778491 dB
# SSIM: 0.96003
# PSNR: 40.72991665845913 dB
# SSIM: 0.93828
# PSNR: 44.53982768758542 dB
# SSIM: 0.96456
# PSNR: 35.295589386710596 dB
# SSIM: 0.97287
# PSNR: 40.812572903817745 dB
# SSIM: 0.93923
# PSNR: 44.90380415294293 dB
# SSIM: 0.97852
# PSNR: 42.13458687900208 dB
# SSIM: 0.96129
# PSNR: 41.64598552835892 dB
# SSIM: 0.95784
# PSNR: 46.056044741749034 dB
# SSIM: 0.97829
# PSNR: 44.488524960626286 dB
# SSIM: 0.97540
# PSNR: 32.578388306773846 dB
# SSIM: 0.89330
# PSNR: 50.83676148961337 dB
# SSIM: 0.99714
# PSNR: 46.351786081311126 dB
# SSIM: 0.97977
# PSNR: 46.57876323523014 dB
# SSIM: 0.98551
# PSNR: 40.62255469830281 dB
# SSIM: 0.94382
# PSNR: 39.24028411181271 dB
# SSIM: 0.91127
# PSNR: 42.418258954674585 dB
# SSIM: 0.96083
# PSNR: 47.903798367267626 dB
# SSIM: 0.98962
# PSNR: 36.19753012534375 dB
# SSIM: 0.96062
# PSNR: 48.54671232795643 dB
# SSIM: 0.99381
# PSNR: 46.611006927310555 dB
# SSIM: 0.98867
# PSNR: 34.45465739586254 dB
# SSIM: 0.94395
# PSNR: 46.03122367045948 dB
# SSIM: 0.98479
# PSNR: 42.258645253033684 dB
# SSIM: 0.95891
# PSNR: 33.08042569566235 dB
# SSIM: 0.97026
# PSNR: 46.175981587370444 dB
# SSIM: 0.98604
# PSNR: 56.7683240835278 dB
# SSIM: 0.99622
# PSNR: 44.598574538962026 dB
# SSIM: 0.96807
# PSNR: 37.77917568602818 dB
# SSIM: 0.93294
# PSNR: 46.36571077849215 dB
# SSIM: 0.98593
# PSNR: 42.727717409703104 dB
# SSIM: 0.96770
# PSNR: 45.751425984926605 dB
# SSIM: 0.98606
# PSNR: 45.25836369503586 dB
# SSIM: 0.97840
# PSNR: 32.67034967460155 dB
# SSIM: 0.91981
# PSNR: 33.02273166396019 dB
# SSIM: 0.93778
# PSNR: 31.687925562001688 dB
# SSIM: 0.95393
# PSNR: 55.59756575799875 dB
# SSIM: 1.00000
# PSNR: 42.202139464255865 dB
# SSIM: 0.96268
# PSNR: 33.28948940275307 dB
# SSIM: 0.94313
# PSNR: 44.76510051787123 dB
# SSIM: 0.97504
# PSNR: 40.75495335996969 dB
# SSIM: 0.97335
# PSNR: 40.13642488887517 dB
# SSIM: 0.93398
# PSNR: 38.91180927397115 dB
# SSIM: 0.91956
# PSNR: 32.417417813295316 dB
# SSIM: 0.94647
# PSNR: 45.29206980624011 dB
# SSIM: 0.97940
# PSNR: 46.3494842900814 dB
# SSIM: 0.98540
# PSNR: 43.0973828880846 dB
# SSIM: 0.96254
# PSNR: 45.91584300601586 dB
# SSIM: 0.98458
# PSNR: 33.39049479422074 dB
# SSIM: 0.93340
# PSNR: 41.561896354677394 dB
# SSIM: 0.95342
# PSNR: 41.20530355951725 dB
# SSIM: 0.93129
# PSNR: 43.22471640238892 dB
# SSIM: 0.96882
# PSNR: 41.659280569536044 dB
# SSIM: 0.95509
# PSNR: 31.430937764281417 dB
# SSIM: 0.94441
# PSNR: 31.80877000623356 dB
# SSIM: 0.91251
# PSNR: 33.285488985063466 dB
# SSIM: 0.95169
# PSNR: 34.43142969902918 dB
# SSIM: 0.91913
# PSNR: 44.245906471644005 dB
# SSIM: 0.97345
# PSNR: 33.02049670059396 dB
# SSIM: 0.94143
# PSNR: 42.97110385205619 dB
# SSIM: 0.96539
# PSNR: 38.059949960999816 dB
# SSIM: 0.96963
# PSNR: 52.60362994071294 dB
# SSIM: 0.99640
# PSNR: 42.680137640552346 dB
# SSIM: 0.96903
# PSNR: 40.86298715135315 dB
# SSIM: 0.94485
# PSNR: 46.99821298012911 dB
# SSIM: 0.98984
# PSNR: 40.277667491652636 dB
# SSIM: 0.94259
# PSNR: 42.178199649243815 dB
# SSIM: 0.96432
# PSNR: 42.78185346395823 dB
# SSIM: 0.97184
# PSNR: 41.0610041488066 dB
# SSIM: 0.94196
# PSNR: 42.90240715514174 dB
# SSIM: 0.95357
# PSNR: 44.955543419929555 dB
# SSIM: 0.97611
# PSNR: 32.698235638986084 dB
# SSIM: 0.94703
# PSNR: 43.34116350717014 dB
# SSIM: 0.97144
# PSNR: 43.571802150609855 dB
# SSIM: 0.97661
# PSNR: 42.23657543862853 dB
# SSIM: 0.94736
# PSNR: 58.108506512526866 dB
# SSIM: 0.99929
# PSNR: 44.07626428497639 dB
# SSIM: 0.97631
# PSNR: 31.676098974092106 dB
# SSIM: 0.94509
# PSNR: 39.24303134052993 dB
# SSIM: 0.96561
# PSNR: 46.41078628667628 dB
# SSIM: 0.98524
# PSNR: 35.425775883223565 dB
# SSIM: 0.95122
# PSNR: 42.9302051073807 dB
# SSIM: 0.96629
# PSNR: 44.37815933900463 dB
# SSIM: 0.97160
# PSNR: 45.00705640161566 dB
# SSIM: 0.98142
# PSNR: 49.91250779789688 dB
# SSIM: 0.99151
# PSNR: 53.2128763969194 dB
# SSIM: 0.99997
# PSNR: 45.01944795282097 dB
# SSIM: 0.98183
# PSNR: 37.27789847980245 dB
# SSIM: 0.91868
# PSNR: 46.59179317818493 dB
# SSIM: 0.98653
# PSNR: 41.04999744211574 dB
# SSIM: 0.95803
# PSNR: 38.67183863771915 dB
# SSIM: 0.94231
# PSNR: 40.52933729212106 dB
# SSIM: 0.93630
# PSNR: 31.67744588470775 dB
# SSIM: 0.93044
# PSNR: 42.71101305870771 dB
# SSIM: 0.95848
# PSNR: 43.61125860181917 dB
# SSIM: 0.97773
# PSNR: 42.82460008764155 dB
# SSIM: 0.97029
# PSNR: 33.37113261183029 dB
# SSIM: 0.91956
# PSNR: 33.16295035162321 dB
# SSIM: 0.92023
# PSNR: 45.04797479775676 dB
# SSIM: 0.98181
# PSNR: 45.437644604283484 dB
# SSIM: 0.98398
# PSNR: 43.69682231437284 dB
# SSIM: 0.97612
# PSNR: 41.46435346990782 dB
# SSIM: 0.95773
# PSNR: 40.53688817087967 dB
# SSIM: 0.94255
# PSNR: 47.13390701493702 dB
# SSIM: 0.98719
# PSNR: 46.351786081311126 dB
# SSIM: 0.98142
# PSNR: 43.86628140846141 dB
# SSIM: 0.96378
# PSNR: 34.578498256287354 dB
# SSIM: 0.94298
# PSNR: 35.60447687038166 dB
# SSIM: 0.96410
# PSNR: 42.11950775257171 dB
# SSIM: 0.95115
# PSNR: 44.018149483226416 dB
# SSIM: 0.97665
# PSNR: 44.45371570619828 dB
# SSIM: 0.96760
# PSNR: 47.478010437397515 dB
# SSIM: 0.98725
# PSNR: 45.44178129724803 dB
# SSIM: 0.98290
# PSNR: 41.45231025537541 dB
# SSIM: 0.97105
# PSNR: 36.3811106940813 dB
# SSIM: 0.93774
# PSNR: 45.66203160228361 dB
# SSIM: 0.98294
# PSNR: 35.39089553383006 dB
# SSIM: 0.96390
# PSNR: 40.18551839027544 dB
# SSIM: 0.92658
# PSNR: 40.944650048111384 dB
# SSIM: 0.93836
# PSNR: 43.35111702012262 dB
# SSIM: 0.97876
# PSNR: 54.200720860777814 dB
# SSIM: 0.99866
# PSNR: 42.381911069089114 dB
# SSIM: 0.96575
# PSNR: 42.65562443531519 dB
# SSIM: 0.96143
# PSNR: 43.442063008886535 dB
# SSIM: 0.96959
# PSNR: 46.293258357687314 dB
# SSIM: 0.98394
# PSNR: 41.91523991406921 dB
# SSIM: 0.96231
# PSNR: 44.205191487067175 dB
# SSIM: 0.97018
# PSNR: 43.00066138935741 dB
# SSIM: 0.96310
# PSNR: 32.760271289074225 dB
# SSIM: 0.90890
# PSNR: 52.766256479321896 dB
# SSIM: 0.99871
# PSNR: 44.687707352389516 dB
# SSIM: 0.97899
# PSNR: 46.39382809893888 dB
# SSIM: 0.98865
# PSNR: 32.07524204460044 dB
# SSIM: 0.95382
# PSNR: 46.146367263508196 dB
# SSIM: 0.98281
# PSNR: 43.31028872127101 dB
# SSIM: 0.96032
# PSNR: 42.393761387728006 dB
# SSIM: 0.96637
# PSNR: 42.478731496633316 dB
# SSIM: 0.96578
# PSNR: 45.925044965506075 dB
# SSIM: 0.98059
# PSNR: 34.767348144984844 dB
# SSIM: 0.91572
# PSNR: 39.48531126039721 dB
# SSIM: 0.93327
# PSNR: 40.70780544086243 dB
# SSIM: 0.93963
# PSNR: 52.701802036169745 dB
# SSIM: 0.99988
# PSNR: 50.742723286037936 dB
# SSIM: 0.99536
# PSNR: 47.94995482756546 dB
# SSIM: 0.98688
# PSNR: 35.92600745046462 dB
# SSIM: 0.96360
# PSNR: 32.91040650482352 dB
# SSIM: 0.96658
# PSNR: 46.81630143419105 dB
# SSIM: 0.98930
# PSNR: 41.76699424875466 dB
# SSIM: 0.95189
# PSNR: 44.645089620455906 dB
# SSIM: 0.96749
# PSNR: 44.49394258852994 dB
# SSIM: 0.97582
# PSNR: 37.81901481146923 dB
# SSIM: 0.94390
# PSNR: 46.08564055097402 dB
# SSIM: 0.97594
# PSNR: 36.681879297404045 dB
# SSIM: 0.90977
# PSNR: 43.98260646076559 dB
# ...
# SSIM: 0.97733
# PSNR: 40.655123828156306 dB
# SSIM: 0.95462
# PSNR: 41.425445354569554 dB
# SSIM: 0.95257
# PSNR: 40.671567852757 dB
# SSIM: 0.94316
# PSNR: 48.11340998147898 dB
# SSIM: 0.98238
# PSNR: 41.42907880873204 dB
# SSIM: 0.95880
# PSNR: 32.48916840315711 dB
# SSIM: 0.93251
# PSNR: 42.14315872477517 dB
# SSIM: 0.96170
# PSNR: 38.69001860994934 dB
# SSIM: 0.91988
# PSNR: 42.820728526278096 dB
# SSIM: 0.95433
# PSNR: 41.90329208135044 dB
# SSIM: 0.96250
# PSNR: 43.95170412963993 dB
# SSIM: 0.97760
# PSNR: 41.65916608339059 dB
# SSIM: 0.95408
# PSNR: 42.767695438180986 dB
# SSIM: 0.96320
# PSNR: 45.477055230494955 dB
# SSIM: 0.97023
# PSNR: 35.03419464331804 dB
# SSIM: 0.94406
# PSNR: 45.99870856430456 dB
# SSIM: 0.97992
# PSNR: 50.14368024117644 dB
# SSIM: 0.98966
# PSNR: 42.96899018241034 dB
# SSIM: 0.97554
# PSNR: 39.35723757112758 dB
# SSIM: 0.92230
# PSNR: 44.75326065657455 dB
# SSIM: 0.98212
# PSNR: 31.12467369182356 dB
# SSIM: 0.92269
# PSNR: 46.379134199704744 dB
# SSIM: 0.98702
# PSNR: 42.075825497429015 dB
# SSIM: 0.96532
# PSNR: 31.82429197583003 dB
# SSIM: 0.95805
# PSNR: 44.18198542517332 dB
# SSIM: 0.97282
# PSNR: 44.02702721202886 dB
# SSIM: 0.97628
# PSNR: 45.5378225446512 dB
# SSIM: 0.98306
# PSNR: 45.762948469926634 dB
# SSIM: 0.98747
# PSNR: 43.39533846426896 dB
# SSIM: 0.97570
# PSNR: 39.17543133922267 dB
# SSIM: 0.96087
# PSNR: 35.02300276794911 dB
# SSIM: 0.96317
# PSNR: 34.91391955867542 dB
# SSIM: 0.95290
# PSNR: 41.529638850100596 dB
# SSIM: 0.95297
# PSNR: 44.47816717080855 dB
# SSIM: 0.97715
# PSNR: 40.859089560839834 dB
# SSIM: 0.94407
# PSNR: 45.7659844418287 dB
# SSIM: 0.98597
# PSNR: 37.856291746601855 dB
# SSIM: 0.96952
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 34.00162099996332 dB
# SSIM: 0.92018
# PSNR: 38.069509472536964 dB
# SSIM: 0.94053
# PSNR: 41.166954213534964 dB
# SSIM: 0.95505
# PSNR: 38.63893226596153 dB
# SSIM: 0.95149
# PSNR: 37.21250813097492 dB
# SSIM: 0.95057
# PSNR: 42.402618708780444 dB
# SSIM: 0.95957
# PSNR: 46.02938515633088 dB
# SSIM: 0.98542
# PSNR: 42.807059295458956 dB
# SSIM: 0.96141
# PSNR: 43.81126802411352 dB
# SSIM: 0.96683
# PSNR: 41.35265595144939 dB
# SSIM: 0.95608
# PSNR: 42.14235752453827 dB
# SSIM: 0.96520
# PSNR: 47.151042994704994 dB
# SSIM: 0.98352
# PSNR: 51.64663566571391 dB
# SSIM: 0.99543
# PSNR: 43.45304062519337 dB
# SSIM: 0.97723
# PSNR: 42.47155380351857 dB
# SSIM: 0.96446
# PSNR: 47.26139281143837 dB
# SSIM: 0.98345
# PSNR: 45.968623066538896 dB
# SSIM: 0.98063
# PSNR: 34.15154224535278 dB
# SSIM: 0.90408
# PSNR: 46.437073673288026 dB
# SSIM: 0.98811
# PSNR: 41.001209535846385 dB
# SSIM: 0.94863
# PSNR: 40.53424041214488 dB
# SSIM: 0.94338
# PSNR: 42.13644767728495 dB
# SSIM: 0.96726
# PSNR: 49.07538211798452 dB
# SSIM: 0.99500
# PSNR: 42.58497973440137 dB
# SSIM: 0.96017
# PSNR: 44.45179317124966 dB
# SSIM: 0.98019
# PSNR: 46.148060078512515 dB
# SSIM: 0.98516
# PSNR: 35.20289267793412 dB
# SSIM: 0.94252
# PSNR: 67.58961329177234 dB
# SSIM: 0.99990
# PSNR: 44.655079762669054 dB
# SSIM: 0.98011
# PSNR: 35.07112742041254 dB
# SSIM: 0.90700
# PSNR: 46.888297003684805 dB
# SSIM: 0.98800
# PSNR: 42.96669592869019 dB
# SSIM: 0.97076
# PSNR: 33.513431086935555 dB
# SSIM: 0.93098
# PSNR: 33.944065430857115 dB
# SSIM: 0.93744
# PSNR: 45.03210222044841 dB
# SSIM: 0.98184
# PSNR: 48.57023447104659 dB
# SSIM: 0.98988
# PSNR: 43.91424660963946 dB
# SSIM: 0.97937
# PSNR: 47.721614495824234 dB
# SSIM: 0.99213
# PSNR: 34.692913956277714 dB
# SSIM: 0.91124
# PSNR: 48.645477708179214 dB
# SSIM: 0.99309
# PSNR: 48.1908133985132 dB
# SSIM: 0.99250
# PSNR: 39.90631305270244 dB
# SSIM: 0.98039
# PSNR: 45.14860367164531 dB
# SSIM: 0.98588
# PSNR: 44.08270404004399 dB
# SSIM: 0.97384
# PSNR: 32.080011124190825 dB
# SSIM: 0.91530
# PSNR: 42.0619152141233 dB
# SSIM: 0.95636
# PSNR: 39.91117628015185 dB
# SSIM: 0.93455
# PSNR: 45.81167695231809 dB
# SSIM: 0.98474
# PSNR: 34.61916718329906 dB
# SSIM: 0.95070
# PSNR: 44.4520393597368 dB
# SSIM: 0.98243
# PSNR: 43.58160945982063 dB
# SSIM: 0.97101
# PSNR: 44.02586821771899 dB
# SSIM: 0.97424
# PSNR: 42.1850149046345 dB
# SSIM: 0.96605
# PSNR: 47.22559411095584 dB
# SSIM: 0.98429
# PSNR: 43.88393320277235 dB
# SSIM: 0.97709
# PSNR: 48.38651467786286 dB
# SSIM: 0.99243
# PSNR: 47.60974624932844 dB
# SSIM: 0.99335
# PSNR: 42.740366184465096 dB
# SSIM: 0.95614
# PSNR: 35.614006614294226 dB
# SSIM: 0.97627
# PSNR: 46.15314248613386 dB
# SSIM: 0.98790
# PSNR: 46.202099778162626 dB
# SSIM: 0.98742
# PSNR: 42.932346692709984 dB
# SSIM: 0.96958
# PSNR: 42.64763609372353 dB
# SSIM: 0.95706
# PSNR: 34.81062007393231 dB
# SSIM: 0.94511
# PSNR: 43.333442505979434 dB
# SSIM: 0.96848
# PSNR: 41.6585190445172 dB
# SSIM: 0.95164
# PSNR: 42.45735354388393 dB
# SSIM: 0.96437
# PSNR: 47.39762002753884 dB
# SSIM: 0.98803
# PSNR: 45.71996878802424 dB
# SSIM: 0.98177
# PSNR: 45.61673961118903 dB
# SSIM: 0.98271
# PSNR: 36.265322585255475 dB
# SSIM: 0.86881
# PSNR: 40.94675335320548 dB
# SSIM: 0.94756
# PSNR: 34.6752000285917 dB
# SSIM: 0.93263
# PSNR: 43.545985099432386 dB
# SSIM: 0.96936
# PSNR: 45.78306123861288 dB
# SSIM: 0.98076
# PSNR: 46.23887971587081 dB
# SSIM: 0.98477
# PSNR: 43.398361074461405 dB
# SSIM: 0.97936
# PSNR: 35.98855078056459 dB
# SSIM: 0.93527
# PSNR: 33.52740322952397 dB
# SSIM: 0.92055
# PSNR: 40.35818011809954 dB
# SSIM: 0.95394
# PSNR: 42.627894154340176 dB
# SSIM: 0.96619
# PSNR: 45.53715387090057 dB
# SSIM: 0.97786
# PSNR: 40.87853357117419 dB
# SSIM: 0.94076
# PSNR: 45.708711379857164 dB
# SSIM: 0.98360
# PSNR: 38.9803034939257 dB
# SSIM: 0.93328
# PSNR: 34.81179570155818 dB
# SSIM: 0.95054
# PSNR: 42.83095823311092 dB
# SSIM: 0.96972
# PSNR: 39.75061278118867 dB
# SSIM: 0.92944
# PSNR: 40.862920850647946 dB
# SSIM: 0.92905
# PSNR: 44.66735107811622 dB
# SSIM: 0.97893
# PSNR: 55.93917127671264 dB
# SSIM: 0.99779
# PSNR: 47.149703460899 dB
# SSIM: 0.98658
# PSNR: 45.681015292542384 dB
# SSIM: 0.98532
# PSNR: 44.905338461648995 dB
# SSIM: 0.97461
# PSNR: 43.397128011348684 dB
# SSIM: 0.97868
# PSNR: 43.758484174770025 dB
# SSIM: 0.97346
# PSNR: 43.15439455370387 dB
# SSIM: 0.96019
# PSNR: 43.96104732395081 dB
# SSIM: 0.97359
# PSNR: 41.550973171934935 dB
# SSIM: 0.95973
# PSNR: 44.99585902887644 dB
# SSIM: 0.98371
# PSNR: inf dB
# SSIM: 1.00000
# PSNR: 43.27269055874808 dB
# SSIM: 0.96942
# PSNR: 31.58101643899021 dB
# SSIM: 0.89386
# PSNR: 36.955263460033564 dB
# SSIM: 0.89844
# PSNR: 39.34883154784003 dB
# SSIM: 0.91855
# PSNR: 31.684796527397147 dB
# SSIM: 0.91891
# PSNR: 36.579792447078894 dB
# SSIM: 0.87915
# PSNR: 37.50390410386256 dB
# SSIM: 0.90732
# PSNR: 45.60201810640179 dB
# SSIM: 0.97851
# PSNR: 48.29585996845229 dB
# SSIM: 0.98990
# PSNR: 41.90900353684394 dB
# SSIM: 0.94840
# PSNR: 42.54535941634026 dB
# SSIM: 0.95733
# PSNR: 43.95067473586401 dB
# SSIM: 0.97108
# PSNR: 43.198591667120844 dB
# SSIM: 0.97181
# PSNR: 32.38784042816303 dB
# SSIM: 0.92717
# PSNR: 35.407543108357395 dB
# SSIM: 0.93358
# PSNR: 42.42002594133537 dB
# SSIM: 0.96756
# PSNR: 31.6778742848391 dB
# SSIM: 0.94762
# PSNR: 34.930020603464015 dB
# SSIM: 0.97941
# PSNR: 43.58609863666696 dB
# SSIM: 0.98314
# PSNR: 40.24040845174727 dB
# SSIM: 0.94062
# PSNR: 42.08061112412005 dB
# SSIM: 0.95670
# PSNR: 34.890382121485224 dB
# SSIM: 0.92577
# PSNR: 42.04010855737489 dB
# SSIM: 0.96616
# PSNR: 52.97937319712172 dB
# SSIM: 0.99762
# PSNR: 45.91520636227969 dB
# SSIM: 0.98370
# PSNR: 41.959387135209724 dB
# SSIM: 0.95985
# PSNR: 45.97994297815277 dB
# SSIM: 0.98429
# PSNR: 40.97946423506073 dB
# SSIM: 0.95221
# PSNR: 33.678047878893324 dB
# SSIM: 0.96974
# PSNR: 44.99100006244162 dB
# SSIM: 0.98277
# PSNR: 42.843231776728004 dB
# SSIM: 0.97036
# PSNR: 31.047599681417672 dB
# SSIM: 0.91298
# PSNR: 34.968569259010074 dB
# SSIM: 0.96531
# PSNR: 44.2586848085498 dB
# SSIM: 0.97752
# PSNR: 42.22814082945517 dB
# SSIM: 0.96781
# PSNR: 39.62297909599444 dB
# SSIM: 0.96312
# PSNR: 43.59547184942977 dB
# SSIM: 0.96852
# PSNR: 45.27631154386982 dB
# SSIM: 0.98030
# PSNR: 41.11047667659601 dB
# SSIM: 0.94988
# PSNR: 45.19690512884238 dB
# SSIM: 0.98420
# PSNR: 41.250622439649824 dB
# SSIM: 0.94988
# PSNR: 41.769362558928556 dB
# SSIM: 0.95472
# PSNR: 42.421722450519454 dB
# SSIM: 0.95833
# PSNR: 37.04038324519376 dB
# SSIM: 0.93780
# PSNR: 45.61875828086963 dB
# SSIM: 0.98464
# PSNR: 44.08527913725598 dB
# SSIM: 0.97377
# PSNR: 44.43727382279219 dB
# SSIM: 0.96934
# PSNR: 33.37112153777388 dB
# SSIM: 0.92912
# PSNR: 40.817736934054565 dB
# SSIM: 0.94083
# PSNR: 38.7547454883541 dB
# SSIM: 0.94503
# PSNR: 47.14424384869598 dB
# SSIM: 0.98731
# PSNR: 50.67985895898921 dB
# SSIM: 0.99796
# PSNR: 39.77140525259643 dB
# SSIM: 0.92948
# PSNR: 42.75671617388717 dB
# SSIM: 0.96384
# PSNR: 45.946632408375265 dB
# SSIM: 0.97816
# PSNR: 46.32560021129826 dB
# SSIM: 0.99084
# PSNR: 38.49410583578106 dB
# SSIM: 0.92945
# PSNR: 40.300665857812106 dB
# SSIM: 0.94494
# PSNR: 33.02043745327189 dB
# SSIM: 0.92277
# PSNR: 45.11268002524457 dB
# SSIM: 0.97727
# PSNR: 38.804869998093366 dB
# SSIM: 0.97376
# PSNR: 42.58507830006481 dB
# SSIM: 0.96255
# PSNR: 39.835632735812126 dB
# SSIM: 0.93719
# PSNR: 43.779374804580506 dB
# SSIM: 0.96519
# PSNR: 40.18783054984424 dB
# SSIM: 0.93486
# PSNR: 41.8329503188835 dB
# SSIM: 0.95149
# PSNR: 32.33304553726721 dB
# SSIM: 0.95374
# PSNR: 41.043163164433814 dB
# SSIM: 0.95132
# PSNR: 40.267380588298984 dB
# SSIM: 0.93158
# PSNR: 44.71812479390522 dB
# SSIM: 0.97368
# PSNR: 42.04675389500774 dB
# SSIM: 0.95568
# PSNR: 41.913724843376 dB
# SSIM: 0.95897
# PSNR: 44.632723013448924 dB
# SSIM: 0.97637
# PSNR: 38.10928014512462 dB
# SSIM: 0.94690
# PSNR: 43.832217693327074 dB
# SSIM: 0.97379
# PSNR: 41.09464718308001 dB
# SSIM: 0.94221
# PSNR: 38.30961663232864 dB
# SSIM: 0.95845
# PSNR: 38.97560255950569 dB
# SSIM: 0.91478
# PSNR: 42.141968105583764 dB
# SSIM: 0.96064
# PSNR: 43.93757551374732 dB
# SSIM: 0.97830
# PSNR: 39.523345781739565 dB
# SSIM: 0.92605
# PSNR: 43.65191944019334 dB
# SSIM: 0.97400
# PSNR: 34.42852329775539 dB
# SSIM: 0.94324
# PSNR: 41.02085922524726 dB
# SSIM: 0.95725
# PSNR: 47.20842996127274 dB
# SSIM: 0.98706
# PSNR: 41.221992398090094 dB
# SSIM: 0.92834
# PSNR: 42.67146937392556 dB
# SSIM: 0.95931
# PSNR: 45.96650218647213 dB
# SSIM: 0.98735
# PSNR: 47.42487137604334 dB
# SSIM: 0.99120
# PSNR: 45.149448598220765 dB
# SSIM: 0.98292
# PSNR: 44.609940648482976 dB
# SSIM: 0.98627
# PSNR: 42.989287490376256 dB
# SSIM: 0.97066
# PSNR: 34.38682379682177 dB
# SSIM: 0.95289
# PSNR: 42.05510488170495 dB
# SSIM: 0.95678
# PSNR: 42.77256187946481 dB
# SSIM: 0.95898
# PSNR: 45.60280791896892 dB
# SSIM: 0.97983
# PSNR: 48.317113101277734 dB
# SSIM: 0.99146
# PSNR: 45.457197796567776 dB
# SSIM: 0.98206
# PSNR: 45.164730084172966 dB
# SSIM: 0.98236
# PSNR: 41.065061266729444 dB
# SSIM: 0.94639
# PSNR: 44.48194118348926 dB
# SSIM: 0.97708
# PSNR: 44.12553016657671 dB
# SSIM: 0.97295
# PSNR: 38.84404272567056 dB
# SSIM: 0.92160
# PSNR: 46.60565519618149 dB
# SSIM: 0.98708
# PSNR: 45.208487237353545 dB
# SSIM: 0.98204
# PSNR: 42.40936379477621 dB
# SSIM: 0.96652
# PSNR: 41.046952893368214 dB
# SSIM: 0.94753
# PSNR: 45.85913817178962 dB
# SSIM: 0.98259
# PSNR: 42.95628275066551 dB
# SSIM: 0.96473
# PSNR: 41.47478397392001 dB
# SSIM: 0.95964
# PSNR: 46.43993117412896 dB
# SSIM: 0.97834
# PSNR: 48.73837846588152 dB
# SSIM: 0.98998
# PSNR: 37.655245047310785 dB
# SSIM: 0.94957
# PSNR: 36.61890966887476 dB
# SSIM: 0.90718
# PSNR: 35.4341208260303 dB
# SSIM: 0.94172
# PSNR: 35.05234885854428 dB
# SSIM: 0.93250
# PSNR: 40.557622542607646 dB
# SSIM: 0.93587
# PSNR: 43.79056528849162 dB
# SSIM: 0.97450
# PSNR: 47.14686712825844 dB
# SSIM: 0.98187
# PSNR: 40.95599376829311 dB
# SSIM: 0.94867
# PSNR: 47.7769679902536 dB
# SSIM: 0.98950
# PSNR: 46.7200088959413 dB
# SSIM: 0.98639
# PSNR: 44.90852440850642 dB
# SSIM: 0.98022
# PSNR: 44.93007768576082 dB
# SSIM: 0.97840
# PSNR: 44.603660603365576 dB
# SSIM: 0.97902
# PSNR: 41.53381996205419 dB
# SSIM: 0.96050
# PSNR: 43.67534211361311 dB
# SSIM: 0.97551
# PSNR: 41.09433249213603 dB
# SSIM: 0.95086
# PSNR: 36.0100855809083 dB
# SSIM: 0.93769
# PSNR: 43.32890714439286 dB
# SSIM: 0.97214
# PSNR: 43.32304015041977 dB
# SSIM: 0.97026
# PSNR: 45.22150185352653 dB
# SSIM: 0.97875
# PSNR: 36.950594836177125 dB
# SSIM: 0.93419
# PSNR: 49.30920476449668 dB
# SSIM: 0.99338
# PSNR: 43.84341365285087 dB
# SSIM: 0.97786
# PSNR: 36.76307491837139 dB
# SSIM: 0.91818
# PSNR: 43.03049655377883 dB
# SSIM: 0.95887
# PSNR: 44.32832489179707 dB
# SSIM: 0.97827
# PSNR: 50.07332448713953 dB
# SSIM: 0.99413
# PSNR: 28.259173885360394 dB
# SSIM: 0.37196
# PSNR: 38.82504974067972 dB
# SSIM: 0.96715
# PSNR: 44.561564445621386 dB
# SSIM: 0.97527
# PSNR: 47.26260446211747 dB
# SSIM: 0.98687
# PSNR: 40.34606357636777 dB
# SSIM: 0.93720
# PSNR: 43.183625420356506 dB
# SSIM: 0.96625
# PSNR: 41.7821041594033 dB
# SSIM: 0.94847
# PSNR: 41.6468044195626 dB
# SSIM: 0.95436
# PSNR: 42.02052543947255 dB
# SSIM: 0.95818
# PSNR: 35.295138647610145 dB
# SSIM: 0.93498
# PSNR: 41.26381318727763 dB
# SSIM: 0.94984
# PSNR: 37.29274566536483 dB
# SSIM: 0.92144
# PSNR: 36.0896962822984 dB
# SSIM: 0.97648
# PSNR: 37.54291774327847 dB
# SSIM: 0.92378
# PSNR: 43.213267933795066 dB
# SSIM: 0.97153
# PSNR: 41.86955112526809 dB
# SSIM: 0.96108
# PSNR: 42.84561869829105 dB
# SSIM: 0.96967
# PSNR: 36.219702476262015 dB
# SSIM: 0.94742
# PSNR: 45.14312675442547 dB
# SSIM: 0.98696
# PSNR: 47.27265428918923 dB
# SSIM: 0.99010
# PSNR: 35.71899131417507 dB
# SSIM: 0.92242
# PSNR: 45.332216065977846 dB
# SSIM: 0.98610
# PSNR: 36.20248941940431 dB
# SSIM: 0.87191
# PSNR: 43.081476028792174 dB
# SSIM: 0.96691
# PSNR: 47.03801412609165 dB
# SSIM: 0.98686
# PSNR: 45.26325743727778 dB
# SSIM: 0.97775
# PSNR: 41.19426983791985 dB
# SSIM: 0.96776
# PSNR: 46.55902983090307 dB
# SSIM: 0.98576
# PSNR: 42.91273165912558 dB
# SSIM: 0.96426
# PSNR: 43.60287910293991 dB
# SSIM: 0.97593
# PSNR: 41.53078885874883 dB
# SSIM: 0.95677
# PSNR: 45.05728243198733 dB
# SSIM: 0.97657
# PSNR: 34.032161411761955 dB
# SSIM: 0.93555
# PSNR: 41.94553588150475 dB
# SSIM: 0.95539
# PSNR: 43.79964115031698 dB
# SSIM: 0.96887
# PSNR: 40.755854823240455 dB
# SSIM: 0.94923
# PSNR: 43.23939542363384 dB
# SSIM: 0.97017
# PSNR: 36.00650301958014 dB
# SSIM: 0.92985
# PSNR: 44.28610438480526 dB
# SSIM: 0.96490
# PSNR: 44.628243746592574 dB
# SSIM: 0.97931
# PSNR: 40.382567026691575 dB
# SSIM: 0.94219
# PSNR: 43.930532603693145 dB
# SSIM: 0.97592
# PSNR: 34.438113789652014 dB
# SSIM: 0.92380
# PSNR: 45.15069405287183 dB
# SSIM: 0.98086
# PSNR: 44.6650133777498 dB
# SSIM: 0.98047
# PSNR: 45.71020393551828 dB
# SSIM: 0.98038
# PSNR: 40.85701586165021 dB
# SSIM: 0.93347
# PSNR: 39.7024701017667 dB
# SSIM: 0.95531
# PSNR: 45.16118337526288 dB
# SSIM: 0.98137
# PSNR: 44.700041261895564 dB
# SSIM: 0.97699
# PSNR: 44.633364696409146 dB
# SSIM: 0.97614
# PSNR: 44.31746040058406 dB
# SSIM: 0.97499
# PSNR: 41.29149072546503 dB
# SSIM: 0.93765
# PSNR: 41.74738289688947 dB
# SSIM: 0.93949
# PSNR: 33.790862903795784 dB
# SSIM: 0.91632
# PSNR: 46.958419138380364 dB
# SSIM: 0.98739
# PSNR: 42.48759533398047 dB
# SSIM: 0.96038
# PSNR: 42.60986451668175 dB
# SSIM: 0.95871
# PSNR: 45.63287801928184 dB
# SSIM: 0.96922
# PSNR: 42.192476783919936 dB
# SSIM: 0.95377
# PSNR: 46.684034934158035 dB
# SSIM: 0.98545
# PSNR: 47.070026339905546 dB
# SSIM: 0.98727
# PSNR: 33.76573757720522 dB
# SSIM: 0.95811
# PSNR: 32.79073735221961 dB
# SSIM: 0.94054
# PSNR: 41.75736588164672 dB
# SSIM: 0.95967
# PSNR: 41.38118750851194 dB
# SSIM: 0.95281
# PSNR: 41.77344377741555 dB
# SSIM: 0.95915
# PSNR: 45.848036993048105 dB
# SSIM: 0.98355
# PSNR: 33.073542326007335 dB
# SSIM: 0.93051
# PSNR: 41.70762852834243 dB
# SSIM: 0.95554
# PSNR: 41.210485282189204 dB
# SSIM: 0.95302
# PSNR: 42.12706849030917 dB
# SSIM: 0.95442
# PSNR: 45.190839389894926 dB
# SSIM: 0.98029
# PSNR: 40.37950745644548 dB
# SSIM: 0.93066
# PSNR: 44.87483830418324 dB
# SSIM: 0.98245
# PSNR: 47.01981216094989 dB
# SSIM: 0.99031
# PSNR: 39.936016272999325 dB
# SSIM: 0.93797
# PSNR: 44.57518102105168 dB
# SSIM: 0.98192
# PSNR: 46.42536411303808 dB
# SSIM: 0.98546
# PSNR: 42.236677776865506 dB
# SSIM: 0.95844
# PSNR: 38.16682793463238 dB
# SSIM: 0.92071
# PSNR: 39.7144136856073 dB
# SSIM: 0.93350
# PSNR: 40.19390760807626 dB
# SSIM: 0.94249
# PSNR: 36.333743163634956 dB
# SSIM: 0.94742
# PSNR: 43.92669658768724 dB
# SSIM: 0.97540
# PSNR: 43.38579430093853 dB
# SSIM: 0.97377
# PSNR: 42.14155090973435 dB
# SSIM: 0.95316
# PSNR: 48.10369638043937 dB
# SSIM: 0.98935
# PSNR: 46.53745676010093 dB
# SSIM: 0.98177
# PSNR: 41.57278852497147 dB
# SSIM: 0.95958
# PSNR: 41.899165962687874 dB
# SSIM: 0.95286
# PSNR: 44.92372923808279 dB
# SSIM: 0.97997
# PSNR: 42.485896986752664 dB
# SSIM: 0.95547
# PSNR: 33.61201784242495 dB
# SSIM: 0.92951
# PSNR: 39.582038307280456 dB
# SSIM: 0.97154
# PSNR: 47.40630466873597 dB
# SSIM: 0.99287
# PSNR: 41.194260893353345 dB
# SSIM: 0.95561
# PSNR: 44.17510368714615 dB
# SSIM: 0.98283
# PSNR: 40.51947488181174 dB
# SSIM: 0.94425
# PSNR: 37.99092027379959 dB
# SSIM: 0.89972
# PSNR: 43.52321741607274 dB
# SSIM: 0.97549
# PSNR: 44.046260091183754 dB
# SSIM: 0.96712
# PSNR: 45.38520905997913 dB
# SSIM: 0.98409
# PSNR: 42.81597025976198 dB
# SSIM: 0.96112
# PSNR: 34.6771432924191 dB
# SSIM: 0.95991
# PSNR: 43.59220018725842 dB
# SSIM: 0.97455
# PSNR: 45.04149516258746 dB
# SSIM: 0.98223
# PSNR: 43.266387257689345 dB
# SSIM: 0.97671
# PSNR: 40.11525450556363 dB
# SSIM: 0.94041
# PSNR: 33.89331224591471 dB
# SSIM: 0.94004

# %%
for i in range(len(psnr_values_train)):
  if(psnr_values_train[i]==inf):
    print(i)
    psnr_values_train[i] = 72.0
# Out:
# 4141
# 4181
# 4524
# 5132
# 5233

# %%
average_psnr_train = np.mean(psnr_values_train)
print(f"Average PSNR: {average_psnr_train}")

average_ssim_train = np.mean(ssim_values_train)
print(f"Average SSIM: {average_ssim_train}")
# Out:
# Average PSNR: 41.397210747800045
# Average SSIM: 0.9498225004314333

# %% [markdown]
# # **Task 2: Multiclass Image Classification using CNNs**

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
from collections import Counter

drive_path = '/content/drive/MyDrive/DL_Milestone_2/train_inpainted'

# Function to load PNG images from subfolders
def load_images_from_subfolders(folder_path):
    image_data = []
    subfolders = [f.path for f in os.scandir(folder_path) if f.is_dir()]

    for subfolder in subfolders:
        subfolder_name = os.path.basename(subfolder)
        print(f"Loading images from {subfolder_name}...")

        for file_name in os.listdir(subfolder):
            if file_name.endswith('.png'):
                file_path = os.path.join(subfolder, file_name)
                img = Image.open(file_path)
                image_data.append((subfolder_name, img))

    return image_data

image_data = load_images_from_subfolders(drive_path)

## Display the first image from the loaded data
if image_data:
    subfolder_name, img = image_data[0]
    plt.imshow(img)
    plt.title(f"Subfolder: {subfolder_name}")
    plt.axis('off')
    plt.show()
# Out:
# Loading images from Flood...
# Loading images from Earthquake...
# Loading images from Landslides...
# Loading images from Hurricane...
# Loading images from Wildfire...

# %%
# Get class distribution
class_distribution = Counter([class_name for class_name, _ in image_data])

# Plot the distribution
plt.bar(class_distribution.keys(), class_distribution.values())
plt.title('Distribution of Different Classes in Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
from PIL import Image, ImageFilter
import os
from tqdm import tqdm

def augment_images(input_dir, output_dir, classes_to_augment):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for class_name in classes_to_augment:
        class_dir = os.path.join(input_dir, class_name)
        output_class_dir = os.path.join(output_dir, class_name)

        if not os.path.exists(output_class_dir):
            os.makedirs(output_class_dir)

        for filename in tqdm(os.listdir(class_dir), desc=f"Processing {class_name} images"):
            image_path = os.path.join(class_dir, filename)

            # Mirroring
            mirrored_output_path = os.path.join(output_class_dir, f"mirrored_{filename}")
            mirror_image(image_path, mirrored_output_path)

            # Blurring
            blurred_output_path = os.path.join(output_class_dir, f"blurred_{filename}")
            blur_image(image_path, blurred_output_path)

    print("Data augmentation completed.")

def mirror_image(input_path, output_path):
    with Image.open(input_path) as img:
        # Mirror the image horizontally
        mirrored_img = img.transpose(Image.FLIP_LEFT_RIGHT)
        # Save the mirrored image
        mirrored_img.save(output_path)

def blur_image(input_path, output_path):
    with Image.open(input_path) as img:
        # Apply Gaussian blur to the image
        blurred_img = img.filter(ImageFilter.GaussianBlur(radius=2))
        # Save the blurred image
        blurred_img.save(output_path)

# %%
input_dir = "/content/drive/MyDrive/DL_Milestone_2/train_inpainted"
output_dir = "/content/drive/MyDrive/DL_Milestone_2/train_augmented"
classes_to_augment = ["Landslides"]
augment_images(input_dir, output_dir, classes_to_augment)
# Out:
# Processing Landslides images: 100%|██████████| 260/260 [00:21<00:00, 12.14it/s]
# Data augmentation completed.

# %%
import os
import shutil

def shift_png_files(source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # List all files in the source folder
    files = os.listdir(source_folder)

    # Filter only PNG files
    png_files = [file for file in files if file.lower().endswith('.png')]

    # Move PNG files to the destination folder
    for png_file in png_files:
        source_path = os.path.join(source_folder, png_file)
        destination_path = os.path.join(destination_folder, png_file)

        shutil.move(source_path, destination_path)
        print(f"Moved {png_file} to {destination_folder}")

# %%
import os
import shutil

def shift_png_files(source_folder, destination_folder):
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # List all files in the source folder
    files = os.listdir(source_folder)

    # Filter only PNG files
    png_files = [file for file in files if file.lower().endswith('.png')]

    # Move PNG files to the destination folder
    for png_file in png_files:
        source_path = os.path.join(source_folder, png_file)
        destination_path = os.path.join(destination_folder, png_file)

        shutil.move(source_path, destination_path)
        print(f"Moved {png_file} to {destination_folder}")

# %%
source_folder = "/content/drive/MyDrive/DL_Milestone_2/train_augmented/Landslides"
destination_folder = "/content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides"
shift_png_files(source_folder, destination_folder)
# Out:
# Moved mirrored_Image_388.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_388.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_235.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_235.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_396.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_396.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_104.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_104.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_221.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_221.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_291.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_291.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_203.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_203.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_533.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_533.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_492.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_492.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_611.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_611.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_346.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_346.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_380.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_380.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_316.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_316.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_248.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_248.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_544.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_544.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_224.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_224.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_169.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_169.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_301.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_301.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_1.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_1.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_552.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_552.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_83.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_83.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_416.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_416.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_261.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_261.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_543.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_543.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_344.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_344.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_447.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_447.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_300.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_300.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_214.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_214.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_454.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_454.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_394.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_394.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_622.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_622.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_593.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_593.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_450.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_450.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_334.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_334.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_502.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_502.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_223.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_223.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_270.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_270.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_653.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_653.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_324.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_324.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_347.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_347.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_161.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_161.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_449.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_449.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_602.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_602.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_404.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_404.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_636.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_636.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_625.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_625.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_608.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_608.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_190.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_190.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_209.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_209.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_432.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_432.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_458.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_458.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_434.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_434.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_279.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_279.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_127.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_127.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_439.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_439.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_139.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_139.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_342.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_342.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_529.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_529.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_532.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_532.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_266.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_266.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_349.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_349.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_265.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_265.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_448.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_448.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_128.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_128.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_437.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_437.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_141.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_141.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_401.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_401.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_457.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_457.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_399.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_399.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_538.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_538.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_263.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_263.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_556.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_556.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_307.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_307.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_299.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_299.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_600.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_600.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_340.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_340.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_294.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_294.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_551.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_551.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_417.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_417.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_518.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_518.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_536.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_536.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_328.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_328.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_220.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_220.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_112.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_112.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_264.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_264.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_626.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_626.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_246.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_246.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_546.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_546.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_77.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_77.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_86.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_86.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_637.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_637.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_232.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_232.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_631.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_631.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_250.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_250.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_155.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_155.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_236.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_236.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_243.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_243.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_272.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_272.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_215.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_215.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_240.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_240.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_144.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_144.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_436.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_436.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_456.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_456.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_534.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_534.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_17.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_17.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_610.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_610.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_348.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_348.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_455.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_455.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_329.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_329.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_365.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_365.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_216.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_216.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_244.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_244.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_208.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_208.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_548.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_548.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_592.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_592.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_452.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_452.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_515.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_515.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_164.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_164.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_271.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_271.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_293.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_293.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_384.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_384.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_640.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_640.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_274.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_274.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_296.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_296.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_526.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_526.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_262.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_262.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_69.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_69.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_321.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_321.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_520.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_520.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_142.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_142.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_519.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_519.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_528.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_528.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_467.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_467.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_453.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_453.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_406.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_406.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_624.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_624.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_119.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_119.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_460.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_460.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_549.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_549.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_154.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_154.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_628.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_628.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_286.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_286.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_641.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_641.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_269.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_269.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_241.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_241.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_160.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_160.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_275.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_275.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_247.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_247.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_172.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_172.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_607.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_607.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_322.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_322.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_390.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_390.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_284.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_284.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_504.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_504.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_657.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_657.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_339.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_339.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_513.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_513.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_463.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_463.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_311.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_311.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_407.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_407.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_517.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_517.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_304.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_304.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_170.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_170.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_493.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_493.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_541.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_541.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_604.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_604.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_629.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_629.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_317.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_317.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_438.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_438.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_530.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_530.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_173.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_173.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_290.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_290.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_555.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_555.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_285.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_285.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_315.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_315.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_239.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_239.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_468.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_468.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_258.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_258.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_443.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_443.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_337.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_337.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_635.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_635.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_312.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_312.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_542.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_542.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_303.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_303.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_12.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_12.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_601.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_601.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_297.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_297.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_255.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_255.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_539.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_539.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_171.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_171.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_395.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_395.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_623.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_623.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_514.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_514.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_327.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_327.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_391.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_391.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_308.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_308.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_545.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_545.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_305.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_305.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_609.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_609.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_364.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_364.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_525.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_525.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_257.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_257.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_642.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_642.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_35.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_35.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_345.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_345.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_595.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_595.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_451.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_451.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_645.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_645.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_557.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_557.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_143.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_143.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_405.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_405.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_560.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_560.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_521.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_521.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_314.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_314.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_331.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_331.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_259.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_259.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_53.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_53.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_14.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_14.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_597.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_597.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_559.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_559.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_516.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_516.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_16.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_16.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_446.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_446.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_23.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_23.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_398.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_398.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_400.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_400.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_522.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_522.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_199.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_199.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_309.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_309.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_613.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_613.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_343.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_343.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_73.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_73.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_234.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_234.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_445.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_445.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_320.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_320.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_442.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_442.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_612.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_612.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_330.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_330.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_634.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_634.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_84.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_84.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_535.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_535.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_22.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_22.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_15.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_15.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_256.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_256.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_30.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_30.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_638.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_638.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_283.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_283.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_524.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_524.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_444.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_444.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_643.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_643.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_85.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_85.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_599.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_599.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_313.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_313.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_306.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_306.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_295.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_295.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_276.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_276.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_558.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_558.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_523.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_523.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_496.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_496.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved mirrored_Image_125.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides
# Moved blurred_Image_125.png to /content/drive/MyDrive/DL_Milestone_2/train_inpainted/Landslides

# %%
drive_path = '/content/drive/MyDrive/DL_Milestone_2/train_inpainted'
image_data = load_images_from_subfolders(drive_path)
# Out:
# Loading images from Flood...
# Loading images from Earthquake...
# Loading images from Landslides...
# Loading images from Hurricane...
# Loading images from Wildfire...

# %%
# Get class distribution
class_distribution = Counter([class_name for class_name, _ in image_data])

# Plot the distribution
plt.bar(class_distribution.keys(), class_distribution.values())
plt.title('Distribution of Different Classes in Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()

# %%
validation_path = '/content/drive/MyDrive/DL_Milestone_2/validation_inpainted'
val_image_data = load_images_from_subfolders(validation_path)

# Get class distribution
class_distribution = Counter([class_name for class_name, _ in val_image_data])

# Plot the distribution
plt.bar(class_distribution.keys(), class_distribution.values())
plt.title('Distribution of Different Classes in Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()
# Out:
# Loading images from Hurricane...
# Loading images from Flood...
# Loading images from Landslides...
# Loading images from Wildfire...
# Loading images from Earthquake...

# %%
#Data augmentation on validation set

input_dir = "/content/drive/MyDrive/DL_Milestone_2/validation_inpainted"
output_dir = "/content/drive/MyDrive/DL_Milestone_2/validation_augmented"
classes_to_augment = ["Landslides"]
augment_images(input_dir, output_dir, classes_to_augment)

#Shift augmented images to validation folder

source_folder = "/content/drive/MyDrive/DL_Milestone_2/validation_augmented/Landslides"
destination_folder = "/content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides"
shift_png_files(source_folder, destination_folder)
# Out:
# Processing Landslides images: 100%|██████████| 61/61 [00:05<00:00, 11.22it/s]
# Data augmentation completed.
# Moved mirrored_Image_403.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_403.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_379.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_379.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_204.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_204.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_254.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_254.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_91.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_91.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_459.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_459.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_632.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_632.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_392.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_392.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_527.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_527.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_621.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_621.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_242.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_242.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_440.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_440.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_13.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_13.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_547.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_547.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_298.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_298.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_481.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_481.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_310.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_310.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_605.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_605.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_245.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_245.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_335.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_335.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_627.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_627.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_159.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_159.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_175.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_175.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_503.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_503.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_82.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_82.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_606.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_606.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_99.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_99.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_341.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_341.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_126.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_126.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_129.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_129.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_332.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_332.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_402.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_402.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_336.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_336.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_162.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_162.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_598.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_598.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_278.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_278.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_550.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_550.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_585.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_585.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_210.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_210.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_218.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_218.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_233.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_233.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_393.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_393.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_115.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_115.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_273.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_273.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_441.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_441.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_639.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_639.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_292.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_292.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_124.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_124.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_68.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_68.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_326.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_326.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_633.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_633.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_540.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_540.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_219.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_219.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_338.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_338.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_249.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_249.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_260.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_260.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_145.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_145.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_163.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_163.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_333.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_333.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_462.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_462.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved mirrored_Image_174.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides
# Moved blurred_Image_174.png to /content/drive/MyDrive/DL_Milestone_2/validation_inpainted/Landslides

# %%
validation_path = '/content/drive/MyDrive/DL_Milestone_2/validation_inpainted'
val_image_data = load_images_from_subfolders(validation_path)

# Get class distribution
class_distribution = Counter([class_name for class_name, _ in val_image_data])

# Plot the distribution
plt.bar(class_distribution.keys(), class_distribution.values())
plt.title('Distribution of Different Classes in Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.show()
# Out:
# Loading images from Hurricane...
# Loading images from Flood...
# Loading images from Landslides...
# Loading images from Wildfire...
# Loading images from Earthquake...

# %% [markdown]
# ## Model Specifications

# %%
import tensorflow as tf
from keras.metrics import Precision, Recall

d = tf.keras.applications.DenseNet121(include_top=False,
                   input_shape=(256,256,3),
                   pooling=None,
                   weights='imagenet')
for i in d.layers:
  i.trainable = True

output_avg = tf.keras.layers.GlobalAveragePooling2D()(d.output)
output_max = tf.keras.layers.GlobalMaxPooling2D()(d.output)
m = tf.keras.layers.minimum([output_avg, output_max])
m = tf.keras.layers.Dropout(0.5)(m)
m = tf.keras.layers.Dense(128, activation = "sigmoid")(m)
m = tf.keras.layers.Dropout(0.3)(m)
m = tf.keras.layers.Dense(256, activation = "relu")(m)
m = tf.keras.layers.Dropout(0.3)(m)
m = tf.keras.layers.Dense(512, activation = "relu")(m)
m = tf.keras.layers.Dropout(0.3)(m)
m = tf.keras.layers.Dense(5, activation= "softmax")(m)
m = tf.keras.models.Model(inputs = d.input, outputs = m)
m.compile(optimizer = tf.keras.optimizers.Adam(0.0001),
          loss = "categorical_crossentropy",
          metrics =["accuracy", Precision(name='precision'), Recall(name='recall')])
#m.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %% [markdown]
# ## Model Training

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

drive_path = '/content/drive/MyDrive/DL_Milestone_2/train_inpainted'

train_datagen = ImageDataGenerator()
train_generator = train_datagen.flow_from_directory(drive_path, batch_size=16, class_mode='categorical', target_size=(256, 256), shuffle=True)

validation_path = '/content/drive/MyDrive/DL_Milestone_2/validation_inpainted'

validation_datagen = ImageDataGenerator()
validation_generator = validation_datagen.flow_from_directory(validation_path, batch_size=16, class_mode='categorical', target_size=(256, 256), shuffle=True)
# Out:
# Found 6003 images belonging to 5 classes.
# Found 1406 images belonging to 5 classes.

# %%
callbacks = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
best_model_file = '/content/drive/MyDrive/DL_Milestone_2/model_2'
best_model = ModelCheckpoint(best_model_file, monitor='val_accuracy', verbose = 1, save_best_only = True)

# %%
history = m.fit(train_generator, epochs=30, verbose=1, validation_data=validation_generator, callbacks = [callbacks, best_model])
# Out:
# Epoch 1/30
# 376/376 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.6747 - precision: 0.8662 - recall: 0.4928
# Epoch 1: val_accuracy improved from -inf to 0.54054, saving model to /content/drive/MyDrive/DL_Milestone_2/model_2
# 376/376 [==============================] - 2705s 7s/step - loss: 0.8811 - accuracy: 0.6747 - precision: 0.8662 - recall: 0.4928 - val_loss: 2.0746 - val_accuracy: 0.5405 - val_precision: 0.5418 - val_recall: 0.5349
# Epoch 2/30
# 376/376 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.9032 - precision: 0.9200 - recall: 0.8846
# Epoch 2: val_accuracy improved from 0.54054 to 0.85277, saving model to /content/drive/MyDrive/DL_Milestone_2/model_2
# 376/376 [==============================] - 189s 503ms/step - loss: 0.3147 - accuracy: 0.9032 - precision: 0.9200 - recall: 0.8846 - val_loss: 0.4326 - val_accuracy: 0.8528 - val_precision: 0.8612 - val_recall: 0.8514
# Epoch 3/30
# 376/376 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9379 - precision: 0.9470 - recall: 0.9312
# Epoch 3: val_accuracy improved from 0.85277 to 0.94595, saving model to /content/drive/MyDrive/DL_Milestone_2/model_2
# 376/376 [==============================] - 205s 545ms/step - loss: 0.1953 - accuracy: 0.9379 - precision: 0.9470 - recall: 0.9312 - val_loss: 0.1879 - val_accuracy: 0.9459 - val_precision: 0.9499 - val_recall: 0.9445
# Epoch 4/30
# 376/376 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9564 - precision: 0.9603 - recall: 0.9515
# Epoch 4: val_accuracy did not improve from 0.94595
# 376/376 [==============================] - 118s 313ms/step - loss: 0.1441 - accuracy: 0.9564 - precision: 0.9603 - recall: 0.9515 - val_loss: 0.4282 - val_accuracy: 0.8855 - val_precision: 0.8872 - val_recall: 0.8841
# Epoch 5/30
# 376/376 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9627 - precision: 0.9655 - recall: 0.9597
# Epoch 5: val_accuracy did not improve from 0.94595
# 376/376 [==============================] - 122s 325ms/step - loss: 0.1178 - accuracy: 0.9627 - precision: 0.9655 - recall: 0.9597 - val_loss: 0.1997 - val_accuracy: 0.9374 - val_precision: 0.9400 - val_recall: 0.9360
# Epoch 6/30
# 376/376 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9727 - precision: 0.9751 - recall: 0.9710
# Epoch 6: val_accuracy did not improve from 0.94595
# 376/376 [==============================] - 127s 339ms/step - loss: 0.0833 - accuracy: 0.9727 - precision: 0.9751 - recall: 0.9710 - val_loss: 0.3128 - val_accuracy: 0.9018 - val_precision: 0.9036 - val_recall: 0.9004
# Epoch 6: early stopping

# %%
m.save_weights('/content/drive/MyDrive/DL_Milestone_2/model_weights.h5')

# %% [markdown]
# ### Loss Function of Training

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 10))
plt.plot(history.history['loss'], label = "loss")
plt.plot(history.history['val_loss'], label = "val_loss")
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 10))
plt.plot(history.history['accuracy'], label = "accuracy")
plt.plot(history.history['precision'], label = "precision")
plt.plot(history.history['recall'], label = "recall")
plt.plot(history.history['val_accuracy'], label = "val_accuracy")
plt.plot(history.history['val_precision'], label = "val_precision")
plt.plot(history.history['val_recall'], label = "val_recall")
plt.legend()

# %% [markdown]
# ## Model Testing

# %% [markdown]
# ### Model Testing for Validation Data

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from keras.metrics import Precision, Recall

# Load the trained model
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/DL_Milestone_2/model_2')
test_path = '/content/drive/MyDrive/DL_Milestone_2/validation_inpainted'
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_path, batch_size=16, class_mode='categorical', target_size=(256, 256), shuffle=False)

# Evaluate the model on the test data
test_loss, test_accuracy, test_precision, test_recall = loaded_model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')

# Read labels of test class
true_labels = test_generator.classes

# Generate predictions
predicted_probabilities = loaded_model.predict(test_generator)
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print classification report
class_labels = list(test_generator.class_indices.keys())
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_labels))
# Out:
# Found 1406 images belonging to 5 classes.
# 88/88 [==============================] - 11s 99ms/step - loss: 0.1879 - accuracy: 0.9459 - precision: 0.9499 - recall: 0.9445
# Test Loss: 0.1879
# Test Accuracy: 0.9459
# Test Precision: 0.9499
# Test Recall: 0.9445
# 88/88 [==============================] - 14s 127ms/step
# Confusion Matrix:
# [[370   3  11   2   0]
#  [  5 282  11   8   0]
#  [  5   7 177   5   1]
#  [  0   0   0 183   0]
#  [  6   2   5   5 318]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   Earthquake       0.96      0.96      0.96       386
#        Flood       0.96      0.92      0.94       306
#    Hurricane       0.87      0.91      0.89       195
#   Landslides       0.90      1.00      0.95       183
#     Wildfire       1.00      0.95      0.97       336
#
#     accuracy                           0.95      1406
#    macro avg       0.94      0.95      0.94      1406
# weighted avg       0.95      0.95      0.95      1406

# %% [markdown]
# ### Model Testing for Train Data

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from keras.metrics import Precision, Recall

# Load the trained model
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/DL_Milestone_2/model_2')
test_path = '/content/drive/MyDrive/DL_Milestone_2/train_inpainted'
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_path, batch_size=16, class_mode='categorical', target_size=(256, 256), shuffle=False)

# Evaluate the model on the test data
test_loss, test_accuracy, test_precision, test_recall = loaded_model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')

# Read labels of test class
true_labels = test_generator.classes

# Generate predictions
predicted_probabilities = loaded_model.predict(test_generator)
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print classification report
class_labels = list(test_generator.class_indices.keys())
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_labels))
# Out:
# Found 6003 images belonging to 5 classes.
# 376/376 [==============================] - 60s 153ms/step - loss: 0.0739 - accuracy: 0.9757 - precision: 0.9779 - recall: 0.9737
# Test Loss: 0.0739
# Test Accuracy: 0.9757
# Test Precision: 0.9779
# Test Recall: 0.9737
# 376/376 [==============================] - 41s 102ms/step
# Confusion Matrix:
# [[1600    2   36    8    1]
#  [   8 1259   33    8    2]
#  [   6    4  810   12    0]
#  [   0    0    0  778    2]
#  [   6    0    9    9 1410]]
# Classification Report:
#               precision    recall  f1-score   support
#
#   Earthquake       0.99      0.97      0.98      1647
#        Flood       1.00      0.96      0.98      1310
#    Hurricane       0.91      0.97      0.94       832
#   Landslides       0.95      1.00      0.98       780
#     Wildfire       1.00      0.98      0.99      1434
#
#     accuracy                           0.98      6003
#    macro avg       0.97      0.98      0.97      6003
# weighted avg       0.98      0.98      0.98      6003

# %% [markdown]
# # **Evaluate Block**
#
# Run the two code blocks below after making the required changes to addresses as per the comments given below.

# %% [markdown]
# ### **Read Me**
#  We were unable to write a method that could take torch tensors as inputs as the model uses images in numpy format. We tried using the .numpy() method however that led to the RAM space being completely used up for some reason. However, any batch of data stored in the folder given as corrupted_images_address seperated into subfolders can be given as input and this evaluate bloack would do the needful and print the given metrics as well.

# %%
# Write the address of folder containing paired test images in corrupted_images_address
corrupted_images_address = "Test"

# Write the address of folder containing actual test images in actual_images_address
# These images are required to calculate the SSIM and PSNR values
actual_images_address = "Test_Actual"

# Write the address of folder where you want inpainted images to be stored.
file_out_address = "Test_Inpainted"

# All three folders mentioned above must have images contained in subfolders named as their class names.
# You can move the test_inpainted folder in our drive to the your desired location.

# Write the GAN model path address here
model_path = "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint"
# Write the CNN model path address here
model_path_2 = '/content/drive/MyDrive/DL_Milestone_2/model_2'

# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
tf.compat.v1.reset_default_graph()

import tensorflow as tf
import cv2 as cv
import random
import os
import math
import numpy as np

def random_interpolates(x, y, alpha=None):
    """
    x: first dimension as batch_size
    y: first dimension as batch_size
    alpha: [BATCH_SIZE, 1]
    """
    shape = x.get_shape().as_list()
    x = tf.reshape(x, [shape[0], -1])
    y = tf.reshape(y, [shape[0], -1])
    if alpha is None:
        alpha = tf.compat.v1.random_uniform(shape=[shape[0], 1])
    interpolates = x + alpha*(y - x)
    return tf.reshape(interpolates, shape)


def gradients_penalty(x, y, mask=None, norm=1.):
    """Improved Training of Wasserstein GANs
    - https://arxiv.org/abs/1704.00028
    """
    gradients = tf.gradients(y, x)[0]
    if mask is None:
        mask = tf.ones_like(gradients)
    slopes = tf.sqrt(tf.reduce_mean(tf.square(gradients) * mask, axis=[1, 2, 3]))
    return tf.reduce_mean(tf.square(slopes - norm))


def standard_conv(x,mask,cnum,ksize=3,stride=1,rate=1,name='conv',padding='SAME'):
        '''
        define convolution for generator
        Args:
                x:iput image
                cnum: channel number
                ksize: kernal size
                stride: convolution stride
                rate : rate for dilated conv
                name: name of layers
        '''
        p       = int(rate*(ksize-1)/2)
        x       = tf.pad(x, [[0,0], [p, p], [p, p], [0,0]],'REFLECT')
        padding = 'VALID'
        x       = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                  ,padding=padding,name=name+'_1')
        return x
def standard_dconv(x,mask,cnum,name='deconv',padding='VALID'):
        '''
        define upsample convolution for generator
        Args:
        x: input image
        mask: input mask
        name: name of layers
        '''
        rate   = 1
        ksize  = 3
        stride = 1
        shape  = x.get_shape().as_list()
        x      = tf.compat.v1.image.resize_nearest_neighbor(x,[shape[1]*2,shape[2]*2])
        p3     = int(1 * (3 - 1) / 2)
        x      = tf.pad(x, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')
        x      = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                          ,padding=padding,name=name+'_1')
        return x


def l2_norm(v, eps=1e-12):
    return v / (tf.reduce_sum(v ** 2) ** 0.5 + eps)


def spectral_norm(w, iteration=1,name='dasd'):
   w_shape = w.shape.as_list()
   w = tf.reshape(w, [-1, w_shape[-1]])

   u = tf.compat.v1.get_variable(name+"u", [1, w_shape[-1]], initializer=tf.compat.v1.truncated_normal_initializer(), trainable=False)

   u_hat = u
   v_hat = None
   for i in range(0, iteration):
       v_ = tf.matmul(u_hat, tf.transpose(w))
       v_hat = l2_norm(v_)

       u_ = tf.matmul(v_hat, w)
       u_hat = l2_norm(u_)

   sigma = tf.matmul(tf.matmul(v_hat, w), tf.transpose(u_hat))
   w_norm = w / sigma

   with tf.control_dependencies([u.assign(u_hat)]):
       w_norm = tf.reshape(w_norm, w_shape)

   return w_norm


def LeakyRelu(x, leak=0.2, name="LeakyRelu"):
        f1 = 0.5 * (1 + leak)
        f2 = 0.5 * (1 - leak)
        return f1 * x + f2 * tf.abs(x)


def dis_conv(x, cnum, ksize=5, stride=2, activation = 'leak_relu', name='conv'):
    """
    covolution for discriminator.
    Args:
        x: input image
        cnum: channel number.
        ksize: kernel size.
        Stride: convolution stride.
        name: name of layers.
    """

    x_shape = x.get_shape().as_list()
    w = tf.compat.v1.get_variable(name = name+'_w',shape = [ksize, ksize, x_shape[-1]] + [cnum])
    w = spectral_norm(w, name = name)
    x = tf.nn.conv2d(x, w, strides = [1, stride, stride, 1], padding = 'SAME')
    bias = tf.compat.v1.get_variable(name=name+'_bias',shape=[cnum])
    if activation != None:
        return  LeakyRelu(x + bias, name = name)
    else:
        return x + bias

from random import randint
import itertools
import numpy as np
import cv2
from math import *
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

def continuous_mask(height, width,num,maxAngle,maxLength,maxBrushWidth,channels=3):
    """Generates a continuous mask with lines, circles and elipses"""

    img = np.zeros((height, width, channels), np.uint8)

    for j in range(0, 1):
        startX = randint(0, width)
        startY = randint(0, height)
        for i in range(0,randint(1,num)):
            angle = randint(0,maxAngle)
            if i%2==0:
                angle = 360 - angle
            length = randint(1,maxLength)
            brushWidth = randint(1, maxBrushWidth)
            endX   = startX + int(length * sin(angle))
            endY   = startY + int(length * cos(angle))
            if endX>255:
                endX = 255
            if endX<0:
                endX = 0
            if endY>255:
                endY = 255
            if endY<0:
                endY = 0
            cv2.line(img, (startX,startY),(endX,endY),(255,255,255),brushWidth)
            cv2.circle(img, (endX,endY),brushWidth//2,(255,255,255),-1)
            startY = endY
            startX = endX


    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return 1-img2



def discontinuous_mask(height, width,num,low,high,channels=3):
    """Generates a discontinuous mask with lines, circles and elipses
       When we were training, we generated more elipses
    """
    img = np.zeros((height, width, channels), np.uint8)

    # Set size scale
    size = int((width + height) * 0.1)
    if width < 64 or height < 64:
        raise Exception("Width and Height of mask must be at least 64!")

    # Draw random lines
    for _ in range(0, randint(1, num)):
        x1, x2 = randint(1, width), randint(1, width)
        y1, y2 = randint(1, height), randint(1, height)
        thickness = randint(3, size)
        cv2.line(img,(x1,y1),(x2,y2),(1,1,1),thickness)

    # Draw random circles
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        radius = randint(3, size)
        cv2.circle(img,(x1,y1),radius,(1,1,1), -1)

    # Draw randow rectangle
    for _ in range(0, randint(1, num)):
        x1,y1 = randint(1, width), randint(1, height)
        x2,y2 = randint(1, width), randint(1, height)
        cv2.rectangle(img, (x1, y1), (x2, y2), (1, 1, 1), -1)

    # Draw random ellipses
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        s1, s2 = randint(low, high), randint(low, high)
        a1, a2, a3 = randint(3, 180), randint(3, 180), randint(3, 180)
        thickness = randint(3, size)
        cv2.ellipse(img, (x1,y1), (s1,s2), a1, a2, a3,(1,1,1), thickness)

    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return img2

import tensorflow as tf
import cv2 as cv
import numpy as np

def region_deconv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)

    x_fusion   = standard_dconv(x_fusion,mask,shape[-1],name = name+"_fusion")
    return x_fusion

def region_conv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    p3 = int(1 * (3 - 1) / 2)

    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)
    x_fusion   = tf.pad(x_fusion, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')

    x_fusion   = tf.compat.v1.layers.conv2d(x_fusion, shape[-1], kernel_size = 3, strides = 1, padding = 'VALID', dilation_rate = 1, name = name + "_fusion")
    x_fusion   = tf.nn.elu(x_fusion)
    return x_fusion

import inspect
import os

import numpy as np
import tensorflow as tf
import time

VGG_MEAN = [103.939, 116.779, 123.68]


class Vgg16:
    def __init__(self, vgg16_npy_path=None):
        if vgg16_npy_path is None:
            path = inspect.getfile(Vgg16)
            path = os.path.abspath(os.path.join(path, os.pardir))
            path = os.path.join(path, "vgg16.npy")
            vgg16_npy_path = path
            print(path)

        self.data_dict = np.load(vgg16_npy_path, encoding='latin1', allow_pickle=True).item()
        print("npy file loaded")

    def build(self, rgb):
        """
        load variable from npy to build the VGG
        :param rgb: rgb image [batch, height, width, 3] values scaled [0, 1]
        """

        start_time = time.time()
        rgb = tf.compat.v1.image.resize_images(rgb, (224, 224))
        print("build model started")
        rgb_scaled = (rgb+1.) * 127.5
        #print(type(rgb[0][0][0][0]))

        # Convert RGB to BGR
        # red, green, blue = tf.split(3, 3, rgb_scaled)
        red, green, blue = tf.split(rgb_scaled, 3, 3)
        assert red.get_shape().as_list()[1:] == [224, 224, 1]
        assert green.get_shape().as_list()[1:] == [224, 224, 1]
        assert blue.get_shape().as_list()[1:] == [224, 224, 1]
        bgr = tf.concat([
            blue - VGG_MEAN[0],
            green - VGG_MEAN[1],
            red - VGG_MEAN[2],
        ], 3)
        assert bgr.get_shape().as_list()[1:] == [224, 224, 3]

        self.conv1_1 = self.conv_layer(bgr, "conv1_1")
        self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
        self.pool1 = self.max_pool(self.conv1_2, 'pool1')

        self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
        self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
        self.pool2 = self.max_pool(self.conv2_2, 'pool2')

        self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
        self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
        self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
        self.pool3 = self.max_pool(self.conv3_3, 'pool3')

        self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
        self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
        self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
        self.pool4 = self.max_pool(self.conv4_3, 'pool4')

        self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
        self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
        self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
        self.pool5 = self.max_pool(self.conv5_3, 'pool5')


        print("build model finished: %ds" % (time.time() - start_time))

    def avg_pool(self, bottom, name):
        return tf.nn.avg_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def max_pool(self, bottom, name):
        return tf.nn.max_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def conv_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            filt = self.get_conv_filter(name)

            conv = tf.nn.conv2d(bottom, filt, [1, 1, 1, 1], padding='SAME')

            conv_biases = self.get_bias(name)
            bias = tf.nn.bias_add(conv, conv_biases)

            relu = tf.nn.relu(bias)
            return relu

    def fc_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            shape = bottom.get_shape().as_list()
            dim = 1
            for d in shape[1:]:
                dim *= d
            x = tf.reshape(bottom, [-1, dim])

            weights = self.get_fc_weight(name)
            biases = self.get_bias(name)

            # Fully connected layer. Note that the '+' operation automatically
            # broadcasts the biases.
            fc = tf.nn.bias_add(tf.matmul(x, weights), biases)

            return fc

    def get_conv_filter(self, name):
        return tf.constant(self.data_dict[name][0], name="filter")

    def get_bias(self, name):
        return tf.constant(self.data_dict[name][1], name="biases")

    def get_fc_weight(self, name):
        return tf.constant(self.data_dict[name][0], name="weights")

def loss_perceptual(pic1, pic2, pic3):
    loss = 0

    for o, c, g in zip(pic2, pic3, pic1):
        loss += l1(o, g) + l1(c, g)
    return loss

def l1(pic1, pic2):
    return tf.reduce_sum(tf.abs(pic1 - pic2))

def gram_matrix(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_a=True)
    gram = gram / tf.cast(C * H * W, x.dtype)
    return gram
def new_gram(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_b=True)
    gram = gram / tf.cast(C * C, x.dtype)
    return gram
def loss_style(output, vgg_gt):
    loss = 0
    for o, g in zip(output, vgg_gt):
        loss += l1(gram_matrix(o), gram_matrix(g))
    return loss

def loss_cor(output, vgg_gt):
    loss = 0
    loss_new = l1(new_gram(output[1]), new_gram(vgg_gt[1]))
    return loss_new

import tensorflow as tf
import cv2 as cv
import numpy as np

def RW_generator(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Region-wise generator
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            predicted image
    '''
    x1 = SINet(x, mask, reuse=reuse)
    x_combine = x * mask + x1 * (1 - mask)
    x2 = GPNet(x_combine,mask, reuse=reuse)
    return x1, x2

def SINet(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Semantic inferring network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by semantic inferring network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    ones_x = tf.ones_like(x)[:, :, :, 0:1]
    x = tf.concat([x, mask], axis=3)
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x_complete, x_missing = tf.concat([x12,x4],axis=-1),x12
            x13 = region_deconv(x_complete, x_missing, mask,name = 'com_13')

            x_complete, x_missing = tf.concat([x13,x3],axis=-1),x13
            x14 = region_conv(x_complete,x_missing,mask,name='com_14')

            x_complete, x_missing = tf.concat([x14,x2],axis=-1),x14
            x15 = region_deconv(x_complete, x_missing, mask, name = 'com_15')

            x16 = standard_conv(x15,mask,cnum,3,1,name='conv16')

            x17=standard_conv(x16,mask,cnum//2,3,1,name='conv17')
            x18=standard_conv(x17,mask,3,3,1,name='conv18')
            x18=tf.clip_by_value(x18,-1.,1.)

            return x18
def GPNet(x,mask,padding='SAME',name='inpaint_net_1',reuse=False):
    '''
    Global perceiving network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by global perceiving network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    x = tf.concat([x, mask], axis=3) #concat
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x13=standard_dconv(tf.concat([x12,x4],axis=-1),mask,2*cnum,name='conv13_upsample')
            x14=standard_conv(tf.concat([x13,x3],axis=-1),mask,2*cnum,3,1,name='conv14')
            x15=standard_dconv(tf.concat([x14,x2],axis=-1),mask,cnum,name='conv15_upsample')
            x16=standard_conv(tf.concat([x15,x1],axis=-1),mask,cnum//2,3,1,name='conv16')
            x17=standard_conv(x16,mask,3,3,1,name='conv17')
            x18=tf.clip_by_value(x17,-1.,1.)

            return x18

def RW_discriminator(x, mask, batch_size, activation = 'leaky_relu',reuse=False):
    '''
    Region-wise discriminator
    Args:
            x: input images
            mask: mask region {0,1}
    returns:
            matrix {real, fake}
    '''
    with tf.compat.v1.variable_scope('discriminator',reuse=reuse):
            cnum=64
            x=tf.concat([x,mask],axis=3)
            x=dis_conv(x,cnum,name='d_conv1')
            x=dis_conv(x,2*cnum,name='d_conv2')
            x=dis_conv(x,4*cnum,name='d_conv3')
            x=dis_conv(x,4*cnum,name='d_conv4')
            x=dis_conv(x,4*cnum,name='d_conv5')
            x=dis_conv(x,4*cnum,name='d_conv6', activation = activation)
            return x
def build_graph_with_loss(batch_data, batch_size, mask, vgg_path, adv_type, stage = 0,
                         lambda_style = 0.001, lambda_cor = 0.00001, alpha = 0.01 ,lambda_adv = 1.0,
                         reuse=False, training = True):

    image_gt=tf.subtract(tf.divide(batch_data,127.5),1.)
    date_shape=batch_data.get_shape().as_list()
    batch_incomplete=image_gt*mask

    image_p1, image_p2 = RW_generator(batch_incomplete, mask)
    image_c1 = image_p1 * (1 - mask) + image_gt * mask
    image_c2 = image_p2 * (1 - mask) + image_gt * mask
    rec_loss = tf.reduce_sum(tf.abs(image_gt - image_p1)) + tf.reduce_sum(tf.abs(image_gt - image_p2))

    vgg = Vgg16(vgg_path)
    vgg.build(image_gt)
    vgg_pos = [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c1)
    vgg_x1 =  [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c2)
    vgg_x2 =  [vgg.pool1,vgg.pool2, vgg.pool3]

    cor_loss = loss_cor(vgg_x1, vgg_pos)
    style_loss= loss_style(vgg_x2, vgg_pos)
    cor_loss = cor_loss * lambda_cor
    style_loss = style_loss * lambda_style
    cor_style = cor_loss + style_loss


    if stage == 1:
        activation = None
        if adv_type == ' ':
            activation = 'leaky_relu'
        d_pred = RW_discriminator(image_c1 * (1 - mask), mask, batch_size, activation)
        d_pred2 = RW_discriminator(image_c2 * (1 - mask), mask, batch_size, activation, reuse = True)
        d_real = RW_discriminator(image_gt * (1 - mask), mask, batch_size, activation, reuse = True)
        mask_label = 1 - mask
        shape = d_pred.get_shape().as_list()
        mask_label =  tf.compat.v1.image.resize_nearest_neighbor(mask_label, [shape[1],shape[2]])
        if adv_type == 'wgan':
            penalty_img = random_interpolates(image_gt, image_c2)
            dout_penalty = RW_discriminator(penalty_img, mask, batch_size, activation,reuse = True)
            penalty_loss = gradients_penalty(penalty_img, dout_penalty, mask = mask)
            adv_d_loss =  tf.reduce_mean(d_pred * mask_label) + tf.reduce_mean(d_pred2 * mask_label) - 0.01 * tf.reduce_mean(d_real * mask_label) +penalty_loss
            adv_g_loss = -1 * tf.reduce_mean(d_pred * mask_label) - tf.reduce_mean(d_pred2 * mask_label)

        elif adv_type == 'gan':
            adv_d_loss = 0.01 * tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_real, labels=tf.ones_like(d_real)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.zeros_like(d_pred)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.zeros_like(d_pred2))* mask_label)
            adv_g_loss = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.ones_like(d_real)) * mask_label)  + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.ones_like(d_real)) * mask_label)

        elif adv_type == 'hinge':

            adv_d_loss =  0.01 * tf.reduce_mean(tf.nn.relu(1 - d_real) * mask_label) + tf.reduce_mean(tf.nn.relu(1 + d_pred) * mask_label)
            + tf.reduce_mean(tf.nn.relu(1 + d_pred2) * mask_label)
            adv_g_loss = -1 * tf.reduce_mean(tf.nn.relu(d_pred) * mask_label) - tf.reduce_mean(tf.nn.relu(d_pred2) * mask_label)
        else:

            adv_d_loss =  alpha*tf.reduce_sum(tf.abs(mask_label - d_real)) + tf.reduce_sum(tf.abs(0 - d_pred)) + tf.reduce_sum(tf.abs(0 - d_pred2))
            adv_g_loss = tf.reduce_sum(tf.abs(mask_label - d_pred)) + tf.reduce_sum(tf.abs(mask_label - d_pred2))
    else:
        adv_d_loss = None
        adv_g_loss = None

    if stage == 1:
        g_loss= rec_loss+cor_style + lambda_adv * adv_g_loss
    else:
        g_loss = rec_loss + cor_style
    g_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'inpaint_net')
    d_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'discriminator') if stage == 1 else None

    tf.compat.v1.summary.image('incomplete',batch_incomplete, max_outputs=7)
    tf.compat.v1.summary.image('image_p1',image_p1, max_outputs=7)
    tf.compat.v1.summary.image('image_p2',image_p2, max_outputs=7)
    tf.compat.v1.summary.image('image_c2',image_c2, max_outputs=7)
    tf.compat.v1.summary.scalar('rec_loss',rec_loss)
    tf.compat.v1.summary.scalar('correlation loss', cor_loss)
    tf.compat.v1.summary.scalar('style loss', style_loss)
    if stage == 1:
        tf.compat.v1.summary.scalar('adv_g_loss', adv_g_loss)
        tf.compat.v1.summary.scalar('adv_d_loss', adv_d_loss)
    return g_vars,d_vars,g_loss,adv_d_loss,rec_loss,cor_loss,style_loss

def infer(batch_data,mask,reuse=False):
        shape=batch_data.get_shape().as_list()
        batch_gt=batch_data/127.5-1.
        batch_incomplete=batch_gt*mask

        image_p1, image_p2=RW_generator(batch_incomplete,mask,reuse=reuse)

        image_c2=batch_incomplete*mask+ image_p2*(1.-mask)
        image_c2=(image_c2+1.)*127.5
        return image_c2

def calculate_psnr(img1, img2):
    # Read images
    image1 = cv2.imread(img1)
    image2 = cv2.imread(img2)

    # Ensure images have the same shape
    if image1.shape != image2.shape:
        raise ValueError("Input images must have the same dimensions")

    # Calculate MSE (Mean Squared Error)
    mse = np.mean((image1 - image2) ** 2)

    # Calculate PSNR (Peak Signal-to-Noise Ratio)
    if mse == 0:
        return float('inf')
    max_pixel = 255.0
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr

from skimage.metrics import structural_similarity as ssim
def calculate_ssim(img1, img2):
    # Read images
    image1 = cv2.imread(img1)
    image2 = cv2.imread(img2)

    # Ensure images have the same shape
    if image1.shape != image2.shape:
        raise ValueError("Input images must have the same dimensions")

    # Convert images to grayscale
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

    # Calculate SSIM
    ssim_index, _ = ssim(gray1, gray2, full=True)
    return ssim_index

images=tf.compat.v1.placeholder(tf.float32,[1,256,256,3],name = 'image')
mask=tf.compat.v1.placeholder(tf.float32,[1,256,256,1],name='mask')
sess = tf.compat.v1.Session()
inpainting_result=infer(images,mask)
saver_pre=tf.compat.v1.train.Saver()
init_op = tf.group(tf.compat.v1.initialize_all_variables(),tf.compat.v1.initialize_local_variables())

psnr_values_test = []
ssim_values_test = []


import random
import gc
import os
import cv2
import glob
import socket
import tensorflow as tf
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

classes = ['Flood', 'Earthquake', 'Landslides', 'Hurricane', 'Wildfire']

for class_name in classes:
  corrupted_image_folder = os.path.join('/content/drive/MyDrive', corrupted_images_address, class_name)
  actual_images_folder = os.path.join('/content/drive/MyDrive', actual_images_address, class_name)
  corrupted_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', corrupted_image_folder)) if f.endswith('.png')]
  actual_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', actual_images_folder)) if f.endswith('.png')]
  common_files = set(corrupted_image_files) & set(actual_image_files)

  for file_name in common_files:
    test_data_path = os.path.join('/content/drive/MyDrive', corrupted_image_folder, file_name)
    corrupted_image = cv2.imread(test_data_path)

    difference_image_gray = cv2.cvtColor(corrupted_image, cv2.COLOR_BGR2GRAY)

    mask_test = 255-cv2.threshold(difference_image_gray, 1, 255, cv2.THRESH_BINARY)[1]
    mask_test = mask_test.reshape((256,256,1))

    cv2.imwrite('/content/mask.png', mask_test)

    mask_path = "/content/mask.png"
    file_out = os.path.join('/content/drive/MyDrive', file_out_address, class_name)
    width = 256
    height = 256
    file_test=test_data_path
    file_mask=mask_path
    sess.run(init_op)
    saver_pre.restore(sess, model_path)

    test_mask = cv2.resize(cv2.imread(file_mask),(height,width))
    test_mask = test_mask[:,:,0:1]
    test_mask = 0. + test_mask//255
    test_mask[test_mask >= 0.5] = 1
    test_mask[test_mask <  0.5] = 0
    test_mask  = 1-test_mask
    test_image = cv2.imread(file_test)[...,::-1]
    test_image = cv2.resize(test_image, (height, width))
    test_mask = np.expand_dims(test_mask,0)
    test_image = np.expand_dims(test_image,0)
    img_out=sess.run(inpainting_result,feed_dict={mask:test_mask,images:test_image})

    out_address = os.path.join('/content/drive/MyDrive', file_out, file_name)
    cv2.imwrite(out_address, img_out[0][...,::-1])

    actual_image_path = os.path.join('/content/drive/MyDrive', actual_images_folder, file_name)
    new_image_path = out_address
    actual_image = cv2.imread(actual_image_path)
    actual_image = cv2.resize(actual_image, (256, 256), interpolation = cv2.INTER_LINEAR)
    actual_image = actual_image.reshape((256,256,3))
    new_image = cv2.imread(new_image_path)
    cv2.imwrite('/content/image.png', actual_image)


    psnr = calculate_psnr('/content/image.png', new_image_path)
    psnr_values_test.append(psnr)
    ssim_value = calculate_ssim('/content/image.png', new_image_path)
    ssim_values_test.append(ssim_value)

for i in range(len(psnr_values_test)):
  if(psnr_values_test[i]==inf):
    psnr_values_test[i] = 72.0

average_psnr = np.mean(psnr_values_test)
print(f"Average PSNR: {average_psnr}")

average_ssim = np.mean(ssim_values_test)
print(f"Average SSIM: {average_ssim}")


import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from keras.metrics import Precision, Recall

# Load the trained model
loaded_model = tf.keras.models.load_model(model_path_2)
test_path = os.path.join('/content/drive/MyDrive', file_out_address)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_path, batch_size=16, class_mode='categorical', target_size=(256, 256), shuffle=False)

# Evaluate the model on the test data
test_loss, test_accuracy, test_precision, test_recall = loaded_model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')

# Read labels of test class
true_labels = test_generator.classes

# Generate predictions
predicted_probabilities = loaded_model.predict(test_generator)
predicted_labels = np.argmax(predicted_probabilities, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print classification report
class_labels = list(test_generator.class_indices.keys())
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_labels))

# %% [markdown]
# # Alternate Evaluate Block

# %% [markdown]
# ### **Read Me**
# This block would, similar to the above block, be unable to take torch tensors as inputs. However, this does not explicitly require the data to be seperated into subfolders. The entire image data can be given as input by storing it in the corrupted_images_address folder.
# The inpainted images will be stored in the file_out_address folder. The classification results would be stored in a list named output list in the alpabetically sorted order of input images names. This output can be used to calculate the custom evaluation metrics.

# %%
# Write the address of folder containing paired test images in corrupted_images_address
corrupted_images_address = "Test"

# Write the address of folder where you want inpainted images to be stored.
file_out_address = "Test_Inpainted"


# Write the GAN model path address here
model_path = "/content/drive/MyDrive/DL_Milestone_2/output/model_new/latest_checkpoint"
# Write the CNN model path address here
model_path_2 = '/content/drive/MyDrive/DL_Milestone_2/model_2'

# This evaluate block will save the inpainted images into the file_out_address based on the different classes and a list output will store all the values of classification results in the order the images are taken as inputs.

# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
tf.compat.v1.reset_default_graph()

import tensorflow as tf
import cv2 as cv
import random
import os
import math
import numpy as np

def random_interpolates(x, y, alpha=None):
    """
    x: first dimension as batch_size
    y: first dimension as batch_size
    alpha: [BATCH_SIZE, 1]
    """
    shape = x.get_shape().as_list()
    x = tf.reshape(x, [shape[0], -1])
    y = tf.reshape(y, [shape[0], -1])
    if alpha is None:
        alpha = tf.compat.v1.random_uniform(shape=[shape[0], 1])
    interpolates = x + alpha*(y - x)
    return tf.reshape(interpolates, shape)


def gradients_penalty(x, y, mask=None, norm=1.):
    """Improved Training of Wasserstein GANs
    - https://arxiv.org/abs/1704.00028
    """
    gradients = tf.gradients(y, x)[0]
    if mask is None:
        mask = tf.ones_like(gradients)
    slopes = tf.sqrt(tf.reduce_mean(tf.square(gradients) * mask, axis=[1, 2, 3]))
    return tf.reduce_mean(tf.square(slopes - norm))


def standard_conv(x,mask,cnum,ksize=3,stride=1,rate=1,name='conv',padding='SAME'):
        '''
        define convolution for generator
        Args:
                x:iput image
                cnum: channel number
                ksize: kernal size
                stride: convolution stride
                rate : rate for dilated conv
                name: name of layers
        '''
        p       = int(rate*(ksize-1)/2)
        x       = tf.pad(x, [[0,0], [p, p], [p, p], [0,0]],'REFLECT')
        padding = 'VALID'
        x       = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                  ,padding=padding,name=name+'_1')
        return x
def standard_dconv(x,mask,cnum,name='deconv',padding='VALID'):
        '''
        define upsample convolution for generator
        Args:
        x: input image
        mask: input mask
        name: name of layers
        '''
        rate   = 1
        ksize  = 3
        stride = 1
        shape  = x.get_shape().as_list()
        x      = tf.compat.v1.image.resize_nearest_neighbor(x,[shape[1]*2,shape[2]*2])
        p3     = int(1 * (3 - 1) / 2)
        x      = tf.pad(x, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')
        x      = tf.compat.v1.layers.conv2d(x,cnum,ksize,stride,dilation_rate=rate,activation=tf.nn.elu
                                          ,padding=padding,name=name+'_1')
        return x


def l2_norm(v, eps=1e-12):
    return v / (tf.reduce_sum(v ** 2) ** 0.5 + eps)


def spectral_norm(w, iteration=1,name='dasd'):
   w_shape = w.shape.as_list()
   w = tf.reshape(w, [-1, w_shape[-1]])

   u = tf.compat.v1.get_variable(name+"u", [1, w_shape[-1]], initializer=tf.compat.v1.truncated_normal_initializer(), trainable=False)

   u_hat = u
   v_hat = None
   for i in range(0, iteration):
       v_ = tf.matmul(u_hat, tf.transpose(w))
       v_hat = l2_norm(v_)

       u_ = tf.matmul(v_hat, w)
       u_hat = l2_norm(u_)

   sigma = tf.matmul(tf.matmul(v_hat, w), tf.transpose(u_hat))
   w_norm = w / sigma

   with tf.control_dependencies([u.assign(u_hat)]):
       w_norm = tf.reshape(w_norm, w_shape)

   return w_norm


def LeakyRelu(x, leak=0.2, name="LeakyRelu"):
        f1 = 0.5 * (1 + leak)
        f2 = 0.5 * (1 - leak)
        return f1 * x + f2 * tf.abs(x)


def dis_conv(x, cnum, ksize=5, stride=2, activation = 'leak_relu', name='conv'):
    """
    covolution for discriminator.
    Args:
        x: input image
        cnum: channel number.
        ksize: kernel size.
        Stride: convolution stride.
        name: name of layers.
    """

    x_shape = x.get_shape().as_list()
    w = tf.compat.v1.get_variable(name = name+'_w',shape = [ksize, ksize, x_shape[-1]] + [cnum])
    w = spectral_norm(w, name = name)
    x = tf.nn.conv2d(x, w, strides = [1, stride, stride, 1], padding = 'SAME')
    bias = tf.compat.v1.get_variable(name=name+'_bias',shape=[cnum])
    if activation != None:
        return  LeakyRelu(x + bias, name = name)
    else:
        return x + bias

from random import randint
import itertools
import numpy as np
import cv2
from math import *
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

def continuous_mask(height, width,num,maxAngle,maxLength,maxBrushWidth,channels=3):
    """Generates a continuous mask with lines, circles and elipses"""

    img = np.zeros((height, width, channels), np.uint8)

    for j in range(0, 1):
        startX = randint(0, width)
        startY = randint(0, height)
        for i in range(0,randint(1,num)):
            angle = randint(0,maxAngle)
            if i%2==0:
                angle = 360 - angle
            length = randint(1,maxLength)
            brushWidth = randint(1, maxBrushWidth)
            endX   = startX + int(length * sin(angle))
            endY   = startY + int(length * cos(angle))
            if endX>255:
                endX = 255
            if endX<0:
                endX = 0
            if endY>255:
                endY = 255
            if endY<0:
                endY = 0
            cv2.line(img, (startX,startY),(endX,endY),(255,255,255),brushWidth)
            cv2.circle(img, (endX,endY),brushWidth//2,(255,255,255),-1)
            startY = endY
            startX = endX


    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return 1-img2



def discontinuous_mask(height, width,num,low,high,channels=3):
    """Generates a discontinuous mask with lines, circles and elipses
       When we were training, we generated more elipses
    """
    img = np.zeros((height, width, channels), np.uint8)

    # Set size scale
    size = int((width + height) * 0.1)
    if width < 64 or height < 64:
        raise Exception("Width and Height of mask must be at least 64!")

    # Draw random lines
    for _ in range(0, randint(1, num)):
        x1, x2 = randint(1, width), randint(1, width)
        y1, y2 = randint(1, height), randint(1, height)
        thickness = randint(3, size)
        cv2.line(img,(x1,y1),(x2,y2),(1,1,1),thickness)

    # Draw random circles
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        radius = randint(3, size)
        cv2.circle(img,(x1,y1),radius,(1,1,1), -1)

    # Draw randow rectangle
    for _ in range(0, randint(1, num)):
        x1,y1 = randint(1, width), randint(1, height)
        x2,y2 = randint(1, width), randint(1, height)
        cv2.rectangle(img, (x1, y1), (x2, y2), (1, 1, 1), -1)

    # Draw random ellipses
    for _ in range(0, randint(1, num)):
        x1, y1 = randint(1, width), randint(1, height)
        s1, s2 = randint(low, high), randint(low, high)
        a1, a2, a3 = randint(3, 180), randint(3, 180), randint(3, 180)
        thickness = randint(3, size)
        cv2.ellipse(img, (x1,y1), (s1,s2), a1, a2, a3,(1,1,1), thickness)

    img2 = np.zeros((height, width,1))
    img2[:, :,0] = img[:, :, 0]
    img2[img2>1] = 1

    return img2

import tensorflow as tf
import cv2 as cv
import numpy as np

def region_deconv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)

    x_fusion   = standard_dconv(x_fusion,mask,shape[-1],name = name+"_fusion")
    return x_fusion

def region_conv(x_complete, x_missing, mask,name = 'com_'):
    shape = x_complete.get_shape().as_list()
    mask = tf.compat.v1.image.resize_nearest_neighbor(mask, size = [shape[1], shape[2]], align_corners=True)
    mask = tf.reshape(mask, [shape[0], shape[1], shape[2], 1])
    p3 = int(1 * (3 - 1) / 2)

    x_complete = x_complete * mask
    shape = x_missing.get_shape().as_list()
    x_missing  = x_missing  * (1 - mask)
    x_fusion   = tf.concat([x_complete,x_missing], axis = -1)
    x_fusion   = tf.pad(x_fusion, [[0,0], [p3,p3], [p3,p3], [0,0]], 'REFLECT')

    x_fusion   = tf.compat.v1.layers.conv2d(x_fusion, shape[-1], kernel_size = 3, strides = 1, padding = 'VALID', dilation_rate = 1, name = name + "_fusion")
    x_fusion   = tf.nn.elu(x_fusion)
    return x_fusion

import inspect
import os

import numpy as np
import tensorflow as tf
import time

VGG_MEAN = [103.939, 116.779, 123.68]


class Vgg16:
    def __init__(self, vgg16_npy_path=None):
        if vgg16_npy_path is None:
            path = inspect.getfile(Vgg16)
            path = os.path.abspath(os.path.join(path, os.pardir))
            path = os.path.join(path, "vgg16.npy")
            vgg16_npy_path = path
            print(path)

        self.data_dict = np.load(vgg16_npy_path, encoding='latin1', allow_pickle=True).item()
        print("npy file loaded")

    def build(self, rgb):
        """
        load variable from npy to build the VGG
        :param rgb: rgb image [batch, height, width, 3] values scaled [0, 1]
        """

        start_time = time.time()
        rgb = tf.compat.v1.image.resize_images(rgb, (224, 224))
        print("build model started")
        rgb_scaled = (rgb+1.) * 127.5
        #print(type(rgb[0][0][0][0]))

        # Convert RGB to BGR
        # red, green, blue = tf.split(3, 3, rgb_scaled)
        red, green, blue = tf.split(rgb_scaled, 3, 3)
        assert red.get_shape().as_list()[1:] == [224, 224, 1]
        assert green.get_shape().as_list()[1:] == [224, 224, 1]
        assert blue.get_shape().as_list()[1:] == [224, 224, 1]
        bgr = tf.concat([
            blue - VGG_MEAN[0],
            green - VGG_MEAN[1],
            red - VGG_MEAN[2],
        ], 3)
        assert bgr.get_shape().as_list()[1:] == [224, 224, 3]

        self.conv1_1 = self.conv_layer(bgr, "conv1_1")
        self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
        self.pool1 = self.max_pool(self.conv1_2, 'pool1')

        self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
        self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
        self.pool2 = self.max_pool(self.conv2_2, 'pool2')

        self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
        self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
        self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
        self.pool3 = self.max_pool(self.conv3_3, 'pool3')

        self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
        self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
        self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
        self.pool4 = self.max_pool(self.conv4_3, 'pool4')

        self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
        self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
        self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
        self.pool5 = self.max_pool(self.conv5_3, 'pool5')


        print("build model finished: %ds" % (time.time() - start_time))

    def avg_pool(self, bottom, name):
        return tf.nn.avg_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def max_pool(self, bottom, name):
        return tf.nn.max_pool(bottom, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)

    def conv_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            filt = self.get_conv_filter(name)

            conv = tf.nn.conv2d(bottom, filt, [1, 1, 1, 1], padding='SAME')

            conv_biases = self.get_bias(name)
            bias = tf.nn.bias_add(conv, conv_biases)

            relu = tf.nn.relu(bias)
            return relu

    def fc_layer(self, bottom, name):
        with tf.compat.v1.variable_scope(name):
            shape = bottom.get_shape().as_list()
            dim = 1
            for d in shape[1:]:
                dim *= d
            x = tf.reshape(bottom, [-1, dim])

            weights = self.get_fc_weight(name)
            biases = self.get_bias(name)

            # Fully connected layer. Note that the '+' operation automatically
            # broadcasts the biases.
            fc = tf.nn.bias_add(tf.matmul(x, weights), biases)

            return fc

    def get_conv_filter(self, name):
        return tf.constant(self.data_dict[name][0], name="filter")

    def get_bias(self, name):
        return tf.constant(self.data_dict[name][1], name="biases")

    def get_fc_weight(self, name):
        return tf.constant(self.data_dict[name][0], name="weights")

def loss_perceptual(pic1, pic2, pic3):
    loss = 0

    for o, c, g in zip(pic2, pic3, pic1):
        loss += l1(o, g) + l1(c, g)
    return loss

def l1(pic1, pic2):
    return tf.reduce_sum(tf.abs(pic1 - pic2))

def gram_matrix(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_a=True)
    gram = gram / tf.cast(C * H * W, x.dtype)
    return gram
def new_gram(x):
    shape = tf.shape(x)
    B, H, W, C = shape[0], shape[1], shape[2], shape[3]
    features = tf.reshape(x, tf.stack([B, -1, C]))
    gram = tf.matmul(features, features, transpose_b=True)
    gram = gram / tf.cast(C * C, x.dtype)
    return gram
def loss_style(output, vgg_gt):
    loss = 0
    for o, g in zip(output, vgg_gt):
        loss += l1(gram_matrix(o), gram_matrix(g))
    return loss

def loss_cor(output, vgg_gt):
    loss = 0
    loss_new = l1(new_gram(output[1]), new_gram(vgg_gt[1]))
    return loss_new

import tensorflow as tf
import cv2 as cv
import numpy as np

def RW_generator(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Region-wise generator
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            predicted image
    '''
    x1 = SINet(x, mask, reuse=reuse)
    x_combine = x * mask + x1 * (1 - mask)
    x2 = GPNet(x_combine,mask, reuse=reuse)
    return x1, x2

def SINet(x,mask,padding='SAME',name='inpaint_net',reuse=False):
    '''
    Semantic inferring network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by semantic inferring network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    ones_x = tf.ones_like(x)[:, :, :, 0:1]
    x = tf.concat([x, mask], axis=3)
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x_complete, x_missing = tf.concat([x12,x4],axis=-1),x12
            x13 = region_deconv(x_complete, x_missing, mask,name = 'com_13')

            x_complete, x_missing = tf.concat([x13,x3],axis=-1),x13
            x14 = region_conv(x_complete,x_missing,mask,name='com_14')

            x_complete, x_missing = tf.concat([x14,x2],axis=-1),x14
            x15 = region_deconv(x_complete, x_missing, mask, name = 'com_15')

            x16 = standard_conv(x15,mask,cnum,3,1,name='conv16')

            x17=standard_conv(x16,mask,cnum//2,3,1,name='conv17')
            x18=standard_conv(x17,mask,3,3,1,name='conv18')
            x18=tf.clip_by_value(x18,-1.,1.)

            return x18
def GPNet(x,mask,padding='SAME',name='inpaint_net_1',reuse=False):
    '''
    Global perceiving network
    Args:
            x: incomplete image
            mask: mask region {0,1}
    returns:
            image predicted by global perceiving network
    '''
    xin=x;
    mask_in=mask
    cnum=32
    x = tf.concat([x, mask], axis=3) #concat
    with tf.compat.v1.variable_scope(name,reuse=reuse):
            x1=standard_conv(x,mask,cnum,5,1,name='conv1')
            x2=standard_conv(x1,mask,2*cnum,3,2,name='conv2_downsample')
            x3=standard_conv(x2,mask,2*cnum,3,1,name='conv3')
            x4=standard_conv(x3,mask,4*cnum,3,2,name='conv4_downsample')
            x5=standard_conv(x4,mask,4*cnum,3,1,name='conv5')
            x6=standard_conv(x5,mask,4*cnum,3,1,name='conv6')

            #dilated conv
            x7=standard_conv(x6,mask,4*cnum,3,rate=2,name='conv7_atrous')
            x8=standard_conv(x7,mask,4*cnum,3,rate=4,name='conv8_atrous')
            x9=standard_conv(x8,mask,4*cnum,3,rate=8,name='conv9_atrous')
            x10=standard_conv(x9,mask,4*cnum,3,rate=16,name='conv10_atrous')



            x11=standard_conv(tf.concat([x10,x6],axis=-1), mask,4*cnum,3,1,name='conv11')
            x12=standard_conv(tf.concat([x11,x5],axis=-1),mask,4*cnum,3,1,name='conv12')

            x13=standard_dconv(tf.concat([x12,x4],axis=-1),mask,2*cnum,name='conv13_upsample')
            x14=standard_conv(tf.concat([x13,x3],axis=-1),mask,2*cnum,3,1,name='conv14')
            x15=standard_dconv(tf.concat([x14,x2],axis=-1),mask,cnum,name='conv15_upsample')
            x16=standard_conv(tf.concat([x15,x1],axis=-1),mask,cnum//2,3,1,name='conv16')
            x17=standard_conv(x16,mask,3,3,1,name='conv17')
            x18=tf.clip_by_value(x17,-1.,1.)

            return x18

def RW_discriminator(x, mask, batch_size, activation = 'leaky_relu',reuse=False):
    '''
    Region-wise discriminator
    Args:
            x: input images
            mask: mask region {0,1}
    returns:
            matrix {real, fake}
    '''
    with tf.compat.v1.variable_scope('discriminator',reuse=reuse):
            cnum=64
            x=tf.concat([x,mask],axis=3)
            x=dis_conv(x,cnum,name='d_conv1')
            x=dis_conv(x,2*cnum,name='d_conv2')
            x=dis_conv(x,4*cnum,name='d_conv3')
            x=dis_conv(x,4*cnum,name='d_conv4')
            x=dis_conv(x,4*cnum,name='d_conv5')
            x=dis_conv(x,4*cnum,name='d_conv6', activation = activation)
            return x
def build_graph_with_loss(batch_data, batch_size, mask, vgg_path, adv_type, stage = 0,
                         lambda_style = 0.001, lambda_cor = 0.00001, alpha = 0.01 ,lambda_adv = 1.0,
                         reuse=False, training = True):

    image_gt=tf.subtract(tf.divide(batch_data,127.5),1.)
    date_shape=batch_data.get_shape().as_list()
    batch_incomplete=image_gt*mask

    image_p1, image_p2 = RW_generator(batch_incomplete, mask)
    image_c1 = image_p1 * (1 - mask) + image_gt * mask
    image_c2 = image_p2 * (1 - mask) + image_gt * mask
    rec_loss = tf.reduce_sum(tf.abs(image_gt - image_p1)) + tf.reduce_sum(tf.abs(image_gt - image_p2))

    vgg = Vgg16(vgg_path)
    vgg.build(image_gt)
    vgg_pos = [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c1)
    vgg_x1 =  [vgg.pool1,vgg.pool2, vgg.pool3]
    vgg.build(image_c2)
    vgg_x2 =  [vgg.pool1,vgg.pool2, vgg.pool3]

    cor_loss = loss_cor(vgg_x1, vgg_pos)
    style_loss= loss_style(vgg_x2, vgg_pos)
    cor_loss = cor_loss * lambda_cor
    style_loss = style_loss * lambda_style
    cor_style = cor_loss + style_loss


    if stage == 1:
        activation = None
        if adv_type == ' ':
            activation = 'leaky_relu'
        d_pred = RW_discriminator(image_c1 * (1 - mask), mask, batch_size, activation)
        d_pred2 = RW_discriminator(image_c2 * (1 - mask), mask, batch_size, activation, reuse = True)
        d_real = RW_discriminator(image_gt * (1 - mask), mask, batch_size, activation, reuse = True)
        mask_label = 1 - mask
        shape = d_pred.get_shape().as_list()
        mask_label =  tf.compat.v1.image.resize_nearest_neighbor(mask_label, [shape[1],shape[2]])
        if adv_type == 'wgan':
            penalty_img = random_interpolates(image_gt, image_c2)
            dout_penalty = RW_discriminator(penalty_img, mask, batch_size, activation,reuse = True)
            penalty_loss = gradients_penalty(penalty_img, dout_penalty, mask = mask)
            adv_d_loss =  tf.reduce_mean(d_pred * mask_label) + tf.reduce_mean(d_pred2 * mask_label) - 0.01 * tf.reduce_mean(d_real * mask_label) +penalty_loss
            adv_g_loss = -1 * tf.reduce_mean(d_pred * mask_label) - tf.reduce_mean(d_pred2 * mask_label)

        elif adv_type == 'gan':
            adv_d_loss = 0.01 * tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_real, labels=tf.ones_like(d_real)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.zeros_like(d_pred)) * mask_label) + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.zeros_like(d_pred2))* mask_label)
            adv_g_loss = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred, labels=tf.ones_like(d_real)) * mask_label)  + tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_pred2, labels=tf.ones_like(d_real)) * mask_label)

        elif adv_type == 'hinge':

            adv_d_loss =  0.01 * tf.reduce_mean(tf.nn.relu(1 - d_real) * mask_label) + tf.reduce_mean(tf.nn.relu(1 + d_pred) * mask_label)
            + tf.reduce_mean(tf.nn.relu(1 + d_pred2) * mask_label)
            adv_g_loss = -1 * tf.reduce_mean(tf.nn.relu(d_pred) * mask_label) - tf.reduce_mean(tf.nn.relu(d_pred2) * mask_label)
        else:

            adv_d_loss =  alpha*tf.reduce_sum(tf.abs(mask_label - d_real)) + tf.reduce_sum(tf.abs(0 - d_pred)) + tf.reduce_sum(tf.abs(0 - d_pred2))
            adv_g_loss = tf.reduce_sum(tf.abs(mask_label - d_pred)) + tf.reduce_sum(tf.abs(mask_label - d_pred2))
    else:
        adv_d_loss = None
        adv_g_loss = None

    if stage == 1:
        g_loss= rec_loss+cor_style + lambda_adv * adv_g_loss
    else:
        g_loss = rec_loss + cor_style
    g_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'inpaint_net')
    d_vars=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES,'discriminator') if stage == 1 else None

    tf.compat.v1.summary.image('incomplete',batch_incomplete, max_outputs=7)
    tf.compat.v1.summary.image('image_p1',image_p1, max_outputs=7)
    tf.compat.v1.summary.image('image_p2',image_p2, max_outputs=7)
    tf.compat.v1.summary.image('image_c2',image_c2, max_outputs=7)
    tf.compat.v1.summary.scalar('rec_loss',rec_loss)
    tf.compat.v1.summary.scalar('correlation loss', cor_loss)
    tf.compat.v1.summary.scalar('style loss', style_loss)
    if stage == 1:
        tf.compat.v1.summary.scalar('adv_g_loss', adv_g_loss)
        tf.compat.v1.summary.scalar('adv_d_loss', adv_d_loss)
    return g_vars,d_vars,g_loss,adv_d_loss,rec_loss,cor_loss,style_loss

def infer(batch_data,mask,reuse=False):
        shape=batch_data.get_shape().as_list()
        batch_gt=batch_data/127.5-1.
        batch_incomplete=batch_gt*mask

        image_p1, image_p2=RW_generator(batch_incomplete,mask,reuse=reuse)

        image_c2=batch_incomplete*mask+ image_p2*(1.-mask)
        image_c2=(image_c2+1.)*127.5
        return image_c2


images=tf.compat.v1.placeholder(tf.float32,[1,256,256,3],name = 'image')
mask=tf.compat.v1.placeholder(tf.float32,[1,256,256,1],name='mask')
sess = tf.compat.v1.Session()
inpainting_result=infer(images,mask)
saver_pre=tf.compat.v1.train.Saver()
init_op = tf.group(tf.compat.v1.initialize_all_variables(),tf.compat.v1.initialize_local_variables())



import random
import gc
import os
import cv2
import glob
import socket
import tensorflow as tf
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import Precision, Recall



output = []
loaded_model = tf.keras.models.load_model(model_path_2)

corrupted_image_folder = os.path.join('/content/drive/MyDrive', corrupted_images_address)
corrupted_image_files = [f for f in os.listdir(os.path.join('/content/drive/MyDrive', corrupted_image_folder)) if f.endswith('.png')]
common_files = set(corrupted_image_files)

for file_name in sorted(common_files):
    test_data_path = os.path.join('/content/drive/MyDrive', corrupted_image_folder, file_name)
    corrupted_image = cv2.imread(test_data_path)

    difference_image_gray = cv2.cvtColor(corrupted_image, cv2.COLOR_BGR2GRAY)

    mask_test = 255-cv2.threshold(difference_image_gray, 1, 255, cv2.THRESH_BINARY)[1]
    mask_test = mask_test.reshape((256,256,1))

    cv2.imwrite('/content/mask.png', mask_test)

    mask_path = "/content/mask.png"
    width = 256
    height = 256
    file_test=test_data_path
    file_mask=mask_path
    file_out = os.path.join('/content/drive/MyDrive', file_out_address)
    sess.run(init_op)
    saver_pre.restore(sess, model_path)

    test_mask = cv2.resize(cv2.imread(file_mask),(height,width))
    test_mask = test_mask[:,:,0:1]
    test_mask = 0. + test_mask//255
    test_mask[test_mask >= 0.5] = 1
    test_mask[test_mask <  0.5] = 0
    test_mask  = 1-test_mask
    test_image = cv2.imread(file_test)[...,::-1]
    test_image = cv2.resize(test_image, (height, width))
    test_mask = np.expand_dims(test_mask,0)
    test_image = np.expand_dims(test_image,0)
    img_out=sess.run(inpainting_result,feed_dict={mask:test_mask,images:test_image})

    out_address = os.path.join('/content/drive/MyDrive', file_out, file_name)
    cv2.imwrite(out_address, img_out[0][...,::-1])

    image = cv2.imread(out_address)
    image = np.expand_dims(image, axis=0)
    predicted_probability = loaded_model.predict(image)
    predicted_labels = np.argmax(predicted_probability, axis=1)
    output.append(predicted_labels[0])

# %%
print(output)
